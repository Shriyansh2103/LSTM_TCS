# %%
import yfinance as yf
import pandas as pd
import os
import numpy as np
import time
import math
from datetime import datetime

# Load stock symbols and their listing dates from CSV
stock_list_path = "NS.csv"  # Path to your CSV
stock_df = pd.read_csv(stock_list_path)
stock_df['DATE OF LISTING'] = pd.to_datetime(stock_df['DATE OF LISTING'])

# Create a directory to store output files
output_directory = "S-Curve_Data"
os.makedirs(output_directory, exist_ok=True)

# ---------------------- Rate-Limited Download Functions ----------------------
def safe_download(symbol, start, retries=3, delay=60):
    """Download stock data with rate limit handling"""
    for attempt in range(retries):
        try:
            data = yf.download(symbol, start=start, interval='1d', progress=False)
            if not data.empty:
                return data
        except Exception as e:
            if 'Too Many Requests' in str(e) or 'Rate limited' in str(e):
                print(f"⏳ Rate limit hit for {symbol}. Waiting {delay} seconds (Attempt {attempt+1}/{retries})...")
                time.sleep(delay)
            else:
                print(f"❌ Unexpected error downloading {symbol}: {e}")
                break
    return pd.DataFrame()

def safe_info(ticker_obj, retries=3, delay=30):
    """Fetch ticker info with rate limit handling"""
    for attempt in range(retries):
        try:
            return ticker_obj.info
        except Exception as e:
            if 'Too Many Requests' in str(e) or 'Rate limited' in str(e):
                print(f"⏳ Rate limit (info) hit. Waiting {delay} seconds...")
                time.sleep(delay)
            else:
                print(f"❌ Info error: {e}")
                break
    return {}

def detect_s_curve(price_series, years):
    """
    Enhanced S-curve detection algorithm that identifies the start of sustained growth

    An S-curve in stock growth typically shows:
    1. Initial slow growth or consolidation phase
    2. Followed by a rapid growth phase that sustains for multiple years
    3. Then stabilization at a higher level

    This function identifies the start of the sustained rapid growth phase (point 2)
    """
    if len(price_series) < 3 or len(years) < 3:
        return np.nan, np.nan

    # Convert to numpy arrays for processing
    prices = np.array(price_series)
    years_array = np.array(years)

    # Calculate year-over-year percentage changes
    pct_changes = np.zeros(len(prices))
    for i in range(1, len(prices)):
        if prices[i-1] > 0:  # Avoid division by zero
            pct_changes[i] = (prices[i] - prices[i-1]) / prices[i-1]

    # Define parameters for S-curve detection
    growth_threshold = 0.15  # 15% minimum annual growth
    sustained_period = min(5, len(prices) - 1)  # Look for 5 years of growth or as much as available
    min_sustained_years = min(3, sustained_period)  # Require at least 3 years to confirm pattern

    # Look for sustained growth periods
    for i in range(1, len(prices) - min_sustained_years + 1):
        # Get the window of percent changes starting at this position
        window = pct_changes[i:i+sustained_period]
        available_years = min(sustained_period, len(window))

        # Check if we have enough positive growth years
        positive_growth_years = sum(window > 0)
        significant_growth_years = sum(window >= growth_threshold)

        # Calculate average growth over this period
        avg_growth = np.mean(window[:available_years])

        # Conditions for S-curve start:
        # 1. Average growth exceeds threshold
        # 2. Most years show positive growth
        # 3. Several years show significant growth
        # 4. Prior period was relatively flat or down (if we have prior data)
        if (avg_growth >= growth_threshold and
            positive_growth_years >= min_sustained_years and
            significant_growth_years >= min_sustained_years * 0.6):

            # Check if there was a change from previous period (if available)
            pattern_confirmed = True
            if i > min_sustained_years:
                prior_period = pct_changes[i-min_sustained_years:i]
                prior_avg_growth = np.mean(prior_period)

                # Confirm we're seeing acceleration from previous period
                if prior_avg_growth >= growth_threshold * 0.8:
                    pattern_confirmed = False

            if pattern_confirmed:
                s_curve_idx = i
                s_curve_price = prices[s_curve_idx]
                s_curve_year = years_array[s_curve_idx]
                return s_curve_price, s_curve_year

    # Alternative approach: Find points where growth rate jumps significantly
    # and stays elevated for multiple years
    for i in range(2, len(pct_changes) - min_sustained_years + 1):
        before_avg = np.mean(pct_changes[max(0, i-2):i])
        after_window = pct_changes[i:i+min_sustained_years]
        after_avg = np.mean(after_window)

        # Check if we have a significant step change in growth rate
        # and the growth is maintained
        if (after_avg > growth_threshold and
            after_avg > before_avg * 2 and  # At least 2x previous growth
            sum(after_window > 0) >= min_sustained_years * 0.8):  # Most years positive

            s_curve_idx = i
            s_curve_price = prices[s_curve_idx]
            s_curve_year = years_array[s_curve_idx]
            return s_curve_price, s_curve_year

    # If we couldn't find a clear S-curve pattern,
    # try to identify a major price bottom followed by recovery
    min_window = min(2, len(prices) - 1)
    for i in range(min_window, len(prices) - min_window):
        # Look for local minimum with clear reversal
        if (prices[i] < np.mean(prices[i-min_window:i]) and
            prices[i] < np.mean(prices[i+1:i+min_window+1]) and
            (prices[i+min_window] / prices[i] - 1) > growth_threshold):

            s_curve_price = prices[i]
            s_curve_year = years_array[i]
            return s_curve_price, s_curve_year

    # If nothing conclusive is found, return NaN
    return np.nan, np.nan

# Function to fetch and process stock data
def fetch_and_process_stock_data(stock_symbol, listing_date, max_retries=3, sleep_time=2):
    """Comprehensive function to fetch and analyze stock data"""
    start_year = listing_date.year
    start_date_str = listing_date.strftime("%Y-%m-%d")

    # Ensure the symbol has the .NS suffix
    full_symbol = stock_symbol if stock_symbol.endswith(".NS") else stock_symbol + ".NS"

    print(f"📥 Processing {full_symbol} from {start_date_str}...")

    try:
        # Download historical stock data from the listing year
        stock_data = safe_download(full_symbol, start=start_date_str, retries=max_retries, delay=sleep_time)

        if stock_data.empty:
            print(f"⚠️ No data found for {full_symbol}")
            return None

        print(f"✅ Data fetched for {full_symbol} ({stock_data.index.min().strftime('%Y-%m-%d')} - {stock_data.index.max().strftime('%Y-%m-%d')})")

        # Check for Close price data
        if 'Close' not in stock_data.columns:
            if 'Adj Close' in stock_data.columns:
                stock_data['Close'] = stock_data['Adj Close']
            else:
                print(f"⚠️ Cannot find price data for {full_symbol}. Skipping.")
                return None

        # Process the data
        stock_data.reset_index(inplace=True)
        stock_data['Year'] = stock_data['Date'].dt.year

        # Add financial year calculation
        stock_data['Fin_Year'] = stock_data['Date'].apply(
            lambda x: x.year if x.month > 3 else x.year - 1
        )

        # Filter out years before listing
        stock_data = stock_data[stock_data['Year'] >= start_year]

        # Yearly metrics - using calendar year for consistency
        yearly_avg_close = stock_data.groupby('Year')['Close'].mean().reset_index()
        yearly_avg_close.columns = ['Year', 'Yearly Average Price']

        # Calculate year-over-year percentage increase in average prices
        yearly_avg_close['Prev Year Avg'] = yearly_avg_close['Yearly Average Price'].shift(1)
        yearly_avg_close['Yearly Avg Price % Increase'] = (
            (yearly_avg_close['Yearly Average Price'] - yearly_avg_close['Prev Year Avg']) /
            yearly_avg_close['Prev Year Avg'] * 100
        )

        # Replace NaN for first year with 0
        yearly_avg_close['Yearly Avg Price % Increase'] = yearly_avg_close['Yearly Avg Price % Increase'].fillna(0)

        # Round to 2 decimal places
        yearly_avg_close['Yearly Avg Price % Increase'] = yearly_avg_close['Yearly Avg Price % Increase'].round(2)

        # Drop the helper column
        yearly_avg_close = yearly_avg_close.drop(columns=['Prev Year Avg'])

        yearly_volatility = stock_data.groupby('Year')['Close'].std().reset_index()
        yearly_volatility.columns = ['Year', 'Yearly Volatility']

        last_dates = stock_data.groupby('Year')['Date'].idxmax()
        last_close_prices = pd.DataFrame()
        last_close_prices['Year'] = stock_data.loc[last_dates, 'Year'].values
        last_close_prices['Market Price'] = stock_data.loc[last_dates, 'Close'].values

        yearly_growth = stock_data.groupby('Year')['Close'].apply(
            lambda x: (x.iloc[-1] / x.iloc[0] - 1) if len(x) > 1 else 0
        ).reset_index()
        yearly_growth.columns = ['Year', 'Yearly Growth']

        # Merge metrics
        merged_data = pd.merge(last_close_prices, yearly_avg_close, on='Year', how='left')
        merged_data = pd.merge(merged_data, yearly_volatility, on='Year', how='left')
        merged_data = pd.merge(merged_data, yearly_growth, on='Year', how='left')
        merged_data.insert(1, 'Stock', full_symbol)

        # Improved S-curve detection
        if len(merged_data) >= 3:  # Need at least 3 years of data for proper detection
            # Sort by year to ensure chronological order
            merged_data = merged_data.sort_values('Year')

            # Get price and year arrays for S-curve detection
            avg_prices = merged_data['Yearly Average Price'].values
            years = merged_data['Year'].values

            # Detect S-curve start
            s_curve_price, s_curve_year = detect_s_curve(avg_prices, years)

            # Calculate years to S-curve
            years_to_scurve = np.nan
            if not np.isnan(s_curve_year):
                years_to_scurve = s_curve_year - start_year

                # Sanity check: if years_to_scurve is negative or too large, something is wrong
                if years_to_scurve < 0 or years_to_scurve > len(merged_data) * 0.75:
                    years_to_scurve = np.nan
                    s_curve_price = np.nan
                    s_curve_year = np.nan
        else:
            s_curve_price = np.nan
            s_curve_year = np.nan
            years_to_scurve = np.nan

        merged_data['Start of S-Curve Price'] = s_curve_price
        merged_data['S-Curve Year'] = s_curve_year
        merged_data['Years to S-Curve Start'] = years_to_scurve

        # Get current financials using the yfinance API
        ticker = yf.Ticker(full_symbol)
        info = safe_info(ticker)

        # Extract current financial metrics
        current_eps = info.get('trailingEps', np.nan)
        current_pe = info.get('trailingPE', np.nan)
        current_book_value = info.get('bookValue', np.nan)
        current_roe = info.get('returnOnEquity', np.nan)

        # Normalize ROE if needed
        if current_roe and current_roe > 1:
            current_roe = current_roe / 100

        # Calculate fundamental PE based on ROE
        fundamental_pe = 1 / current_roe if current_roe and current_roe > 0 else np.nan

        # Add required columns
        for col in ['EPS', 'Projected EPS', 'P/E Ratio', 'Fundamental P/E',
                    'Book Value', 'P/B Ratio', 'ROE', 'Intrinsic Value',
                    'Intrinsic Value (Graham)', 'Intrinsic Value (Combined)',
                    'Market to Intrinsic Ratio']:
            if col not in merged_data.columns:
                merged_data[col] = np.nan

        # Apply derived metrics (approach from first script)
        # Financial metrics - synthesized approach from both scripts
        for index, row in merged_data.iterrows():
            year = row['Year']
            market_price = row['Market Price']
            years_diff = merged_data['Year'].max() - year

            # Estimated EPS based on current EPS with historical growth adjustment
            if current_eps is not None and not pd.isna(current_eps):
                growth_factor = (1 / (1.10 ** years_diff)) if years_diff > 0 else 1
                estimated_eps = current_eps * growth_factor
            else:
                # Fallback calculation from first script
                estimated_eps = (row['Yearly Average Price'] * 0.1 *
                                (1 + row.get('Yearly Growth', 0) * 0.3))
                if not pd.isna(estimated_eps):
                    estimated_eps = max(estimated_eps, 0.01)

            merged_data.at[index, 'EPS'] = estimated_eps

            # Estimated Book Value
            if current_book_value is not None and not pd.isna(current_book_value):
                growth_factor = (1 / (1.08 ** years_diff)) if years_diff > 0 else 1
                estimated_book = current_book_value * growth_factor
            else:
                # Fallback calculation from first script
                factor = (1 - row.get('Yearly Growth', 0) * 0.1 + np.sin(index) * 0.05)
                if not pd.isna(factor):
                    factor = max(factor, 0.05)
                estimated_book = row['Yearly Average Price'] * 0.5 * factor

            merged_data.at[index, 'Book Value'] = estimated_book

            # Calculate P/E and P/B ratios
            if not pd.isna(estimated_eps) and estimated_eps > 0:
                merged_data.at[index, 'P/E Ratio'] = market_price / estimated_eps

            if not pd.isna(estimated_book) and estimated_book > 0:
                merged_data.at[index, 'P/B Ratio'] = market_price / estimated_book

            # Return on Equity
            if current_roe is not None and not pd.isna(current_roe):
                merged_data.at[index, 'ROE'] = current_roe
            else:
                # Calculate from EPS and Book Value
                if not pd.isna(estimated_eps) and not pd.isna(estimated_book) and estimated_book > 0:
                    roe_value = estimated_eps / estimated_book
                    merged_data.at[index, 'ROE'] = roe_value

            # Fundamental P/E calculation
            if not pd.isna(merged_data.at[index, 'ROE']) and merged_data.at[index, 'ROE'] > 0:
                merged_data.at[index, 'Fundamental P/E'] = 1 / merged_data.at[index, 'ROE']
            else:
                # Alternative calculation from first script
                base_pe = 15.0
                if not pd.isna(row.get('Yearly Volatility')) and not pd.isna(row['Yearly Average Price']):
                    base_pe -= (row['Yearly Volatility'] / row['Yearly Average Price'] * 20)

                if not pd.isna(row.get('Yearly Growth')):
                    base_pe += (row['Yearly Growth'] * 10)

                base_pe = max(8, min(25, base_pe))
                merged_data.at[index, 'Fundamental P/E'] = base_pe

            # Calculate future growth and EPS projection
            future_growth_rate = row.get('Yearly Growth', 0)
            if not pd.isna(future_growth_rate):
                future_growth_rate = max(-0.1, min(0.2, future_growth_rate))
                if not pd.isna(estimated_eps):
                    merged_data.at[index, 'Projected EPS'] = estimated_eps * (1 + future_growth_rate)

            # Intrinsic Value calculations
            # Graham's formula
            try:
                if not pd.isna(estimated_eps) and not pd.isna(estimated_book) and estimated_eps > 0 and estimated_book > 0:
                    graham_value = math.sqrt(22.5 * estimated_eps * estimated_book)
                    merged_data.at[index, 'Intrinsic Value (Graham)'] = graham_value
            except:
                pass

            # EPS-based intrinsic value
            if not pd.isna(estimated_eps) and not pd.isna(merged_data.at[index, 'Fundamental P/E']):
                eps_value = estimated_eps * merged_data.at[index, 'Fundamental P/E']
                merged_data.at[index, 'Intrinsic Value'] = eps_value

            # Combined intrinsic value
            values = []
            for col in ['Intrinsic Value', 'Intrinsic Value (Graham)']:
                if col in merged_data.columns and not pd.isna(merged_data.at[index, col]):
                    values.append(merged_data.at[index, col])

            if values:
                combined = np.mean(values)
                merged_data.at[index, 'Intrinsic Value (Combined)'] = combined

                if not pd.isna(market_price) and combined > 0:
                    market_ratio = market_price / combined
                    merged_data.at[index, 'Market to Intrinsic Ratio'] = market_ratio

        # Valuation status
        conditions = [
            merged_data['Market to Intrinsic Ratio'] < 0.8,
            merged_data['Market to Intrinsic Ratio'] < 1.0,
            merged_data['Market to Intrinsic Ratio'] < 1.2,
            merged_data['Market to Intrinsic Ratio'] >= 1.2
        ]
        values = ['Undervalued', 'Fair Value', 'Slightly Overvalued', 'Overvalued']
        merged_data['Valuation Status'] = np.select(conditions, values, default='Fair Value')

        # Round numeric columns
        final_columns = [
            'Year', 'Stock', 'Market Price', 'Yearly Average Price', 'Yearly Avg Price % Increase',
            'Yearly Volatility', 'Yearly Growth', 'EPS', 'Projected EPS', 'P/E Ratio',
            'Fundamental P/E', 'Book Value', 'P/B Ratio', 'ROE', 'Start of S-Curve Price',
            'S-Curve Year', 'Years to S-Curve Start', 'Intrinsic Value',
            'Intrinsic Value (Graham)', 'Intrinsic Value (Combined)',
            'Market to Intrinsic Ratio', 'Valuation Status'
        ]

        # Ensure all columns exist (add if missing)
        for col in final_columns:
            if col not in merged_data.columns and col not in ['Year', 'Stock', 'Valuation Status']:
                merged_data[col] = np.nan

        # Select and order columns that actually exist in the dataframe
        existing_columns = [col for col in final_columns if col in merged_data.columns]
        merged_data = merged_data[existing_columns]

        # Round numeric columns
        for col in merged_data.columns:
            if col not in ['Year', 'Stock', 'Valuation Status', 'S-Curve Year']:
                try:
                    if merged_data[col].dtype in [np.float64, np.float32, float]:
                        merged_data[col] = merged_data[col].round(2)
                except:
                    pass

        # Save to file
        file_path = os.path.join(output_directory, f"{full_symbol}_yearly_analysis.csv")
        merged_data.to_csv(file_path, index=False)

        print(f"📁 Saved: {file_path}")
        return merged_data

    except Exception as error:
        print(f"⚠️ Error processing {full_symbol}: {error}")
        time.sleep(sleep_time)
        return None

# Main execution
all_results = {}
for i, row in stock_df.iterrows():
    symbol = row['SYMBOL']
    listing_date = row['DATE OF LISTING']

    result = fetch_and_process_stock_data(symbol, listing_date)

    if result is not None:
        all_results[symbol] = result

    # Take a break every 10 stocks to avoid rate limits
    if (i + 1) % 10 == 0:
        print("🌍 Taking a longer break to avoid rate limits...")
        time.sleep(15)

# Create summary of latest data for all stocks
if all_results:
    summary_data = []
    for symbol, data in all_results.items():
        if not data.empty:
            latest_year = data['Year'].max()
            latest_data = data[data['Year'] == latest_year].copy()
            if not latest_data.empty:
                summary_data.append(latest_data)

    if summary_data:
        summary_df = pd.concat(summary_data)
        summary_file = os.path.join(output_directory, "all_stocks_latest_analysis.csv")
        summary_df.to_csv(summary_file, index=False)
        print(f"📊 Summary saved to {summary_file}")

print(f"✅ Analysis complete. Output in '{output_directory}/'")
# Out:
# 📥 Processing 20MICRONS.NS from 2008-10-06...
# YF.download() has changed argument auto_adjust default to True
# ✅ Data fetched for 20MICRONS.NS (2008-10-06 - 2025-04-11)
# 📁 Saved: S-Curve_Data/20MICRONS.NS_yearly_analysis.csv
# 📥 Processing 21STCENMGM.NS from 1995-05-03...
# ✅ Data fetched for 21STCENMGM.NS (2018-01-11 - 2025-04-11)
# 📁 Saved: S-Curve_Data/21STCENMGM.NS_yearly_analysis.csv
# 📥 Processing 360ONE.NS from 2019-09-19...
# ✅ Data fetched for 360ONE.NS (2019-09-19 - 2025-04-11)
# 📁 Saved: S-Curve_Data/360ONE.NS_yearly_analysis.csv
# 📥 Processing 3MINDIA.NS from 2004-08-13...
# ✅ Data fetched for 3MINDIA.NS (2004-08-13 - 2025-04-11)
# 📁 Saved: S-Curve_Data/3MINDIA.NS_yearly_analysis.csv
# 📥 Processing 3PLAND.NS from 1995-07-19...
# ✅ Data fetched for 3PLAND.NS (2008-03-11 - 2025-04-11)
# 📁 Saved: S-Curve_Data/3PLAND.NS_yearly_analysis.csv
# 📥 Processing 5PAISA.NS from 2017-11-16...
# ✅ Data fetched for 5PAISA.NS (2017-11-16 - 2025-04-11)
# 📁 Saved: S-Curve_Data/5PAISA.NS_yearly_analysis.csv
# 📥 Processing 63MOONS.NS from 2005-06-20...
# ✅ Data fetched for 63MOONS.NS (2005-06-20 - 2025-04-11)
# 📁 Saved: S-Curve_Data/63MOONS.NS_yearly_analysis.csv
# 📥 Processing A2ZINFRA.NS from 2010-12-23...
# ✅ Data fetched for A2ZINFRA.NS (2010-12-23 - 2025-04-11)
# 📁 Saved: S-Curve_Data/A2ZINFRA.NS_yearly_analysis.csv
# 📥 Processing AARTIDRUGS.NS from 2003-09-19...
# ✅ Data fetched for AARTIDRUGS.NS (2003-09-19 - 2025-04-11)
# 📁 Saved: S-Curve_Data/AARTIDRUGS.NS_yearly_analysis.csv
# 📥 Processing AARTIIND.NS from 1995-02-08...
# ✅ Data fetched for AARTIIND.NS (2002-07-01 - 2025-04-11)
# 📁 Saved: S-Curve_Data/AARTIIND.NS_yearly_analysis.csv
# 🌍 Taking a longer break to avoid rate limits...
# 📥 Processing AARVEEDEN.NS from 2006-11-21...
# ✅ Data fetched for AARVEEDEN.NS (2006-11-21 - 2025-04-11)
# 📁 Saved: S-Curve_Data/AARVEEDEN.NS_yearly_analysis.csv
# 📥 Processing AAVAS.NS from 2018-10-08...
# ✅ Data fetched for AAVAS.NS (2018-10-08 - 2025-04-11)
# 📁 Saved: S-Curve_Data/AAVAS.NS_yearly_analysis.csv
# 📥 Processing ABAN.NS from 1995-03-29...
# ✅ Data fetched for ABAN.NS (2002-08-12 - 2025-04-11)
# 📁 Saved: S-Curve_Data/ABAN.NS_yearly_analysis.csv
# 📥 Processing ABB.NS from 1995-02-08...
# ✅ Data fetched for ABB.NS (2002-07-01 - 2025-04-11)
# 📁 Saved: S-Curve_Data/ABB.NS_yearly_analysis.csv
# 📥 Processing ABBOTINDIA.NS from 2010-01-08...
# ✅ Data fetched for ABBOTINDIA.NS (2010-01-08 - 2025-04-11)
# 📁 Saved: S-Curve_Data/ABBOTINDIA.NS_yearly_analysis.csv
# 📥 Processing ABCAPITAL.NS from 2017-09-01...
# ✅ Data fetched for ABCAPITAL.NS (2017-09-01 - 2025-04-11)
# 📁 Saved: S-Curve_Data/ABCAPITAL.NS_yearly_analysis.csv
# 📥 Processing ABFRL.NS from 2013-07-17...
# ✅ Data fetched for ABFRL.NS (2013-07-17 - 2025-04-11)
# 📁 Saved: S-Curve_Data/ABFRL.NS_yearly_analysis.csv
# 📥 Processing ABREL.NS from 2003-06-27...
# ✅ Data fetched for ABREL.NS (2003-06-27 - 2025-04-11)
# 📁 Saved: S-Curve_Data/ABREL.NS_yearly_analysis.csv
# 📥 Processing ACC.NS from 1996-11-20...
# ✅ Data fetched for ACC.NS (2002-07-01 - 2025-04-11)
# 📁 Saved: S-Curve_Data/ACC.NS_yearly_analysis.csv
# 📥 Processing ACCELYA.NS from 1999-12-01...
# ✅ Data fetched for ACCELYA.NS (2002-07-01 - 2025-04-11)
# 📁 Saved: S-Curve_Data/ACCELYA.NS_yearly_analysis.csv
# 🌍 Taking a longer break to avoid rate limits...
# 📥 Processing ACE.NS from 2006-09-26...
# ✅ Data fetched for ACE.NS (2006-09-26 - 2025-04-11)
# 📁 Saved: S-Curve_Data/ACE.NS_yearly_analysis.csv
# 📥 Processing ACLGATI.NS from 2006-10-10...
# ✅ Data fetched for ACLGATI.NS (2006-10-10 - 2025-04-11)
# 📁 Saved: S-Curve_Data/ACLGATI.NS_yearly_analysis.csv
# 📥 Processing ADANIENSOL.NS from 2015-07-31...
# ✅ Data fetched for ADANIENSOL.NS (2023-08-16 - 2025-04-11)
# 📁 Saved: S-Curve_Data/ADANIENSOL.NS_yearly_analysis.csv
# 📥 Processing ADANIENT.NS from 1997-06-04...
# ✅ Data fetched for ADANIENT.NS (2002-07-01 - 2025-04-11)
# 📁 Saved: S-Curve_Data/ADANIENT.NS_yearly_analysis.csv
# 📥 Processing ADANIGREEN.NS from 2018-06-18...
# ✅ Data fetched for ADANIGREEN.NS (2018-06-18 - 2025-04-11)
# 📁 Saved: S-Curve_Data/ADANIGREEN.NS_yearly_analysis.csv
# 📥 Processing ADANIPORTS.NS from 2007-11-27...
# ✅ Data fetched for ADANIPORTS.NS (2007-11-27 - 2025-04-11)
# 📁 Saved: S-Curve_Data/ADANIPORTS.NS_yearly_analysis.csv
# 📥 Processing ADANIPOWER.NS from 2009-08-20...
# ✅ Data fetched for ADANIPOWER.NS (2009-08-20 - 2025-04-11)
# 📁 Saved: S-Curve_Data/ADANIPOWER.NS_yearly_analysis.csv
# 📥 Processing ADFFOODS.NS from 2010-09-15...
# ✅ Data fetched for ADFFOODS.NS (2010-09-15 - 2025-04-11)
# 📁 Saved: S-Curve_Data/ADFFOODS.NS_yearly_analysis.csv
# 📥 Processing ADORWELD.NS from 1995-05-10...
# ✅ Data fetched for ADORWELD.NS (2002-07-01 - 2025-04-09)
# 📁 Saved: S-Curve_Data/ADORWELD.NS_yearly_analysis.csv
# 📥 Processing ADROITINFO.NS from 1997-08-13...
# ✅ Data fetched for ADROITINFO.NS (2015-10-13 - 2025-04-11)
# 📁 Saved: S-Curve_Data/ADROITINFO.NS_yearly_analysis.csv
# 🌍 Taking a longer break to avoid rate limits...
# 📥 Processing ADSL.NS from 2007-07-25...
# ✅ Data fetched for ADSL.NS (2007-07-25 - 2025-04-11)
# 📁 Saved: S-Curve_Data/ADSL.NS_yearly_analysis.csv
# 📥 Processing ADVANIHOTR.NS from 2007-06-25...
# ✅ Data fetched for ADVANIHOTR.NS (2007-06-25 - 2025-04-11)
# 📁 Saved: S-Curve_Data/ADVANIHOTR.NS_yearly_analysis.csv
# 📥 Processing ADVENZYMES.NS from 2016-08-01...
# ✅ Data fetched for ADVENZYMES.NS (2016-08-01 - 2025-04-11)
# 📁 Saved: S-Curve_Data/ADVENZYMES.NS_yearly_analysis.csv
# 📥 Processing AEGISLOG.NS from 1996-04-03...
# ✅ Data fetched for AEGISLOG.NS (2024-05-30 - 2025-04-11)
# 📁 Saved: S-Curve_Data/AEGISLOG.NS_yearly_analysis.csv
# 📥 Processing AFFLE.NS from 2019-08-08...
# ✅ Data fetched for AFFLE.NS (2019-08-08 - 2025-04-11)
# 📁 Saved: S-Curve_Data/AFFLE.NS_yearly_analysis.csv
# 📥 Processing AGARIND.NS from 2014-05-26...
# ✅ Data fetched for AGARIND.NS (2014-05-26 - 2025-04-11)
# 📁 Saved: S-Curve_Data/AGARIND.NS_yearly_analysis.csv
# 📥 Processing AGI.NS from 2000-05-31...
# ✅ Data fetched for AGI.NS (2002-07-01 - 2025-04-11)
# 📁 Saved: S-Curve_Data/AGI.NS_yearly_analysis.csv
# 📥 Processing AGRITECH.NS from 2014-01-28...
# ✅ Data fetched for AGRITECH.NS (2014-01-28 - 2025-04-11)
# 📁 Saved: S-Curve_Data/AGRITECH.NS_yearly_analysis.csv
# 📥 Processing AGROPHOS.NS from 2019-03-08...
# ✅ Data fetched for AGROPHOS.NS (2019-03-08 - 2025-04-11)
# 📁 Saved: S-Curve_Data/AGROPHOS.NS_yearly_analysis.csv
# 📥 Processing AHLEAST.NS from 2010-08-11...
# ✅ Data fetched for AHLEAST.NS (2010-08-11 - 2025-04-11)
# 📁 Saved: S-Curve_Data/AHLEAST.NS_yearly_analysis.csv
# 🌍 Taking a longer break to avoid rate limits...
# 📥 Processing AHLUCONT.NS from 2009-12-14...
# ✅ Data fetched for AHLUCONT.NS (2009-12-14 - 2025-04-11)
# 📁 Saved: S-Curve_Data/AHLUCONT.NS_yearly_analysis.csv
# 📥 Processing AIAENG.NS from 2005-12-14...
# ✅ Data fetched for AIAENG.NS (2005-12-14 - 2025-04-11)
# 📁 Saved: S-Curve_Data/AIAENG.NS_yearly_analysis.csv
# 📥 Processing AIRAN.NS from 2019-05-03...
# ✅ Data fetched for AIRAN.NS (2019-05-03 - 2025-04-11)
# 📁 Saved: S-Curve_Data/AIRAN.NS_yearly_analysis.csv
# 📥 Processing AJANTPHARM.NS from 2000-05-29...
# ✅ Data fetched for AJANTPHARM.NS (2002-07-01 - 2025-04-11)
# 📁 Saved: S-Curve_Data/AJANTPHARM.NS_yearly_analysis.csv
# 📥 Processing AJMERA.NS from 2009-06-16...
# ✅ Data fetched for AJMERA.NS (2009-06-16 - 2025-04-11)
# 📁 Saved: S-Curve_Data/AJMERA.NS_yearly_analysis.csv
# 📥 Processing AKASH.NS from 2019-10-11...
# ✅ Data fetched for AKASH.NS (2019-10-11 - 2025-04-11)
# 📁 Saved: S-Curve_Data/AKASH.NS_yearly_analysis.csv
# 📥 Processing AKSHARCHEM.NS from 2017-03-28...
# ✅ Data fetched for AKSHARCHEM.NS (2017-03-29 - 2025-04-11)
# 📁 Saved: S-Curve_Data/AKSHARCHEM.NS_yearly_analysis.csv
# 📥 Processing AKSHOPTFBR.NS from 2000-08-18...
# ✅ Data fetched for AKSHOPTFBR.NS (2002-07-01 - 2025-04-11)
# 📁 Saved: S-Curve_Data/AKSHOPTFBR.NS_yearly_analysis.csv
# 📥 Processing AKZOINDIA.NS from 2001-06-28...
# ✅ Data fetched for AKZOINDIA.NS (2002-07-01 - 2025-04-11)
# 📁 Saved: S-Curve_Data/AKZOINDIA.NS_yearly_analysis.csv
# 📥 Processing ALANKIT.NS from 2015-06-30...
# ✅ Data fetched for ALANKIT.NS (2015-06-30 - 2025-04-11)
# 📁 Saved: S-Curve_Data/ALANKIT.NS_yearly_analysis.csv
# 🌍 Taking a longer break to avoid rate limits...
# 📥 Processing ALBERTDAVD.NS from 2016-06-14...
# ✅ Data fetched for ALBERTDAVD.NS (2016-06-14 - 2025-04-11)
# 📁 Saved: S-Curve_Data/ALBERTDAVD.NS_yearly_analysis.csv
# 📥 Processing ALEMBICLTD.NS from 1999-09-22...
# ✅ Data fetched for ALEMBICLTD.NS (2002-07-01 - 2025-04-11)
# 📁 Saved: S-Curve_Data/ALEMBICLTD.NS_yearly_analysis.csv
# 📥 Processing ALICON.NS from 2006-09-29...
# ✅ Data fetched for ALICON.NS (2006-10-03 - 2025-04-11)
# 📁 Saved: S-Curve_Data/ALICON.NS_yearly_analysis.csv
# 📥 Processing ALKALI.NS from 2008-11-06...
# ✅ Data fetched for ALKALI.NS (2008-11-06 - 2025-04-11)
# 📁 Saved: S-Curve_Data/ALKALI.NS_yearly_analysis.csv
# 📥 Processing ALKEM.NS from 2015-12-23...
# ✅ Data fetched for ALKEM.NS (2015-12-23 - 2025-04-11)
# 📁 Saved: S-Curve_Data/ALKEM.NS_yearly_analysis.csv
# 📥 Processing ALKYLAMINE.NS from 2007-11-26...
# ✅ Data fetched for ALKYLAMINE.NS (2007-11-26 - 2025-04-11)
# 📁 Saved: S-Curve_Data/ALKYLAMINE.NS_yearly_analysis.csv
# 📥 Processing ALLCARGO.NS from 2006-06-23...
# ✅ Data fetched for ALLCARGO.NS (2006-06-23 - 2025-04-11)
# 📁 Saved: S-Curve_Data/ALLCARGO.NS_yearly_analysis.csv
# 📥 Processing ALLDIGI.NS from 2005-05-09...
# ✅ Data fetched for ALLDIGI.NS (2024-09-18 - 2025-04-11)
# 📁 Saved: S-Curve_Data/ALLDIGI.NS_yearly_analysis.csv
# 📥 Processing ALMONDZ.NS from 2008-06-16...
# ✅ Data fetched for ALMONDZ.NS (2008-06-16 - 2025-04-11)
# 📁 Saved: S-Curve_Data/ALMONDZ.NS_yearly_analysis.csv
# 📥 Processing ALPA.NS from 2007-08-06...
# ✅ Data fetched for ALPA.NS (2007-08-06 - 2025-04-11)
# 📁 Saved: S-Curve_Data/ALPA.NS_yearly_analysis.csv
# 🌍 Taking a longer break to avoid rate limits...
# 📥 Processing ALPHAGEO.NS from 2007-05-11...
# ✅ Data fetched for ALPHAGEO.NS (2007-05-11 - 2025-04-11)
# 📁 Saved: S-Curve_Data/ALPHAGEO.NS_yearly_analysis.csv
# 📥 Processing ALPSINDUS.NS from 1996-04-24...
# ✅ Data fetched for ALPSINDUS.NS (2002-07-01 - 2025-04-11)
# 📁 Saved: S-Curve_Data/ALPSINDUS.NS_yearly_analysis.csv
# 📥 Processing AMBER.NS from 2018-01-30...
# ✅ Data fetched for AMBER.NS (2018-01-30 - 2025-04-11)
# 📁 Saved: S-Curve_Data/AMBER.NS_yearly_analysis.csv
# 📥 Processing AMBICAAGAR.NS from 2004-06-29...
# ✅ Data fetched for AMBICAAGAR.NS (2004-06-29 - 2025-04-11)
# 📁 Saved: S-Curve_Data/AMBICAAGAR.NS_yearly_analysis.csv
# 📥 Processing AMBIKCO.NS from 2008-01-29...
# ✅ Data fetched for AMBIKCO.NS (2008-01-29 - 2025-04-11)
# 📁 Saved: S-Curve_Data/AMBIKCO.NS_yearly_analysis.csv
# 📥 Processing AMBUJACEM.NS from 1998-02-18...
# ✅ Data fetched for AMBUJACEM.NS (2002-07-01 - 2025-04-11)
# 📁 Saved: S-Curve_Data/AMBUJACEM.NS_yearly_analysis.csv
# 📥 Processing AMDIND.NS from 2007-03-19...
# ✅ Data fetched for AMDIND.NS (2007-03-19 - 2025-04-11)
# 📁 Saved: S-Curve_Data/AMDIND.NS_yearly_analysis.csv
# 📥 Processing AMJLAND.NS from 1995-02-08...
# ✅ Data fetched for AMJLAND.NS (2002-07-01 - 2025-04-11)
# 📁 Saved: S-Curve_Data/AMJLAND.NS_yearly_analysis.csv
# 📥 Processing AMRUTANJAN.NS from 2015-01-02...
# ✅ Data fetched for AMRUTANJAN.NS (2015-01-02 - 2025-04-11)
# 📁 Saved: S-Curve_Data/AMRUTANJAN.NS_yearly_analysis.csv
# 📥 Processing ANANTRAJ.NS from 2006-09-27...
# ✅ Data fetched for ANANTRAJ.NS (2006-09-27 - 2025-04-11)
# 📁 Saved: S-Curve_Data/ANANTRAJ.NS_yearly_analysis.csv
# 🌍 Taking a longer break to avoid rate limits...
# 📥 Processing ANDHRAPAP.NS from 2004-05-13...
# ✅ Data fetched for ANDHRAPAP.NS (2004-05-13 - 2025-04-11)
# 📁 Saved: S-Curve_Data/ANDHRAPAP.NS_yearly_analysis.csv
# 📥 Processing ANDHRSUGAR.NS from 1995-11-01...
# ✅ Data fetched for ANDHRSUGAR.NS (2002-07-01 - 2025-04-11)
# 📁 Saved: S-Curve_Data/ANDHRSUGAR.NS_yearly_analysis.csv
# 📥 Processing ANIKINDS.NS from 2008-05-21...
# ✅ Data fetched for ANIKINDS.NS (2008-05-21 - 2025-04-11)
# 📁 Saved: S-Curve_Data/ANIKINDS.NS_yearly_analysis.csv
# 📥 Processing ANSALAPI.NS from 2006-01-27...
# ✅ Data fetched for ANSALAPI.NS (2006-01-27 - 2025-04-11)
# 📁 Saved: S-Curve_Data/ANSALAPI.NS_yearly_analysis.csv
# 📥 Processing ANTGRAPHIC.NS from 1997-12-31...
# ✅ Data fetched for ANTGRAPHIC.NS (2002-07-01 - 2025-04-11)
# 📁 Saved: S-Curve_Data/ANTGRAPHIC.NS_yearly_analysis.csv
# 📥 Processing ANUP.NS from 2019-03-01...
# ✅ Data fetched for ANUP.NS (2019-03-01 - 2025-04-11)
# 📁 Saved: S-Curve_Data/ANUP.NS_yearly_analysis.csv
# 📥 Processing APARINDS.NS from 2004-07-12...
# ✅ Data fetched for APARINDS.NS (2004-07-12 - 2025-04-11)
# 📁 Saved: S-Curve_Data/APARINDS.NS_yearly_analysis.csv
# 📥 Processing APCL.NS from 2017-04-10...
# ✅ Data fetched for APCL.NS (2017-04-10 - 2025-04-11)
# 📁 Saved: S-Curve_Data/APCL.NS_yearly_analysis.csv
# 📥 Processing APCOTEXIND.NS from 1995-09-06...
# ✅ Data fetched for APCOTEXIND.NS (2002-08-12 - 2025-04-11)
# 📁 Saved: S-Curve_Data/APCOTEXIND.NS_yearly_analysis.csv
# 📥 Processing APEX.NS from 2017-09-04...
# ✅ Data fetched for APEX.NS (2017-09-05 - 2025-04-11)
# 📁 Saved: S-Curve_Data/APEX.NS_yearly_analysis.csv
# 🌍 Taking a longer break to avoid rate limits...
# 📥 Processing APLAPOLLO.NS from 2011-12-14...
# ✅ Data fetched for APLAPOLLO.NS (2011-12-14 - 2025-04-11)
# 📁 Saved: S-Curve_Data/APLAPOLLO.NS_yearly_analysis.csv
# 📥 Processing APLLTD.NS from 2011-09-20...
# ✅ Data fetched for APLLTD.NS (2011-09-20 - 2025-04-11)
# 📁 Saved: S-Curve_Data/APLLTD.NS_yearly_analysis.csv
# 📥 Processing APOLLO.NS from 2018-01-22...
# ✅ Data fetched for APOLLO.NS (2018-01-22 - 2025-04-11)
# 📁 Saved: S-Curve_Data/APOLLO.NS_yearly_analysis.csv
# 📥 Processing APOLLOHOSP.NS from 1996-01-10...
# ✅ Data fetched for APOLLOHOSP.NS (2002-07-01 - 2025-04-11)
# 📁 Saved: S-Curve_Data/APOLLOHOSP.NS_yearly_analysis.csv
# 📥 Processing APOLLOPIPE.NS from 2019-11-11...
# ✅ Data fetched for APOLLOPIPE.NS (2019-11-11 - 2025-04-11)
# 📁 Saved: S-Curve_Data/APOLLOPIPE.NS_yearly_analysis.csv
# 📥 Processing APOLLOTYRE.NS from 1995-05-31...
# ✅ Data fetched for APOLLOTYRE.NS (2002-01-01 - 2025-04-11)
# 📁 Saved: S-Curve_Data/APOLLOTYRE.NS_yearly_analysis.csv
# 📥 Processing APOLSINHOT.NS from 2015-01-28...
# ✅ Data fetched for APOLSINHOT.NS (2015-02-16 - 2025-04-11)
# 📁 Saved: S-Curve_Data/APOLSINHOT.NS_yearly_analysis.csv
# 📥 Processing APTECHT.NS from 2002-09-27...
# ✅ Data fetched for APTECHT.NS (2002-09-27 - 2025-04-11)
# 📁 Saved: S-Curve_Data/APTECHT.NS_yearly_analysis.csv
# 📥 Processing ARCHIDPLY.NS from 2008-07-04...
# ✅ Data fetched for ARCHIDPLY.NS (2008-07-04 - 2025-04-11)
# 📁 Saved: S-Curve_Data/ARCHIDPLY.NS_yearly_analysis.csv
# 📥 Processing ARCHIES.NS from 1998-09-02...
# ✅ Data fetched for ARCHIES.NS (2002-08-12 - 2025-04-11)
# 📁 Saved: S-Curve_Data/ARCHIES.NS_yearly_analysis.csv
# 🌍 Taking a longer break to avoid rate limits...
# 📥 Processing ARE&M.NS from 2003-09-05...
# ✅ Data fetched for ARE&M.NS (2023-10-18 - 2025-04-11)
# 📁 Saved: S-Curve_Data/ARE&M.NS_yearly_analysis.csv
# 📥 Processing ARENTERP.NS from 1995-10-18...
# ✅ Data fetched for ARENTERP.NS (2017-11-07 - 2025-04-11)
# 📁 Saved: S-Curve_Data/ARENTERP.NS_yearly_analysis.csv
# 📥 Processing ARIES.NS from 2008-01-11...
# ✅ Data fetched for ARIES.NS (2008-01-11 - 2025-04-11)
# 📁 Saved: S-Curve_Data/ARIES.NS_yearly_analysis.csv
# 📥 Processing ARIHANTSUP.NS from 2017-03-28...
# ✅ Data fetched for ARIHANTSUP.NS (2017-03-29 - 2025-04-11)
# 📁 Saved: S-Curve_Data/ARIHANTSUP.NS_yearly_analysis.csv
# 📥 Processing ARMANFIN.NS from 2016-06-14...
# ✅ Data fetched for ARMANFIN.NS (2016-06-14 - 2025-04-11)
# 📁 Saved: S-Curve_Data/ARMANFIN.NS_yearly_analysis.csv
# 📥 Processing AROGRANITE.NS from 2007-04-24...
# ✅ Data fetched for AROGRANITE.NS (2007-04-24 - 2025-04-11)
# 📁 Saved: S-Curve_Data/AROGRANITE.NS_yearly_analysis.csv
# 📥 Processing ARROWGREEN.NS from 2015-05-21...
# ✅ Data fetched for ARROWGREEN.NS (2015-05-21 - 2025-04-11)
# 📁 Saved: S-Curve_Data/ARROWGREEN.NS_yearly_analysis.csv
# 📥 Processing ARVIND.NS from 1995-02-08...
# ✅ Data fetched for ARVIND.NS (2002-07-01 - 2025-04-11)
# 📁 Saved: S-Curve_Data/ARVIND.NS_yearly_analysis.csv
# 📥 Processing ARVINDFASN.NS from 2019-03-08...
# ✅ Data fetched for ARVINDFASN.NS (2019-03-08 - 2025-04-11)
# 📁 Saved: S-Curve_Data/ARVINDFASN.NS_yearly_analysis.csv
# 📥 Processing ARVSMART.NS from 2015-08-26...
# ✅ Data fetched for ARVSMART.NS (2015-08-26 - 2025-04-11)
# 📁 Saved: S-Curve_Data/ARVSMART.NS_yearly_analysis.csv
# 🌍 Taking a longer break to avoid rate limits...
# 📥 Processing ASAHIINDIA.NS from 1998-03-18...
# ✅ Data fetched for ASAHIINDIA.NS (2002-07-01 - 2025-04-11)
# 📁 Saved: S-Curve_Data/ASAHIINDIA.NS_yearly_analysis.csv
# 📥 Processing ASAHISONG.NS from 2011-08-29...
# ✅ Data fetched for ASAHISONG.NS (2011-08-29 - 2025-04-11)
# 📁 Saved: S-Curve_Data/ASAHISONG.NS_yearly_analysis.csv
# 📥 Processing ASAL.NS from 2002-03-12...
# ✅ Data fetched for ASAL.NS (2002-07-01 - 2025-04-11)
# 📁 Saved: S-Curve_Data/ASAL.NS_yearly_analysis.csv
# 📥 Processing ASHAPURMIN.NS from 1995-09-20...
# ✅ Data fetched for ASHAPURMIN.NS (1996-01-05 - 2025-04-11)
# 📁 Saved: S-Curve_Data/ASHAPURMIN.NS_yearly_analysis.csv
# 📥 Processing ASHIANA.NS from 2011-06-29...
# ✅ Data fetched for ASHIANA.NS (2011-06-29 - 2025-04-11)
# 📁 Saved: S-Curve_Data/ASHIANA.NS_yearly_analysis.csv
# 📥 Processing ASHIMASYN.NS from 1995-07-27...
# ✅ Data fetched for ASHIMASYN.NS (2002-07-01 - 2025-04-11)
# 📁 Saved: S-Curve_Data/ASHIMASYN.NS_yearly_analysis.csv
# 📥 Processing ASHOKA.NS from 2010-10-14...
# ✅ Data fetched for ASHOKA.NS (2010-10-14 - 2025-04-11)
# 📁 Saved: S-Curve_Data/ASHOKA.NS_yearly_analysis.csv
# 📥 Processing ASHOKLEY.NS from 1995-05-25...
# ✅ Data fetched for ASHOKLEY.NS (2002-07-01 - 2025-04-11)
# 📁 Saved: S-Curve_Data/ASHOKLEY.NS_yearly_analysis.csv
# 📥 Processing ASIANHOTNR.NS from 2010-04-07...
# ✅ Data fetched for ASIANHOTNR.NS (2010-04-07 - 2025-04-11)
# 📁 Saved: S-Curve_Data/ASIANHOTNR.NS_yearly_analysis.csv
# 📥 Processing ASIANPAINT.NS from 1995-05-31...
# ✅ Data fetched for ASIANPAINT.NS (2002-07-01 - 2025-04-11)
# 📁 Saved: S-Curve_Data/ASIANPAINT.NS_yearly_analysis.csv
# 🌍 Taking a longer break to avoid rate limits...
# 📥 Processing ASIANTILES.NS from 2007-08-23...
# ✅ Data fetched for ASIANTILES.NS (2007-08-23 - 2025-04-11)
# 📁 Saved: S-Curve_Data/ASIANTILES.NS_yearly_analysis.csv
# 📥 Processing ASPINWALL.NS from 2016-06-14...
# ✅ Data fetched for ASPINWALL.NS (2016-06-14 - 2025-04-11)
# 📁 Saved: S-Curve_Data/ASPINWALL.NS_yearly_analysis.csv
# 📥 Processing ASTEC.NS from 2009-11-25...
# ✅ Data fetched for ASTEC.NS (2009-11-25 - 2025-04-11)
# 📁 Saved: S-Curve_Data/ASTEC.NS_yearly_analysis.csv
# 📥 Processing ASTERDM.NS from 2018-02-26...
# ✅ Data fetched for ASTERDM.NS (2018-02-26 - 2025-04-11)
# 📁 Saved: S-Curve_Data/ASTERDM.NS_yearly_analysis.csv
# 📥 Processing ASTRAL.NS from 2007-03-20...
# ✅ Data fetched for ASTRAL.NS (2007-03-20 - 2025-04-11)
# 📁 Saved: S-Curve_Data/ASTRAL.NS_yearly_analysis.csv
# 📥 Processing ASTRAMICRO.NS from 2004-11-01...
# ✅ Data fetched for ASTRAMICRO.NS (2004-11-01 - 2025-04-11)
# 📁 Saved: S-Curve_Data/ASTRAMICRO.NS_yearly_analysis.csv
# 📥 Processing ASTRAZEN.NS from 2001-05-04...
# ✅ Data fetched for ASTRAZEN.NS (2002-07-01 - 2025-04-11)
# 📁 Saved: S-Curve_Data/ASTRAZEN.NS_yearly_analysis.csv
# 📥 Processing ASTRON.NS from 2017-12-29...
# ✅ Data fetched for ASTRON.NS (2017-12-29 - 2025-04-11)
# ⚠️ Error processing ASTRON.NS: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# 📥 Processing ATGL.NS from 2018-11-05...
# ✅ Data fetched for ATGL.NS (2018-11-05 - 2025-04-11)
# 📁 Saved: S-Curve_Data/ATGL.NS_yearly_analysis.csv
# 📥 Processing ATLANTAA.NS from 2006-09-25...
# ✅ Data fetched for ATLANTAA.NS (2006-09-25 - 2025-04-11)
# 📁 Saved: S-Curve_Data/ATLANTAA.NS_yearly_analysis.csv
# 🌍 Taking a longer break to avoid rate limits...
# 📥 Processing ATLASCYCLE.NS from 1996-10-23...
# ✅ Data fetched for ATLASCYCLE.NS (2002-07-01 - 2025-04-11)
# 📁 Saved: S-Curve_Data/ATLASCYCLE.NS_yearly_analysis.csv
# 📥 Processing ATUL.NS from 1998-05-06...
# ✅ Data fetched for ATUL.NS (2002-07-01 - 2025-04-11)
# 📁 Saved: S-Curve_Data/ATUL.NS_yearly_analysis.csv
# 📥 Processing ATULAUTO.NS from 2013-06-26...
# ✅ Data fetched for ATULAUTO.NS (2013-06-26 - 2025-04-11)
# 📁 Saved: S-Curve_Data/ATULAUTO.NS_yearly_analysis.csv
# 📥 Processing AUBANK.NS from 2017-07-10...
# ✅ Data fetched for AUBANK.NS (2017-07-11 - 2025-04-11)
# 📁 Saved: S-Curve_Data/AUBANK.NS_yearly_analysis.csv
# 📥 Processing AURIONPRO.NS from 2005-10-25...
# ✅ Data fetched for AURIONPRO.NS (2005-10-25 - 2025-04-11)
# 📁 Saved: S-Curve_Data/AURIONPRO.NS_yearly_analysis.csv
# 📥 Processing AUROPHARMA.NS from 2000-07-19...
# ✅ Data fetched for AUROPHARMA.NS (2000-07-19 - 2025-04-11)
# 📁 Saved: S-Curve_Data/AUROPHARMA.NS_yearly_analysis.csv
# 📥 Processing AURUM.NS from 2015-08-19...
# ✅ Data fetched for AURUM.NS (2015-08-19 - 2025-04-11)
# 📁 Saved: S-Curve_Data/AURUM.NS_yearly_analysis.csv
# 📥 Processing AUSOMENT.NS from 1996-04-17...
# ✅ Data fetched for AUSOMENT.NS (2002-07-18 - 2025-04-11)
# 📁 Saved: S-Curve_Data/AUSOMENT.NS_yearly_analysis.csv
# 📥 Processing AUTOAXLES.NS from 2003-05-29...
# ✅ Data fetched for AUTOAXLES.NS (2003-05-29 - 2025-04-11)
# 📁 Saved: S-Curve_Data/AUTOAXLES.NS_yearly_analysis.csv
# 📥 Processing AUTOIND.NS from 2007-01-31...
# ✅ Data fetched for AUTOIND.NS (2007-01-31 - 2025-04-11)
# 📁 Saved: S-Curve_Data/AUTOIND.NS_yearly_analysis.csv
# 🌍 Taking a longer break to avoid rate limits...
# 📥 Processing AVADHSUGAR.NS from 2017-07-28...
# ✅ Data fetched for AVADHSUGAR.NS (2017-08-02 - 2025-04-11)
# 📁 Saved: S-Curve_Data/AVADHSUGAR.NS_yearly_analysis.csv
# 📥 Processing AVANTIFEED.NS from 2015-04-15...
# ✅ Data fetched for AVANTIFEED.NS (2015-04-15 - 2025-04-11)
# 📁 Saved: S-Curve_Data/AVANTIFEED.NS_yearly_analysis.csv
# 📥 Processing AVTNPL.NS from 2007-01-10...
# ✅ Data fetched for AVTNPL.NS (2007-01-10 - 2025-04-11)
# 📁 Saved: S-Curve_Data/AVTNPL.NS_yearly_analysis.csv
# 📥 Processing AXISBANK.NS from 1998-11-16...
# ✅ Data fetched for AXISBANK.NS (1998-11-27 - 2025-04-11)
# 📁 Saved: S-Curve_Data/AXISBANK.NS_yearly_analysis.csv
# 📥 Processing AXISCADES.NS from 2000-12-21...
# ✅ Data fetched for AXISCADES.NS (2002-07-01 - 2025-04-11)
# 📁 Saved: S-Curve_Data/AXISCADES.NS_yearly_analysis.csv
# 📥 Processing AYMSYNTEX.NS from 2015-08-14...
# ✅ Data fetched for AYMSYNTEX.NS (2015-08-14 - 2025-04-11)
# 📁 Saved: S-Curve_Data/AYMSYNTEX.NS_yearly_analysis.csv
# 📥 Processing BAGFILMS.NS from 2003-10-17...
# ✅ Data fetched for BAGFILMS.NS (2003-10-17 - 2025-04-11)
# 📁 Saved: S-Curve_Data/BAGFILMS.NS_yearly_analysis.csv
# 📥 Processing BAJAJ-AUTO.NS from 2008-05-26...
# ✅ Data fetched for BAJAJ-AUTO.NS (2008-05-26 - 2025-04-11)
# 📁 Saved: S-Curve_Data/BAJAJ-AUTO.NS_yearly_analysis.csv
# 📥 Processing BAJAJCON.NS from 2010-08-18...
# ✅ Data fetched for BAJAJCON.NS (2010-08-18 - 2025-04-11)
# 📁 Saved: S-Curve_Data/BAJAJCON.NS_yearly_analysis.csv
# 📥 Processing BAJAJELEC.NS from 2007-11-02...
# ✅ Data fetched for BAJAJELEC.NS (2007-11-02 - 2025-04-11)
# 📁 Saved: S-Curve_Data/BAJAJELEC.NS_yearly_analysis.csv
# 🌍 Taking a longer break to avoid rate limits...
# 📥 Processing BAJAJFINSV.NS from 2008-05-26...
# ✅ Data fetched for BAJAJFINSV.NS (2008-05-26 - 2025-04-11)
# 📁 Saved: S-Curve_Data/BAJAJFINSV.NS_yearly_analysis.csv
# 📥 Processing BAJAJHIND.NS from 1995-05-10...
# ✅ Data fetched for BAJAJHIND.NS (2002-07-01 - 2025-04-11)
# 📁 Saved: S-Curve_Data/BAJAJHIND.NS_yearly_analysis.csv
# 📥 Processing BAJAJHLDNG.NS from 1995-03-15...
# ✅ Data fetched for BAJAJHLDNG.NS (2002-08-12 - 2025-04-11)
# 📁 Saved: S-Curve_Data/BAJAJHLDNG.NS_yearly_analysis.csv
# 📥 Processing BAJFINANCE.NS from 2003-04-01...
# ✅ Data fetched for BAJFINANCE.NS (2003-04-01 - 2025-04-11)
# 📁 Saved: S-Curve_Data/BAJFINANCE.NS_yearly_analysis.csv
# 📥 Processing BALAJITELE.NS from 2000-11-22...
# ✅ Data fetched for BALAJITELE.NS (2002-07-01 - 2025-04-11)
# 📁 Saved: S-Curve_Data/BALAJITELE.NS_yearly_analysis.csv
# 📥 Processing BALAMINES.NS from 2007-04-05...
# ✅ Data fetched for BALAMINES.NS (2007-04-05 - 2025-04-11)
# 📁 Saved: S-Curve_Data/BALAMINES.NS_yearly_analysis.csv
# 📥 Processing BALAXI.NS from 2015-11-30...
# ✅ Data fetched for BALAXI.NS (2015-12-01 - 2025-04-11)
# 📁 Saved: S-Curve_Data/BALAXI.NS_yearly_analysis.csv
# 📥 Processing BALKRISHNA.NS from 2015-07-28...
# ✅ Data fetched for BALKRISHNA.NS (2015-07-28 - 2025-04-11)
# 📁 Saved: S-Curve_Data/BALKRISHNA.NS_yearly_analysis.csv
# 📥 Processing BALKRISIND.NS from 2006-01-27...
# ✅ Data fetched for BALKRISIND.NS (2006-01-27 - 2025-04-11)
# 📁 Saved: S-Curve_Data/BALKRISIND.NS_yearly_analysis.csv
# 📥 Processing BALMLAWRIE.NS from 1995-07-06...
# ✅ Data fetched for BALMLAWRIE.NS (2002-07-01 - 2025-04-11)
# 📁 Saved: S-Curve_Data/BALMLAWRIE.NS_yearly_analysis.csv
# 🌍 Taking a longer break to avoid rate limits...
# 📥 Processing BALPHARMA.NS from 2006-05-08...
# ✅ Data fetched for BALPHARMA.NS (2006-05-08 - 2025-04-11)
# 📁 Saved: S-Curve_Data/BALPHARMA.NS_yearly_analysis.csv
# 📥 Processing BALRAMCHIN.NS from 1995-02-08...
# ✅ Data fetched for BALRAMCHIN.NS (2002-07-01 - 2025-04-11)
# 📁 Saved: S-Curve_Data/BALRAMCHIN.NS_yearly_analysis.csv
# 📥 Processing BANARBEADS.NS from 1995-07-07...
# ✅ Data fetched for BANARBEADS.NS (2011-12-29 - 2025-04-11)
# 📁 Saved: S-Curve_Data/BANARBEADS.NS_yearly_analysis.csv
# 📥 Processing BANARISUG.NS from 2003-05-28...
# ✅ Data fetched for BANARISUG.NS (2003-05-28 - 2025-04-11)
# 📁 Saved: S-Curve_Data/BANARISUG.NS_yearly_analysis.csv
# 📥 Processing BANCOINDIA.NS from 2006-12-22...
# ✅ Data fetched for BANCOINDIA.NS (2006-12-22 - 2025-04-11)
# 📁 Saved: S-Curve_Data/BANCOINDIA.NS_yearly_analysis.csv
# 📥 Processing BANDHANBNK.NS from 2018-03-27...
# ✅ Data fetched for BANDHANBNK.NS (2018-03-27 - 2025-04-11)
# 📁 Saved: S-Curve_Data/BANDHANBNK.NS_yearly_analysis.csv
# 📥 Processing BANG.NS from 2008-02-20...
# ✅ Data fetched for BANG.NS (2008-02-20 - 2025-04-11)
# 📁 Saved: S-Curve_Data/BANG.NS_yearly_analysis.csv
# 📥 Processing BANKBARODA.NS from 1997-02-19...
# ✅ Data fetched for BANKBARODA.NS (2002-07-01 - 2025-04-11)
# 📁 Saved: S-Curve_Data/BANKBARODA.NS_yearly_analysis.csv
# 📥 Processing BANKINDIA.NS from 1997-04-30...
# ✅ Data fetched for BANKINDIA.NS (2002-07-01 - 2025-04-11)
# 📁 Saved: S-Curve_Data/BANKINDIA.NS_yearly_analysis.csv
# 📥 Processing BANSWRAS.NS from 2007-04-11...
# ✅ Data fetched for BANSWRAS.NS (2007-04-11 - 2025-04-11)
# 📁 Saved: S-Curve_Data/BANSWRAS.NS_yearly_analysis.csv
# 🌍 Taking a longer break to avoid rate limits...
# 📥 Processing BASF.NS from 1995-05-17...
# ✅ Data fetched for BASF.NS (2002-07-01 - 2025-04-11)
# 📁 Saved: S-Curve_Data/BASF.NS_yearly_analysis.csv
# 📥 Processing BASML.NS from 2005-11-14...
# ✅ Data fetched for BASML.NS (2005-11-14 - 2025-04-11)
# 📁 Saved: S-Curve_Data/BASML.NS_yearly_analysis.csv
# 📥 Processing BATAINDIA.NS from 2003-06-18...
# ✅ Data fetched for BATAINDIA.NS (2003-06-18 - 2025-04-11)
# 📁 Saved: S-Curve_Data/BATAINDIA.NS_yearly_analysis.csv
# 📥 Processing BAYERCROP.NS from 2010-01-08...
# ✅ Data fetched for BAYERCROP.NS (2010-01-08 - 2025-04-11)
# 📁 Saved: S-Curve_Data/BAYERCROP.NS_yearly_analysis.csv
# 📥 Processing BBL.NS from 2006-11-21...
# ✅ Data fetched for BBL.NS (2006-11-21 - 2025-04-11)
# 📁 Saved: S-Curve_Data/BBL.NS_yearly_analysis.csv
# 📥 Processing BBOX.NS from 2003-07-22...
# ✅ Data fetched for BBOX.NS (2003-07-22 - 2025-04-11)
# 📁 Saved: S-Curve_Data/BBOX.NS_yearly_analysis.csv
# 📥 Processing BBTC.NS from 1996-04-03...
# ✅ Data fetched for BBTC.NS (2002-07-01 - 2025-04-11)
# 📁 Saved: S-Curve_Data/BBTC.NS_yearly_analysis.csv
# 📥 Processing BDL.NS from 2018-03-23...
# ✅ Data fetched for BDL.NS (2018-03-23 - 2025-04-11)
# 📁 Saved: S-Curve_Data/BDL.NS_yearly_analysis.csv
# 📥 Processing BEARDSELL.NS from 2015-01-13...
# ✅ Data fetched for BEARDSELL.NS (2015-01-13 - 2025-04-11)
# 📁 Saved: S-Curve_Data/BEARDSELL.NS_yearly_analysis.csv
# 📥 Processing BEDMUTHA.NS from 2010-10-14...
# ✅ Data fetched for BEDMUTHA.NS (2010-10-14 - 2025-04-11)
# 📁 Saved: S-Curve_Data/BEDMUTHA.NS_yearly_analysis.csv
# 🌍 Taking a longer break to avoid rate limits...
# 📥 Processing BEL.NS from 2000-07-19...
# ✅ Data fetched for BEL.NS (2002-07-01 - 2025-04-11)
# 📁 Saved: S-Curve_Data/BEL.NS_yearly_analysis.csv
# 📥 Processing BEML.NS from 2003-11-05...
# ✅ Data fetched for BEML.NS (2003-11-05 - 2025-04-11)
# 📁 Saved: S-Curve_Data/BEML.NS_yearly_analysis.csv
# 📥 Processing BEPL.NS from 2005-03-21...
# ✅ Data fetched for BEPL.NS (2005-03-21 - 2025-04-11)
# 📁 Saved: S-Curve_Data/BEPL.NS_yearly_analysis.csv
# 📥 Processing BERGEPAINT.NS from 1999-11-24...
# ✅ Data fetched for BERGEPAINT.NS (2002-07-01 - 2025-04-11)
# 📁 Saved: S-Curve_Data/BERGEPAINT.NS_yearly_analysis.csv
# 📥 Processing BFINVEST.NS from 2011-01-14...
# ✅ Data fetched for BFINVEST.NS (2011-01-14 - 2025-04-11)
# 📁 Saved: S-Curve_Data/BFINVEST.NS_yearly_analysis.csv
# 📥 Processing BFUTILITIE.NS from 2007-05-03...
# ✅ Data fetched for BFUTILITIE.NS (2007-05-03 - 2025-04-11)
# 📁 Saved: S-Curve_Data/BFUTILITIE.NS_yearly_analysis.csv
# 📥 Processing BGRENERGY.NS from 2008-01-03...
# ✅ Data fetched for BGRENERGY.NS (2008-01-03 - 2025-04-11)
# 📁 Saved: S-Curve_Data/BGRENERGY.NS_yearly_analysis.csv
# 📥 Processing BHAGERIA.NS from 2016-03-02...
# ✅ Data fetched for BHAGERIA.NS (2016-03-02 - 2025-04-11)
# 📁 Saved: S-Curve_Data/BHAGERIA.NS_yearly_analysis.csv
# 📥 Processing BHAGYANGR.NS from 2017-05-17...
# ✅ Data fetched for BHAGYANGR.NS (2017-05-17 - 2025-04-11)
# 📁 Saved: S-Curve_Data/BHAGYANGR.NS_yearly_analysis.csv
# 📥 Processing BHANDARI.NS from 2017-01-30...
# ✅ Data fetched for BHANDARI.NS (2017-01-30 - 2025-04-11)
# 📁 Saved: S-Curve_Data/BHANDARI.NS_yearly_analysis.csv
# 🌍 Taking a longer break to avoid rate limits...
# 📥 Processing BHARATFORG.NS from 2003-04-04...
# ✅ Data fetched for BHARATFORG.NS (2003-04-04 - 2025-04-11)
# 📁 Saved: S-Curve_Data/BHARATFORG.NS_yearly_analysis.csv
# 📥 Processing BHARATGEAR.NS from 1996-04-03...
# ✅ Data fetched for BHARATGEAR.NS (2002-07-01 - 2025-04-11)
# 📁 Saved: S-Curve_Data/BHARATGEAR.NS_yearly_analysis.csv
# 📥 Processing BHARATRAS.NS from 1995-10-11...
# ✅ Data fetched for BHARATRAS.NS (2002-07-01 - 2025-04-11)
# 📁 Saved: S-Curve_Data/BHARATRAS.NS_yearly_analysis.csv
# 📥 Processing BHARATWIRE.NS from 2016-04-01...
# ✅ Data fetched for BHARATWIRE.NS (2016-04-01 - 2025-04-11)
# 📁 Saved: S-Curve_Data/BHARATWIRE.NS_yearly_analysis.csv
# 📥 Processing BHARTIARTL.NS from 2002-02-15...
# ✅ Data fetched for BHARTIARTL.NS (2002-07-01 - 2025-04-11)
# 📁 Saved: S-Curve_Data/BHARTIARTL.NS_yearly_analysis.csv
# 📥 Processing BHEL.NS from 2003-11-11...
# ✅ Data fetched for BHEL.NS (2003-11-11 - 2025-04-11)
# 📁 Saved: S-Curve_Data/BHEL.NS_yearly_analysis.csv
# 📥 Processing BIGBLOC.NS from 2016-09-02...
# ✅ Data fetched for BIGBLOC.NS (2016-09-02 - 2025-04-11)
# 📁 Saved: S-Curve_Data/BIGBLOC.NS_yearly_analysis.csv
# 📥 Processing BIL.NS from 2000-04-12...
# ✅ Data fetched for BIL.NS (2002-07-01 - 2025-04-11)
# 📁 Saved: S-Curve_Data/BIL.NS_yearly_analysis.csv
# 📥 Processing BINANIIND.NS from 2006-09-27...
# ✅ Data fetched for BINANIIND.NS (2006-09-27 - 2025-04-11)
# 📁 Saved: S-Curve_Data/BINANIIND.NS_yearly_analysis.csv
# 📥 Processing BIOCON.NS from 2004-04-07...
# ✅ Data fetched for BIOCON.NS (2004-04-07 - 2025-04-11)
# 📁 Saved: S-Curve_Data/BIOCON.NS_yearly_analysis.csv
# 🌍 Taking a longer break to avoid rate limits...
# 📥 Processing BIOFILCHEM.NS from 1996-06-12...
# ✅ Data fetched for BIOFILCHEM.NS (2017-07-27 - 2025-04-11)
# 📁 Saved: S-Curve_Data/BIOFILCHEM.NS_yearly_analysis.csv
# 📥 Processing BIRLACABLE.NS from 1995-12-06...
# ✅ Data fetched for BIRLACABLE.NS (2002-07-01 - 2025-04-11)
# 📁 Saved: S-Curve_Data/BIRLACABLE.NS_yearly_analysis.csv
# 📥 Processing BIRLACORPN.NS from 1995-04-12...
# ✅ Data fetched for BIRLACORPN.NS (2002-07-01 - 2025-04-11)
# 📁 Saved: S-Curve_Data/BIRLACORPN.NS_yearly_analysis.csv
# 📥 Processing BIRLAMONEY.NS from 2008-02-07...
# ✅ Data fetched for BIRLAMONEY.NS (2008-02-07 - 2025-04-11)
# 📁 Saved: S-Curve_Data/BIRLAMONEY.NS_yearly_analysis.csv
# 📥 Processing BLBLIMITED.NS from 2000-05-31...
# ✅ Data fetched for BLBLIMITED.NS (2002-08-12 - 2025-04-11)
# 📁 Saved: S-Curve_Data/BLBLIMITED.NS_yearly_analysis.csv
# 📥 Processing BLISSGVS.NS from 2010-07-26...
# ✅ Data fetched for BLISSGVS.NS (2010-07-26 - 2025-04-11)
# 📁 Saved: S-Curve_Data/BLISSGVS.NS_yearly_analysis.csv
# 📥 Processing BLKASHYAP.NS from 2006-03-17...
# ✅ Data fetched for BLKASHYAP.NS (2006-03-17 - 2025-04-11)
# 📁 Saved: S-Curve_Data/BLKASHYAP.NS_yearly_analysis.csv
# 📥 Processing BLS.NS from 2016-06-14...
# ✅ Data fetched for BLS.NS (2016-06-15 - 2025-04-11)
# 📁 Saved: S-Curve_Data/BLS.NS_yearly_analysis.csv
# 📥 Processing BLUECHIP.NS from 1997-03-12...
# ✅ Data fetched for BLUECHIP.NS (2002-07-01 - 2025-04-11)
# 📁 Saved: S-Curve_Data/BLUECHIP.NS_yearly_analysis.csv
# 📥 Processing BLUECOAST.NS from 2000-02-16...
# ✅ Data fetched for BLUECOAST.NS (2000-02-16 - 2025-04-11)
# 📁 Saved: S-Curve_Data/BLUECOAST.NS_yearly_analysis.csv
# 🌍 Taking a longer break to avoid rate limits...
# 📥 Processing BLUEDART.NS from 2002-12-12...
# ✅ Data fetched for BLUEDART.NS (2002-12-12 - 2025-04-11)
# 📁 Saved: S-Curve_Data/BLUEDART.NS_yearly_analysis.csv
# 📥 Processing BLUESTARCO.NS from 2000-06-15...
# ✅ Data fetched for BLUESTARCO.NS (2002-07-01 - 2025-04-11)
# 📁 Saved: S-Curve_Data/BLUESTARCO.NS_yearly_analysis.csv
# 📥 Processing BODALCHEM.NS from 2011-08-22...
# ✅ Data fetched for BODALCHEM.NS (2011-08-22 - 2025-04-11)
# 📁 Saved: S-Curve_Data/BODALCHEM.NS_yearly_analysis.csv
# 📥 Processing BOMDYEING.NS from 1995-04-26...
# ✅ Data fetched for BOMDYEING.NS (1996-01-01 - 2025-04-11)
# 📁 Saved: S-Curve_Data/BOMDYEING.NS_yearly_analysis.csv
# 📥 Processing BORORENEW.NS from 2018-05-25...
# ✅ Data fetched for BORORENEW.NS (2018-05-25 - 2025-04-11)
# 📁 Saved: S-Curve_Data/BORORENEW.NS_yearly_analysis.csv
# 📥 Processing BOSCHLTD.NS from 2003-05-12...
# ✅ Data fetched for BOSCHLTD.NS (2003-05-12 - 2025-04-11)
# 📁 Saved: S-Curve_Data/BOSCHLTD.NS_yearly_analysis.csv
# 📥 Processing BPCL.NS from 1995-09-13...
# ✅ Data fetched for BPCL.NS (1996-01-02 - 2025-04-11)
# 📁 Saved: S-Curve_Data/BPCL.NS_yearly_analysis.csv
# 📥 Processing BPL.NS from 1995-06-14...
# ✅ Data fetched for BPL.NS (2002-07-01 - 2025-04-11)
# 📁 Saved: S-Curve_Data/BPL.NS_yearly_analysis.csv
# 📥 Processing BRIGADE.NS from 2007-12-31...
# ✅ Data fetched for BRIGADE.NS (2007-12-31 - 2025-04-11)
# ⚠️ Error processing BRIGADE.NS: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# 📥 Processing BRITANNIA.NS from 1998-11-05...
# ✅ Data fetched for BRITANNIA.NS (1998-11-05 - 2025-04-11)
# 📁 Saved: S-Curve_Data/BRITANNIA.NS_yearly_analysis.csv
# 🌍 Taking a longer break to avoid rate limits...
# 📥 Processing BRNL.NS from 2017-09-18...
# ✅ Data fetched for BRNL.NS (2017-09-18 - 2025-04-11)
# 📁 Saved: S-Curve_Data/BRNL.NS_yearly_analysis.csv
# 📥 Processing BROOKS.NS from 2011-09-05...
# ✅ Data fetched for BROOKS.NS (2011-09-05 - 2025-04-11)
# 📁 Saved: S-Curve_Data/BROOKS.NS_yearly_analysis.csv
# 📥 Processing BSE.NS from 2017-02-03...
# ✅ Data fetched for BSE.NS (2017-02-03 - 2025-04-11)
# 📁 Saved: S-Curve_Data/BSE.NS_yearly_analysis.csv
# 📥 Processing BSL.NS from 1995-07-27...
# ✅ Data fetched for BSL.NS (2002-07-01 - 2025-04-11)
# 📁 Saved: S-Curve_Data/BSL.NS_yearly_analysis.csv
# 📥 Processing BSOFT.NS from 1999-11-24...
# ✅ Data fetched for BSOFT.NS (2002-07-01 - 2025-04-11)
# 📁 Saved: S-Curve_Data/BSOFT.NS_yearly_analysis.csv
# 📥 Processing BUTTERFLY.NS from 2014-04-28...
# ✅ Data fetched for BUTTERFLY.NS (2014-04-28 - 2025-04-11)
# 📁 Saved: S-Curve_Data/BUTTERFLY.NS_yearly_analysis.csv
# 📥 Processing BVCL.NS from 2007-11-23...
# ✅ Data fetched for BVCL.NS (2007-11-23 - 2025-04-11)
# 📁 Saved: S-Curve_Data/BVCL.NS_yearly_analysis.csv
# 📥 Processing BYKE.NS from 2015-04-15...
# ✅ Data fetched for BYKE.NS (2015-04-15 - 2025-04-11)
# 📁 Saved: S-Curve_Data/BYKE.NS_yearly_analysis.csv
# 📥 Processing CALSOFT.NS from 2000-06-28...
# ✅ Data fetched for CALSOFT.NS (2002-07-01 - 2025-04-11)
# 📁 Saved: S-Curve_Data/CALSOFT.NS_yearly_analysis.csv
# 📥 Processing CAMLINFINE.NS from 2015-01-20...
# ✅ Data fetched for CAMLINFINE.NS (2015-01-20 - 2025-04-11)
# 📁 Saved: S-Curve_Data/CAMLINFINE.NS_yearly_analysis.csv
# 🌍 Taking a longer break to avoid rate limits...
# 📥 Processing CANBK.NS from 2002-12-23...
# ✅ Data fetched for CANBK.NS (2002-12-23 - 2025-04-11)
# 📁 Saved: S-Curve_Data/CANBK.NS_yearly_analysis.csv
# 📥 Processing CANFINHOME.NS from 1995-05-10...
# ✅ Data fetched for CANFINHOME.NS (2002-07-01 - 2025-04-11)
# 📁 Saved: S-Curve_Data/CANFINHOME.NS_yearly_analysis.csv
# 📥 Processing CANTABIL.NS from 2010-10-12...
# ✅ Data fetched for CANTABIL.NS (2010-10-12 - 2025-04-11)
# 📁 Saved: S-Curve_Data/CANTABIL.NS_yearly_analysis.csv
# 📥 Processing CAPACITE.NS from 2017-09-25...
# ✅ Data fetched for CAPACITE.NS (2017-09-25 - 2025-04-11)
# 📁 Saved: S-Curve_Data/CAPACITE.NS_yearly_analysis.csv
# 📥 Processing CAPLIPOINT.NS from 2014-06-23...
# ✅ Data fetched for CAPLIPOINT.NS (2014-06-23 - 2025-04-11)
# 📁 Saved: S-Curve_Data/CAPLIPOINT.NS_yearly_analysis.csv
# 📥 Processing CAPTRUST.NS from 2017-01-16...
# ✅ Data fetched for CAPTRUST.NS (2017-01-16 - 2025-04-11)
# 📁 Saved: S-Curve_Data/CAPTRUST.NS_yearly_analysis.csv
# 📥 Processing CARBORUNIV.NS from 1996-04-03...
# ✅ Data fetched for CARBORUNIV.NS (2002-07-01 - 2025-04-11)
# 📁 Saved: S-Curve_Data/CARBORUNIV.NS_yearly_analysis.csv
# 📥 Processing CARERATING.NS from 2012-12-26...
# ✅ Data fetched for CARERATING.NS (2012-12-26 - 2025-04-11)
# 📁 Saved: S-Curve_Data/CARERATING.NS_yearly_analysis.csv
# 📥 Processing CASTROLIND.NS from 2014-03-14...
# ✅ Data fetched for CASTROLIND.NS (2014-03-14 - 2025-04-11)
# 📁 Saved: S-Curve_Data/CASTROLIND.NS_yearly_analysis.csv
# 📥 Processing CCCL.NS from 2007-10-15...
# ✅ Data fetched for CCCL.NS (2007-10-15 - 2025-04-11)
# 📁 Saved: S-Curve_Data/CCCL.NS_yearly_analysis.csv
# 🌍 Taking a longer break to avoid rate limits...
# 📥 Processing CCHHL.NS from 2015-02-03...
# ✅ Data fetched for CCHHL.NS (2015-02-03 - 2025-04-11)
# 📁 Saved: S-Curve_Data/CCHHL.NS_yearly_analysis.csv
# 📥 Processing CCL.NS from 2004-06-07...
# ✅ Data fetched for CCL.NS (2004-06-07 - 2025-04-11)
# 📁 Saved: S-Curve_Data/CCL.NS_yearly_analysis.csv
# 📥 Processing CDSL.NS from 2017-06-30...
# ✅ Data fetched for CDSL.NS (2017-06-30 - 2025-04-11)
# 📁 Saved: S-Curve_Data/CDSL.NS_yearly_analysis.csv
# 📥 Processing CEATLTD.NS from 2008-02-01...
# ✅ Data fetched for CEATLTD.NS (2008-02-01 - 2025-04-11)
# 📁 Saved: S-Curve_Data/CEATLTD.NS_yearly_analysis.csv
# 📥 Processing CELEBRITY.NS from 2006-01-12...
# ✅ Data fetched for CELEBRITY.NS (2006-01-12 - 2025-04-11)
# 📁 Saved: S-Curve_Data/CELEBRITY.NS_yearly_analysis.csv
# 📥 Processing CENTENKA.NS from 1995-05-10...
# ✅ Data fetched for CENTENKA.NS (1999-01-01 - 2025-04-11)
# 📁 Saved: S-Curve_Data/CENTENKA.NS_yearly_analysis.csv
# 📥 Processing CENTEXT.NS from 2004-07-20...
# ✅ Data fetched for CENTEXT.NS (2004-07-20 - 2025-04-11)
# 📁 Saved: S-Curve_Data/CENTEXT.NS_yearly_analysis.csv
# 📥 Processing CENTRALBK.NS from 2007-08-21...
# ✅ Data fetched for CENTRALBK.NS (2007-08-21 - 2025-04-11)
# 📁 Saved: S-Curve_Data/CENTRALBK.NS_yearly_analysis.csv
# 📥 Processing CENTRUM.NS from 2018-04-04...
# ✅ Data fetched for CENTRUM.NS (2018-04-04 - 2025-04-11)
# 📁 Saved: S-Curve_Data/CENTRUM.NS_yearly_analysis.csv
# 📥 Processing CENTUM.NS from 2007-10-05...
# ✅ Data fetched for CENTUM.NS (2007-10-05 - 2025-04-11)
# 📁 Saved: S-Curve_Data/CENTUM.NS_yearly_analysis.csv
# 🌍 Taking a longer break to avoid rate limits...
# 📥 Processing CENTURYPLY.NS from 2006-03-23...
# ✅ Data fetched for CENTURYPLY.NS (2006-03-23 - 2025-04-11)
# 📁 Saved: S-Curve_Data/CENTURYPLY.NS_yearly_analysis.csv
# 📥 Processing CERA.NS from 2007-11-02...
# ✅ Data fetched for CERA.NS (2007-11-02 - 2025-04-11)
# 📁 Saved: S-Curve_Data/CERA.NS_yearly_analysis.csv
# 📥 Processing CEREBRAINT.NS from 2013-06-26...
# ✅ Data fetched for CEREBRAINT.NS (2013-06-26 - 2025-04-11)
# 📁 Saved: S-Curve_Data/CEREBRAINT.NS_yearly_analysis.csv
# 📥 Processing CESC.NS from 1995-02-08...
# ✅ Data fetched for CESC.NS (2002-07-01 - 2025-04-11)
# 📁 Saved: S-Curve_Data/CESC.NS_yearly_analysis.csv
# 📥 Processing CGCL.NS from 2010-10-29...
# ✅ Data fetched for CGCL.NS (2010-10-29 - 2025-04-11)
# 📁 Saved: S-Curve_Data/CGCL.NS_yearly_analysis.csv
# 📥 Processing CGPOWER.NS from 1995-03-01...
# ✅ Data fetched for CGPOWER.NS (2002-07-01 - 2025-04-11)
# 📁 Saved: S-Curve_Data/CGPOWER.NS_yearly_analysis.csv
# 📥 Processing CHALET.NS from 2019-02-07...
# ✅ Data fetched for CHALET.NS (2019-02-07 - 2025-04-11)
# 📁 Saved: S-Curve_Data/CHALET.NS_yearly_analysis.csv
# 📥 Processing CHAMBLFERT.NS from 1995-06-14...
# ✅ Data fetched for CHAMBLFERT.NS (2002-07-01 - 2025-04-11)
# 📁 Saved: S-Curve_Data/CHAMBLFERT.NS_yearly_analysis.csv
# 📥 Processing CHEMBOND.NS from 2019-11-20...
# ✅ Data fetched for CHEMBOND.NS (2019-11-20 - 2025-04-11)
# 📁 Saved: S-Curve_Data/CHEMBOND.NS_yearly_analysis.csv
# 📥 Processing CHEMFAB.NS from 2018-04-25...
# ✅ Data fetched for CHEMFAB.NS (2018-04-25 - 2025-04-11)
# 📁 Saved: S-Curve_Data/CHEMFAB.NS_yearly_analysis.csv
# 🌍 Taking a longer break to avoid rate limits...
# 📥 Processing CHENNPETRO.NS from 2000-06-07...
# ✅ Data fetched for CHENNPETRO.NS (2002-07-01 - 2025-04-11)
# 📁 Saved: S-Curve_Data/CHENNPETRO.NS_yearly_analysis.csv
# 📥 Processing CHOLAFIN.NS from 1996-05-15...
# ✅ Data fetched for CHOLAFIN.NS (2002-07-01 - 2025-04-11)
# 📁 Saved: S-Curve_Data/CHOLAFIN.NS_yearly_analysis.csv
# 📥 Processing CHOLAHLDNG.NS from 2017-09-25...
# ✅ Data fetched for CHOLAHLDNG.NS (2017-09-25 - 2025-04-11)
# 📁 Saved: S-Curve_Data/CHOLAHLDNG.NS_yearly_analysis.csv
# 📥 Processing CIEINDIA.NS from 2007-08-30...
# ✅ Data fetched for CIEINDIA.NS (2007-08-30 - 2025-04-11)
# 📁 Saved: S-Curve_Data/CIEINDIA.NS_yearly_analysis.csv
# 📥 Processing CIGNITITEC.NS from 2014-10-13...
# ✅ Data fetched for CIGNITITEC.NS (2014-10-13 - 2025-04-11)
# 📁 Saved: S-Curve_Data/CIGNITITEC.NS_yearly_analysis.csv
# 📥 Processing CINELINE.NS from 2012-06-13...
# ✅ Data fetched for CINELINE.NS (2012-06-13 - 2025-04-11)
# 📁 Saved: S-Curve_Data/CINELINE.NS_yearly_analysis.csv
# 📥 Processing CINEVISTA.NS from 2000-05-02...
# ✅ Data fetched for CINEVISTA.NS (2002-07-01 - 2025-04-11)
# 📁 Saved: S-Curve_Data/CINEVISTA.NS_yearly_analysis.csv
# 📥 Processing CIPLA.NS from 1995-02-08...
# ✅ Data fetched for CIPLA.NS (1996-01-01 - 2025-04-11)
# 📁 Saved: S-Curve_Data/CIPLA.NS_yearly_analysis.csv
# 📥 Processing CLEDUCATE.NS from 2017-03-31...
# ✅ Data fetched for CLEDUCATE.NS (2017-04-03 - 2025-04-11)
# 📁 Saved: S-Curve_Data/CLEDUCATE.NS_yearly_analysis.csv
# 📥 Processing COALINDIA.NS from 2010-11-04...
# ✅ Data fetched for COALINDIA.NS (2010-11-04 - 2025-04-11)
# 📁 Saved: S-Curve_Data/COALINDIA.NS_yearly_analysis.csv
# 🌍 Taking a longer break to avoid rate limits...
# 📥 Processing COCHINSHIP.NS from 2017-08-11...
# ✅ Data fetched for COCHINSHIP.NS (2017-08-11 - 2025-04-11)
# 📁 Saved: S-Curve_Data/COCHINSHIP.NS_yearly_analysis.csv
# 📥 Processing COFFEEDAY.NS from 2015-11-02...
# ✅ Data fetched for COFFEEDAY.NS (2015-11-02 - 2025-04-11)
# 📁 Saved: S-Curve_Data/COFFEEDAY.NS_yearly_analysis.csv
# 📥 Processing COFORGE.NS from 2004-08-30...
# ✅ Data fetched for COFORGE.NS (2004-08-30 - 2025-04-11)
# 📁 Saved: S-Curve_Data/COFORGE.NS_yearly_analysis.csv
# 📥 Processing COLPAL.NS from 2007-12-17...
# ✅ Data fetched for COLPAL.NS (2007-12-17 - 2025-04-11)
# 📁 Saved: S-Curve_Data/COLPAL.NS_yearly_analysis.csv
# 📥 Processing COMPINFO.NS from 2016-07-07...
# ✅ Data fetched for COMPINFO.NS (2016-07-07 - 2025-04-11)
# 📁 Saved: S-Curve_Data/COMPINFO.NS_yearly_analysis.csv
# 📥 Processing COMPUSOFT.NS from 2012-03-02...
# ✅ Data fetched for COMPUSOFT.NS (2012-03-02 - 2025-04-11)
# 📁 Saved: S-Curve_Data/COMPUSOFT.NS_yearly_analysis.csv
# 📥 Processing CONCOR.NS from 1997-05-07...
# ✅ Data fetched for CONCOR.NS (2002-07-01 - 2025-04-11)
# 📁 Saved: S-Curve_Data/CONCOR.NS_yearly_analysis.csv
# 📥 Processing CONFIPET.NS from 2019-06-13...
# ✅ Data fetched for CONFIPET.NS (2020-10-23 - 2025-04-11)
# 📁 Saved: S-Curve_Data/CONFIPET.NS_yearly_analysis.csv
# 📥 Processing CONSOFINVT.NS from 2005-03-29...
# ✅ Data fetched for CONSOFINVT.NS (2005-03-29 - 2025-04-11)
# 📁 Saved: S-Curve_Data/CONSOFINVT.NS_yearly_analysis.csv
# 📥 Processing CONTROLPR.NS from 2016-06-24...
# ✅ Data fetched for CONTROLPR.NS (2016-06-24 - 2025-04-11)
# 📁 Saved: S-Curve_Data/CONTROLPR.NS_yearly_analysis.csv
# 🌍 Taking a longer break to avoid rate limits...
# 📥 Processing CORALFINAC.NS from 1996-03-25...
# ✅ Data fetched for CORALFINAC.NS (2017-03-29 - 2025-04-11)
# 📁 Saved: S-Curve_Data/CORALFINAC.NS_yearly_analysis.csv
# 📥 Processing CORDSCABLE.NS from 2008-02-13...
# ✅ Data fetched for CORDSCABLE.NS (2008-02-13 - 2025-04-11)
# 📁 Saved: S-Curve_Data/CORDSCABLE.NS_yearly_analysis.csv
# 📥 Processing COROMANDEL.NS from 1995-05-31...
# ✅ Data fetched for COROMANDEL.NS (2002-08-12 - 2025-04-11)
# 📁 Saved: S-Curve_Data/COROMANDEL.NS_yearly_analysis.csv
# 📥 Processing COSMOFIRST.NS from 1995-05-25...
# ✅ Data fetched for COSMOFIRST.NS (1999-01-01 - 2025-04-11)
# 📁 Saved: S-Curve_Data/COSMOFIRST.NS_yearly_analysis.csv
# 📥 Processing COUNCODOS.NS from 2009-01-22...
# ✅ Data fetched for COUNCODOS.NS (2009-01-22 - 2025-04-11)
# 📁 Saved: S-Curve_Data/COUNCODOS.NS_yearly_analysis.csv
# 📥 Processing CPCAP.NS from 2010-10-06...
# ✅ Data fetched for CPCAP.NS (2025-03-11 - 2025-04-11)
# 📁 Saved: S-Curve_Data/CPCAP.NS_yearly_analysis.csv
# 📥 Processing CREATIVE.NS from 2019-08-05...
# ✅ Data fetched for CREATIVE.NS (2019-08-05 - 2025-04-11)
# 📁 Saved: S-Curve_Data/CREATIVE.NS_yearly_analysis.csv
# 📥 Processing CREATIVEYE.NS from 2000-12-20...
# ✅ Data fetched for CREATIVEYE.NS (2002-07-01 - 2025-04-11)
# 📁 Saved: S-Curve_Data/CREATIVEYE.NS_yearly_analysis.csv
# 📥 Processing CREDITACC.NS from 2018-08-23...
# ✅ Data fetched for CREDITACC.NS (2018-08-23 - 2025-04-11)
# 📁 Saved: S-Curve_Data/CREDITACC.NS_yearly_analysis.csv
# 📥 Processing CREST.NS from 2006-12-27...
# ✅ Data fetched for CREST.NS (2006-12-27 - 2025-04-11)
# 📁 Saved: S-Curve_Data/CREST.NS_yearly_analysis.csv
# 🌍 Taking a longer break to avoid rate limits...
# 📥 Processing CRISIL.NS from 1995-06-28...
# ✅ Data fetched for CRISIL.NS (2002-07-01 - 2025-04-11)
# 📁 Saved: S-Curve_Data/CRISIL.NS_yearly_analysis.csv
# 📥 Processing CROMPTON.NS from 2016-05-13...
# ✅ Data fetched for CROMPTON.NS (2016-05-13 - 2025-04-11)
# 📁 Saved: S-Curve_Data/CROMPTON.NS_yearly_analysis.csv
# 📥 Processing CSBBANK.NS from 2019-12-04...
# ✅ Data fetched for CSBBANK.NS (2019-12-04 - 2025-04-11)
# 📁 Saved: S-Curve_Data/CSBBANK.NS_yearly_analysis.csv
# 📥 Processing CTE.NS from 2007-02-07...
# ✅ Data fetched for CTE.NS (2007-02-07 - 2025-04-11)
# 📁 Saved: S-Curve_Data/CTE.NS_yearly_analysis.csv
# 📥 Processing CUB.NS from 1998-08-25...
# ✅ Data fetched for CUB.NS (2002-07-01 - 2025-04-11)
# 📁 Saved: S-Curve_Data/CUB.NS_yearly_analysis.csv
# 📥 Processing CUBEXTUB.NS from 1996-04-24...
# ✅ Data fetched for CUBEXTUB.NS (2008-01-25 - 2025-04-11)
# 📁 Saved: S-Curve_Data/CUBEXTUB.NS_yearly_analysis.csv
# 📥 Processing CUMMINSIND.NS from 1995-03-29...
# ✅ Data fetched for CUMMINSIND.NS (2002-07-01 - 2025-04-11)
# 📁 Saved: S-Curve_Data/CUMMINSIND.NS_yearly_analysis.csv
# 📥 Processing CUPID.NS from 2016-09-16...
# ✅ Data fetched for CUPID.NS (2016-09-16 - 2025-04-11)
# 📁 Saved: S-Curve_Data/CUPID.NS_yearly_analysis.csv
# 📥 Processing CYBERMEDIA.NS from 2005-06-10...
# ✅ Data fetched for CYBERMEDIA.NS (2005-06-10 - 2025-04-11)
# 📁 Saved: S-Curve_Data/CYBERMEDIA.NS_yearly_analysis.csv
# 📥 Processing CYBERTECH.NS from 1999-01-27...
# ✅ Data fetched for CYBERTECH.NS (2002-07-01 - 2025-04-11)
# 📁 Saved: S-Curve_Data/CYBERTECH.NS_yearly_analysis.csv
# 🌍 Taking a longer break to avoid rate limits...
# 📥 Processing CYIENT.NS from 1998-09-30...
# ✅ Data fetched for CYIENT.NS (2006-07-28 - 2025-04-11)
# 📁 Saved: S-Curve_Data/CYIENT.NS_yearly_analysis.csv
# 📥 Processing DABUR.NS from 1999-04-28...
# ✅ Data fetched for DABUR.NS (2002-07-01 - 2025-04-11)
# 📁 Saved: S-Curve_Data/DABUR.NS_yearly_analysis.csv
# 📥 Processing DALBHARAT.NS from 2019-01-22...
# ✅ Data fetched for DALBHARAT.NS (2019-01-22 - 2025-04-11)
# 📁 Saved: S-Curve_Data/DALBHARAT.NS_yearly_analysis.csv
# 📥 Processing DALMIASUG.NS from 1996-01-17...
# ✅ Data fetched for DALMIASUG.NS (2002-07-01 - 2025-04-11)
# 📁 Saved: S-Curve_Data/DALMIASUG.NS_yearly_analysis.csv
# 📥 Processing DAMODARIND.NS from 2016-07-04...
# ✅ Data fetched for DAMODARIND.NS (2016-07-04 - 2025-04-11)
# 📁 Saved: S-Curve_Data/DAMODARIND.NS_yearly_analysis.csv
# 📥 Processing DATAMATICS.NS from 2004-05-07...
# ✅ Data fetched for DATAMATICS.NS (2004-05-07 - 2025-04-11)
# 📁 Saved: S-Curve_Data/DATAMATICS.NS_yearly_analysis.csv
# 📥 Processing DBCORP.NS from 2010-01-06...
# ✅ Data fetched for DBCORP.NS (2010-01-06 - 2025-04-11)
# 📁 Saved: S-Curve_Data/DBCORP.NS_yearly_analysis.csv
# 📥 Processing DBL.NS from 2016-08-11...
# ✅ Data fetched for DBL.NS (2016-08-11 - 2025-04-11)
# 📁 Saved: S-Curve_Data/DBL.NS_yearly_analysis.csv
# 📥 Processing DBREALTY.NS from 2010-02-24...
# ✅ Data fetched for DBREALTY.NS (2010-02-24 - 2025-04-11)
# 📁 Saved: S-Curve_Data/DBREALTY.NS_yearly_analysis.csv
# 📥 Processing DBSTOCKBRO.NS from 2012-02-29...
# ✅ Data fetched for DBSTOCKBRO.NS (2012-02-29 - 2025-04-11)
# 📁 Saved: S-Curve_Data/DBSTOCKBRO.NS_yearly_analysis.csv
# 🌍 Taking a longer break to avoid rate limits...
# 📥 Processing DCAL.NS from 2017-09-21...
# ✅ Data fetched for DCAL.NS (2017-09-21 - 2025-04-11)
# ...
# 📥 Processing UGARSUGAR.NS from 2010-08-23...
# ✅ Data fetched for UGARSUGAR.NS (2010-08-23 - 2025-04-11)
# 📁 Saved: S-Curve_Data/UGARSUGAR.NS_yearly_analysis.csv
# 📥 Processing UJJIVANSFB.NS from 2019-12-12...
# ✅ Data fetched for UJJIVANSFB.NS (2019-12-12 - 2025-04-11)
# 📁 Saved: S-Curve_Data/UJJIVANSFB.NS_yearly_analysis.csv
# 🌍 Taking a longer break to avoid rate limits...
# 📥 Processing ULTRACEMCO.NS from 2004-08-24...
# ✅ Data fetched for ULTRACEMCO.NS (2004-08-24 - 2025-04-11)
# 📁 Saved: S-Curve_Data/ULTRACEMCO.NS_yearly_analysis.csv
# 📥 Processing UMANGDAIRY.NS from 2015-12-02...
# ✅ Data fetched for UMANGDAIRY.NS (2015-12-02 - 2025-04-11)
# 📁 Saved: S-Curve_Data/UMANGDAIRY.NS_yearly_analysis.csv
# 📥 Processing UMESLTD.NS from 2010-07-12...
# ✅ Data fetched for UMESLTD.NS (2010-07-12 - 2025-04-11)
# 📁 Saved: S-Curve_Data/UMESLTD.NS_yearly_analysis.csv
# 📥 Processing UNICHEMLAB.NS from 2001-02-07...
# ✅ Data fetched for UNICHEMLAB.NS (2002-07-01 - 2025-04-11)
# 📁 Saved: S-Curve_Data/UNICHEMLAB.NS_yearly_analysis.csv
# 📥 Processing UNIENTER.NS from 2004-01-23...
# ✅ Data fetched for UNIENTER.NS (2004-01-23 - 2025-04-11)
# 📁 Saved: S-Curve_Data/UNIENTER.NS_yearly_analysis.csv
# 📥 Processing UNIONBANK.NS from 2002-09-24...
# ✅ Data fetched for UNIONBANK.NS (2002-09-24 - 2025-04-11)
# 📁 Saved: S-Curve_Data/UNIONBANK.NS_yearly_analysis.csv
# 📥 Processing UNITDSPR.NS from 2001-09-27...
# ✅ Data fetched for UNITDSPR.NS (2024-05-30 - 2025-04-11)
# 📁 Saved: S-Curve_Data/UNITDSPR.NS_yearly_analysis.csv
# 📥 Processing UNITECH.NS from 1999-09-08...
# ✅ Data fetched for UNITECH.NS (2002-07-01 - 2025-04-11)
# 📁 Saved: S-Curve_Data/UNITECH.NS_yearly_analysis.csv
# 📥 Processing UNITEDTEA.NS from 2015-01-28...
# ✅ Data fetched for UNITEDTEA.NS (2015-01-28 - 2025-04-11)
# 📁 Saved: S-Curve_Data/UNITEDTEA.NS_yearly_analysis.csv
# 📥 Processing UNIVCABLES.NS from 1995-05-17...
# ✅ Data fetched for UNIVCABLES.NS (2002-07-01 - 2025-04-11)
# 📁 Saved: S-Curve_Data/UNIVCABLES.NS_yearly_analysis.csv
# 🌍 Taking a longer break to avoid rate limits...
# 📥 Processing UNOMINDA.NS from 2007-02-02...
# ✅ Data fetched for UNOMINDA.NS (2007-02-02 - 2025-04-11)
# 📁 Saved: S-Curve_Data/UNOMINDA.NS_yearly_analysis.csv
# 📥 Processing UPL.NS from 2004-01-23...
# ✅ Data fetched for UPL.NS (2004-01-23 - 2025-04-11)
# 📁 Saved: S-Curve_Data/UPL.NS_yearly_analysis.csv
# 📥 Processing URJA.NS from 2017-03-28...
# ✅ Data fetched for URJA.NS (2017-03-28 - 2025-04-11)
# 📁 Saved: S-Curve_Data/URJA.NS_yearly_analysis.csv
# 📥 Processing USHAMART.NS from 2000-10-11...
# ✅ Data fetched for USHAMART.NS (2002-01-01 - 2025-04-11)
# 📁 Saved: S-Curve_Data/USHAMART.NS_yearly_analysis.csv
# 📥 Processing UTTAMSUGAR.NS from 2006-04-10...
# ✅ Data fetched for UTTAMSUGAR.NS (2006-04-10 - 2025-04-11)
# 📁 Saved: S-Curve_Data/UTTAMSUGAR.NS_yearly_analysis.csv
# 📥 Processing V2RETAIL.NS from 2007-07-04...
# ✅ Data fetched for V2RETAIL.NS (2007-07-04 - 2025-04-11)
# 📁 Saved: S-Curve_Data/V2RETAIL.NS_yearly_analysis.csv
# 📥 Processing VADILALIND.NS from 2011-06-15...
# ✅ Data fetched for VADILALIND.NS (2011-06-15 - 2025-04-11)
# 📁 Saved: S-Curve_Data/VADILALIND.NS_yearly_analysis.csv
# 📥 Processing VAIBHAVGBL.NS from 2004-04-05...
# ✅ Data fetched for VAIBHAVGBL.NS (2004-04-06 - 2025-04-11)
# 📁 Saved: S-Curve_Data/VAIBHAVGBL.NS_yearly_analysis.csv
# 📥 Processing VAKRANGEE.NS from 2006-04-03...
# ✅ Data fetched for VAKRANGEE.NS (2006-04-03 - 2025-04-11)
# 📁 Saved: S-Curve_Data/VAKRANGEE.NS_yearly_analysis.csv
# 📥 Processing VARDHACRLC.NS from 2003-09-30...
# ✅ Data fetched for VARDHACRLC.NS (2003-09-30 - 2025-04-11)
# 📁 Saved: S-Curve_Data/VARDHACRLC.NS_yearly_analysis.csv
# 🌍 Taking a longer break to avoid rate limits...
# 📥 Processing VARDMNPOLY.NS from 2003-05-12...
# ✅ Data fetched for VARDMNPOLY.NS (2003-05-12 - 2025-04-11)
# 📁 Saved: S-Curve_Data/VARDMNPOLY.NS_yearly_analysis.csv
# 📥 Processing VARROC.NS from 2018-07-06...
# ✅ Data fetched for VARROC.NS (2018-07-09 - 2025-04-11)
# 📁 Saved: S-Curve_Data/VARROC.NS_yearly_analysis.csv
# 📥 Processing VASCONEQ.NS from 2010-02-15...
# ✅ Data fetched for VASCONEQ.NS (2010-02-15 - 2025-04-11)
# 📁 Saved: S-Curve_Data/VASCONEQ.NS_yearly_analysis.csv
# 📥 Processing VASWANI.NS from 2011-09-20...
# ✅ Data fetched for VASWANI.NS (2011-10-24 - 2025-04-11)
# 📁 Saved: S-Curve_Data/VASWANI.NS_yearly_analysis.csv
# 📥 Processing VBL.NS from 2016-11-08...
# ✅ Data fetched for VBL.NS (2016-11-08 - 2025-04-11)
# 📁 Saved: S-Curve_Data/VBL.NS_yearly_analysis.csv
# 📥 Processing VEDL.NS from 1998-05-13...
# ✅ Data fetched for VEDL.NS (1998-05-13 - 2025-04-11)
# 📁 Saved: S-Curve_Data/VEDL.NS_yearly_analysis.csv
# 📥 Processing VEEDOL.NS from 2007-01-16...
# ✅ Data fetched for VEEDOL.NS (2007-01-16 - 2025-04-11)
# 📁 Saved: S-Curve_Data/VEEDOL.NS_yearly_analysis.csv
# 📥 Processing VENKEYS.NS from 2003-07-28...
# ✅ Data fetched for VENKEYS.NS (2003-07-28 - 2025-04-11)
# 📁 Saved: S-Curve_Data/VENKEYS.NS_yearly_analysis.csv
# 📥 Processing VENUSREM.NS from 2006-12-20...
# ✅ Data fetched for VENUSREM.NS (2006-12-20 - 2025-04-11)
# 📁 Saved: S-Curve_Data/VENUSREM.NS_yearly_analysis.csv
# 📥 Processing VESUVIUS.NS from 2002-10-04...
# ✅ Data fetched for VESUVIUS.NS (2002-10-04 - 2025-04-11)
# 📁 Saved: S-Curve_Data/VESUVIUS.NS_yearly_analysis.csv
# 🌍 Taking a longer break to avoid rate limits...
# 📥 Processing VETO.NS from 2015-04-29...
# ✅ Data fetched for VETO.NS (2015-04-29 - 2025-04-11)
# 📁 Saved: S-Curve_Data/VETO.NS_yearly_analysis.csv
# 📥 Processing VGUARD.NS from 2008-03-13...
# ✅ Data fetched for VGUARD.NS (2008-03-13 - 2025-04-11)
# 📁 Saved: S-Curve_Data/VGUARD.NS_yearly_analysis.csv
# 📥 Processing VHL.NS from 2005-06-30...
# ✅ Data fetched for VHL.NS (2005-06-30 - 2025-04-11)
# 📁 Saved: S-Curve_Data/VHL.NS_yearly_analysis.csv
# 📥 Processing VIDHIING.NS from 2016-03-02...
# ✅ Data fetched for VIDHIING.NS (2016-03-02 - 2025-04-11)
# 📁 Saved: S-Curve_Data/VIDHIING.NS_yearly_analysis.csv
# 📥 Processing VIJIFIN.NS from 2016-07-11...
# ✅ Data fetched for VIJIFIN.NS (2016-07-11 - 2025-04-11)
# 📁 Saved: S-Curve_Data/VIJIFIN.NS_yearly_analysis.csv
# 📥 Processing VIKASECO.NS from 2011-12-12...
# ✅ Data fetched for VIKASECO.NS (2011-12-12 - 2025-04-11)
# 📁 Saved: S-Curve_Data/VIKASECO.NS_yearly_analysis.csv
# 📥 Processing VIKASLIFE.NS from 2019-05-08...
# ✅ Data fetched for VIKASLIFE.NS (2019-05-08 - 2025-04-11)
# 📁 Saved: S-Curve_Data/VIKASLIFE.NS_yearly_analysis.csv
# 📥 Processing VIMTALABS.NS from 2005-12-15...
# ✅ Data fetched for VIMTALABS.NS (2005-12-15 - 2025-04-11)
# 📁 Saved: S-Curve_Data/VIMTALABS.NS_yearly_analysis.csv
# 📥 Processing VINATIORGA.NS from 2009-07-28...
# ✅ Data fetched for VINATIORGA.NS (2009-07-28 - 2025-04-11)
# 📁 Saved: S-Curve_Data/VINATIORGA.NS_yearly_analysis.csv
# 📥 Processing VINDHYATEL.NS from 1995-02-08...
# ✅ Data fetched for VINDHYATEL.NS (2002-07-01 - 2025-04-11)
# 📁 Saved: S-Curve_Data/VINDHYATEL.NS_yearly_analysis.csv
# 🌍 Taking a longer break to avoid rate limits...
# 📥 Processing VINYLINDIA.NS from 2008-07-21...
# ✅ Data fetched for VINYLINDIA.NS (2008-07-21 - 2025-04-11)
# 📁 Saved: S-Curve_Data/VINYLINDIA.NS_yearly_analysis.csv
# 📥 Processing VIPCLOTHNG.NS from 2007-08-06...
# ✅ Data fetched for VIPCLOTHNG.NS (2007-08-06 - 2025-04-11)
# 📁 Saved: S-Curve_Data/VIPCLOTHNG.NS_yearly_analysis.csv
# 📥 Processing VIPIND.NS from 2005-03-02...
# ✅ Data fetched for VIPIND.NS (2005-03-02 - 2025-04-11)
# 📁 Saved: S-Curve_Data/VIPIND.NS_yearly_analysis.csv
# 📥 Processing VIPULLTD.NS from 2015-04-23...
# ✅ Data fetched for VIPULLTD.NS (2015-04-23 - 2025-04-11)
# 📁 Saved: S-Curve_Data/VIPULLTD.NS_yearly_analysis.csv
# 📥 Processing VISAKAIND.NS from 1996-08-28...
# ✅ Data fetched for VISAKAIND.NS (2002-07-01 - 2025-04-11)
# 📁 Saved: S-Curve_Data/VISAKAIND.NS_yearly_analysis.csv
# 📥 Processing VISASTEEL.NS from 2006-03-17...
# ✅ Data fetched for VISASTEEL.NS (2006-03-17 - 2025-04-11)
# 📁 Saved: S-Curve_Data/VISASTEEL.NS_yearly_analysis.csv
# 📥 Processing VISHNU.NS from 2015-03-05...
# ✅ Data fetched for VISHNU.NS (2015-03-05 - 2025-04-11)
# 📁 Saved: S-Curve_Data/VISHNU.NS_yearly_analysis.csv
# 📥 Processing VISHWARAJ.NS from 2019-10-15...
# ✅ Data fetched for VISHWARAJ.NS (2019-10-15 - 2025-04-11)
# 📁 Saved: S-Curve_Data/VISHWARAJ.NS_yearly_analysis.csv
# 📥 Processing VIVIDHA.NS from 2013-05-21...
# ✅ Data fetched for VIVIDHA.NS (2013-05-21 - 2025-04-11)
# 📁 Saved: S-Curve_Data/VIVIDHA.NS_yearly_analysis.csv
# 📥 Processing VLSFINANCE.NS from 1995-05-25...
# ✅ Data fetched for VLSFINANCE.NS (2002-06-26 - 2025-04-11)
# 📁 Saved: S-Curve_Data/VLSFINANCE.NS_yearly_analysis.csv
# 🌍 Taking a longer break to avoid rate limits...
# 📥 Processing VMART.NS from 2013-02-20...
# ✅ Data fetched for VMART.NS (2013-02-20 - 2025-04-11)
# 📁 Saved: S-Curve_Data/VMART.NS_yearly_analysis.csv
# 📥 Processing VOLTAMP.NS from 2006-09-20...
# ✅ Data fetched for VOLTAMP.NS (2006-09-20 - 2025-04-11)
# 📁 Saved: S-Curve_Data/VOLTAMP.NS_yearly_analysis.csv
# 📥 Processing VOLTAS.NS from 1995-04-12...
# ✅ Data fetched for VOLTAS.NS (2002-07-01 - 2025-04-11)
# 📁 Saved: S-Curve_Data/VOLTAS.NS_yearly_analysis.csv
# 📥 Processing VRLLOG.NS from 2015-04-30...
# ✅ Data fetched for VRLLOG.NS (2015-04-30 - 2025-04-11)
# 📁 Saved: S-Curve_Data/VRLLOG.NS_yearly_analysis.csv
# 📥 Processing VSSL.NS from 2012-05-17...
# ✅ Data fetched for VSSL.NS (2012-05-17 - 2025-04-11)
# 📁 Saved: S-Curve_Data/VSSL.NS_yearly_analysis.csv
# 📥 Processing VSTIND.NS from 2003-09-05...
# ✅ Data fetched for VSTIND.NS (2003-09-05 - 2025-04-11)
# 📁 Saved: S-Curve_Data/VSTIND.NS_yearly_analysis.csv
# 📥 Processing VSTTILLERS.NS from 2011-06-20...
# ✅ Data fetched for VSTTILLERS.NS (2011-06-20 - 2025-04-11)
# 📁 Saved: S-Curve_Data/VSTTILLERS.NS_yearly_analysis.csv
# 📥 Processing VTL.NS from 2003-01-14...
# ✅ Data fetched for VTL.NS (2003-01-14 - 2025-04-11)
# 📁 Saved: S-Curve_Data/VTL.NS_yearly_analysis.csv
# 📥 Processing WABAG.NS from 2010-10-13...
# ✅ Data fetched for WABAG.NS (2010-10-13 - 2025-04-11)
# 📁 Saved: S-Curve_Data/WABAG.NS_yearly_analysis.csv
# 📥 Processing WALCHANNAG.NS from 1996-09-18...
# ✅ Data fetched for WALCHANNAG.NS (2002-07-01 - 2025-04-11)
# 📁 Saved: S-Curve_Data/WALCHANNAG.NS_yearly_analysis.csv
# 🌍 Taking a longer break to avoid rate limits...
# 📥 Processing WANBURY.NS from 2007-01-29...
# ✅ Data fetched for WANBURY.NS (2007-01-29 - 2025-04-11)
# 📁 Saved: S-Curve_Data/WANBURY.NS_yearly_analysis.csv
# 📥 Processing WEBELSOLAR.NS from 2007-05-15...
# ✅ Data fetched for WEBELSOLAR.NS (2007-05-15 - 2025-04-11)
# 📁 Saved: S-Curve_Data/WEBELSOLAR.NS_yearly_analysis.csv
# 📥 Processing WEIZMANIND.NS from 1995-05-10...
# ✅ Data fetched for WEIZMANIND.NS (2002-07-02 - 2025-04-11)
# 📁 Saved: S-Curve_Data/WEIZMANIND.NS_yearly_analysis.csv
# 📥 Processing WELCORP.NS from 2005-05-24...
# ✅ Data fetched for WELCORP.NS (2005-05-24 - 2025-04-11)
# 📁 Saved: S-Curve_Data/WELCORP.NS_yearly_analysis.csv
# 📥 Processing WELENT.NS from 2004-11-04...
# ✅ Data fetched for WELENT.NS (2004-11-04 - 2025-04-11)
# 📁 Saved: S-Curve_Data/WELENT.NS_yearly_analysis.csv
# 📥 Processing WELINV.NS from 2010-09-20...
# ✅ Data fetched for WELINV.NS (2010-09-20 - 2025-04-11)
# 📁 Saved: S-Curve_Data/WELINV.NS_yearly_analysis.csv
# 📥 Processing WELSPUNLIV.NS from 2003-12-04...
# ✅ Data fetched for WELSPUNLIV.NS (2003-12-04 - 2025-04-11)
# 📁 Saved: S-Curve_Data/WELSPUNLIV.NS_yearly_analysis.csv
# 📥 Processing WENDT.NS from 2006-08-07...
# ✅ Data fetched for WENDT.NS (2006-08-07 - 2025-04-11)
# 📁 Saved: S-Curve_Data/WENDT.NS_yearly_analysis.csv
# 📥 Processing WHEELS.NS from 2000-04-07...
# ✅ Data fetched for WHEELS.NS (2002-07-01 - 2025-04-11)
# 📁 Saved: S-Curve_Data/WHEELS.NS_yearly_analysis.csv
# 📥 Processing WHIRLPOOL.NS from 2010-04-06...
# ✅ Data fetched for WHIRLPOOL.NS (2010-04-06 - 2025-04-11)
# 📁 Saved: S-Curve_Data/WHIRLPOOL.NS_yearly_analysis.csv
# 🌍 Taking a longer break to avoid rate limits...
# 📥 Processing WILLAMAGOR.NS from 1995-02-08...
# ✅ Data fetched for WILLAMAGOR.NS (2002-07-01 - 2025-04-11)
# 📁 Saved: S-Curve_Data/WILLAMAGOR.NS_yearly_analysis.csv
# 📥 Processing WINDMACHIN.NS from 2011-08-17...
# ✅ Data fetched for WINDMACHIN.NS (2011-08-17 - 2025-04-11)
# 📁 Saved: S-Curve_Data/WINDMACHIN.NS_yearly_analysis.csv
# 📥 Processing WINSOME.NS from 2011-08-25...
# ✅ Data fetched for WINSOME.NS (2011-08-25 - 2025-04-11)
# 📁 Saved: S-Curve_Data/WINSOME.NS_yearly_analysis.csv
# 📥 Processing WIPL.NS from 2017-04-17...
# ✅ Data fetched for WIPL.NS (2017-04-18 - 2025-04-11)
# 📁 Saved: S-Curve_Data/WIPL.NS_yearly_analysis.csv
# 📥 Processing WIPRO.NS from 1995-11-08...
# ✅ Data fetched for WIPRO.NS (1996-01-01 - 2025-04-11)
# 📁 Saved: S-Curve_Data/WIPRO.NS_yearly_analysis.csv
# 📥 Processing WOCKPHARMA.NS from 2000-02-23...
# ✅ Data fetched for WOCKPHARMA.NS (2002-07-01 - 2025-04-11)
# 📁 Saved: S-Curve_Data/WOCKPHARMA.NS_yearly_analysis.csv
# 📥 Processing WONDERLA.NS from 2014-05-09...
# ✅ Data fetched for WONDERLA.NS (2014-05-09 - 2025-04-11)
# 📁 Saved: S-Curve_Data/WONDERLA.NS_yearly_analysis.csv
# 📥 Processing WSI.NS from 2007-08-01...
# ✅ Data fetched for WSI.NS (2007-08-01 - 2025-04-11)
# 📁 Saved: S-Curve_Data/WSI.NS_yearly_analysis.csv
# 📥 Processing WSTCSTPAPR.NS from 2001-01-17...
# ✅ Data fetched for WSTCSTPAPR.NS (2002-07-01 - 2025-04-11)
# 📁 Saved: S-Curve_Data/WSTCSTPAPR.NS_yearly_analysis.csv
# 📥 Processing XCHANGING.NS from 2005-03-09...
# ✅ Data fetched for XCHANGING.NS (2005-03-09 - 2025-04-11)
# 📁 Saved: S-Curve_Data/XCHANGING.NS_yearly_analysis.csv
# 🌍 Taking a longer break to avoid rate limits...
# 📥 Processing XELPMOC.NS from 2019-02-04...
# ✅ Data fetched for XELPMOC.NS (2019-02-04 - 2025-04-11)
# 📁 Saved: S-Curve_Data/XELPMOC.NS_yearly_analysis.csv
# 📥 Processing XPROINDIA.NS from 2004-04-27...
# ✅ Data fetched for XPROINDIA.NS (2004-04-27 - 2025-04-11)
# 📁 Saved: S-Curve_Data/XPROINDIA.NS_yearly_analysis.csv
# 📥 Processing YAARI.NS from 2011-08-18...
# ✅ Data fetched for YAARI.NS (2011-08-18 - 2025-04-11)
# 📁 Saved: S-Curve_Data/YAARI.NS_yearly_analysis.csv
# 📥 Processing YESBANK.NS from 2005-07-12...
# ✅ Data fetched for YESBANK.NS (2005-07-12 - 2025-04-11)
# 📁 Saved: S-Curve_Data/YESBANK.NS_yearly_analysis.csv
# 📥 Processing ZEEL.NS from 1998-09-09...
# ✅ Data fetched for ZEEL.NS (2002-07-01 - 2025-04-11)
# 📁 Saved: S-Curve_Data/ZEEL.NS_yearly_analysis.csv
# 📥 Processing ZEELEARN.NS from 2010-12-20...
# ✅ Data fetched for ZEELEARN.NS (2010-12-20 - 2025-04-11)
# 📁 Saved: S-Curve_Data/ZEELEARN.NS_yearly_analysis.csv
# 📥 Processing ZEEMEDIA.NS from 2007-01-10...
# ✅ Data fetched for ZEEMEDIA.NS (2007-01-10 - 2025-04-11)
# 📁 Saved: S-Curve_Data/ZEEMEDIA.NS_yearly_analysis.csv
# 📥 Processing ZENITHEXPO.NS from 1996-07-10...
# ✅ Data fetched for ZENITHEXPO.NS (2002-07-02 - 2025-04-11)
# 📁 Saved: S-Curve_Data/ZENITHEXPO.NS_yearly_analysis.csv
# 📥 Processing ZENITHSTL.NS from 2007-04-30...
# ✅ Data fetched for ZENITHSTL.NS (2007-04-30 - 2025-04-11)
# 📁 Saved: S-Curve_Data/ZENITHSTL.NS_yearly_analysis.csv
# 📥 Processing ZENSARTECH.NS from 2003-07-09...
# ✅ Data fetched for ZENSARTECH.NS (2003-07-09 - 2025-04-11)
# 📁 Saved: S-Curve_Data/ZENSARTECH.NS_yearly_analysis.csv
# 🌍 Taking a longer break to avoid rate limits...
# 📥 Processing ZENTEC.NS from 2015-03-30...
# ✅ Data fetched for ZENTEC.NS (2015-03-30 - 2025-04-11)
# 📁 Saved: S-Curve_Data/ZENTEC.NS_yearly_analysis.csv
# 📥 Processing ZFCVINDIA.NS from 2008-10-01...
# ✅ Data fetched for ZFCVINDIA.NS (2008-10-01 - 2025-04-11)
# 📁 Saved: S-Curve_Data/ZFCVINDIA.NS_yearly_analysis.csv
# 📥 Processing ZODIACLOTH.NS from 1995-09-27...
# ✅ Data fetched for ZODIACLOTH.NS (2002-07-01 - 2025-04-11)
# 📁 Saved: S-Curve_Data/ZODIACLOTH.NS_yearly_analysis.csv
# 📥 Processing ZOTA.NS from 2019-08-19...
# ✅ Data fetched for ZOTA.NS (2019-08-19 - 2025-04-11)
# 📁 Saved: S-Curve_Data/ZOTA.NS_yearly_analysis.csv
# 📥 Processing ZUARI.NS from 2012-11-27...
# ✅ Data fetched for ZUARI.NS (2012-11-27 - 2025-04-11)
# 📁 Saved: S-Curve_Data/ZUARI.NS_yearly_analysis.csv
# 📥 Processing ZUARIIND.NS from 1995-04-12...
# ✅ Data fetched for ZUARIIND.NS (2002-07-01 - 2025-04-11)
# 📁 Saved: S-Curve_Data/ZUARIIND.NS_yearly_analysis.csv
# 📥 Processing ZYDUSLIFE.NS from 2000-04-18...
# ✅ Data fetched for ZYDUSLIFE.NS (2000-04-27 - 2025-04-11)
# 📁 Saved: S-Curve_Data/ZYDUSLIFE.NS_yearly_analysis.csv
# 📥 Processing ZYDUSWELL.NS from 2009-11-13...
# ✅ Data fetched for ZYDUSWELL.NS (2009-11-13 - 2025-04-11)
# 📁 Saved: S-Curve_Data/ZYDUSWELL.NS_yearly_analysis.csv
# 📊 Summary saved to S-Curve_Data/all_stocks_latest_analysis.csv
# ✅ Analysis complete. Output in 'S-Curve_Data/'

# %%
import shutil

# Replace 'your_folder_name' with the name of the folder you want to zip
folder_to_zip = 'S-Curve_Data'
zip_filename = 'S-Curve_Data.zip'

# Create zip file
shutil.make_archive(base_name=zip_filename.replace('.zip', ''), format='zip', root_dir=folder_to_zip)

print(f"Zipped folder saved as: {zip_filename}")
# Out:
# Zipped folder saved as: S-Curve_Data.zip

# %%
import yfinance as yf
import pandas as pd
import os
import numpy as np
import time
import math
from datetime import datetime

# Load stock symbols and their listing dates from CSV
stock_list_path = "NS.csv"  # Path to your CSV
stock_df = pd.read_csv(stock_list_path)
stock_df['DATE OF LISTING'] = pd.to_datetime(stock_df['DATE OF LISTING'])

# Create a directory to store output files (changed output folder name)
output_directory = "Stock_Analysis_Data"
os.makedirs(output_directory, exist_ok=True)

# ---------------------- Rate-Limited Download Functions ----------------------
def safe_download(symbol, start, retries=3, delay=60):
    """Download stock data with rate limit handling"""
    for attempt in range(retries):
        try:
            data = yf.download(symbol, start=start, interval='1d', progress=False)
            if not data.empty:
                return data
        except Exception as e:
            if 'Too Many Requests' in str(e) or 'Rate limited' in str(e):
                print(f"⏳ Rate limit hit for {symbol}. Waiting {delay} seconds (Attempt {attempt+1}/{retries})...")
                time.sleep(delay)
            else:
                print(f"❌ Unexpected error downloading {symbol}: {e}")
                break
    return pd.DataFrame()

def safe_info(ticker_obj, retries=3, delay=30):
    """Fetch ticker info with rate limit handling"""
    for attempt in range(retries):
        try:
            return ticker_obj.info
        except Exception as e:
            if 'Too Many Requests' in str(e) or 'Rate limited' in str(e):
                print(f"⏳ Rate limit (info) hit. Waiting {delay} seconds...")
                time.sleep(delay)
            else:
                print(f"❌ Info error: {e}")
                break
    return {}

# Function to fetch and process stock data
def fetch_and_process_stock_data(stock_symbol, listing_date, max_retries=3, sleep_time=2):
    """Comprehensive function to fetch and analyze stock data"""
    start_year = listing_date.year
    start_date_str = listing_date.strftime("%Y-%m-%d")

    # Ensure the symbol has the .NS suffix
    full_symbol = stock_symbol if stock_symbol.endswith(".NS") else stock_symbol + ".NS"

    print(f"📥 Processing {full_symbol} from {start_date_str}...")

    try:
        # Download historical stock data from the listing year
        stock_data = safe_download(full_symbol, start=start_date_str, retries=max_retries, delay=sleep_time)

        if stock_data.empty:
            print(f"⚠️ No data found for {full_symbol}")
            return None

        print(f"✅ Data fetched for {full_symbol} ({stock_data.index.min().strftime('%Y-%m-%d')} - {stock_data.index.max().strftime('%Y-%m-%d')})")

        # Check for Close price data
        if 'Close' not in stock_data.columns:
            if 'Adj Close' in stock_data.columns:
                stock_data['Close'] = stock_data['Adj Close']
            else:
                print(f"⚠️ Cannot find price data for {full_symbol}. Skipping.")
                return None

        # Process the data
        stock_data.reset_index(inplace=True)
        stock_data['Year'] = stock_data['Date'].dt.year

        # Add financial year calculation
        stock_data['Fin_Year'] = stock_data['Date'].apply(
            lambda x: x.year if x.month > 3 else x.year - 1
        )

        # Filter out years before listing
        stock_data = stock_data[stock_data['Year'] >= start_year]

        # Yearly metrics - using calendar year for consistency
        yearly_avg_close = stock_data.groupby('Year')['Close'].mean().reset_index()
        yearly_avg_close.columns = ['Year', 'Yearly Average Price']

        # Calculate year-over-year percentage increase in average prices
        yearly_avg_close['Prev Year Avg'] = yearly_avg_close['Yearly Average Price'].shift(1)
        yearly_avg_close['Yearly Avg Price % Increase'] = (
            (yearly_avg_close['Yearly Average Price'] - yearly_avg_close['Prev Year Avg']) /
            yearly_avg_close['Prev Year Avg'] * 100
        )

        # Replace NaN for first year with 0
        yearly_avg_close['Yearly Avg Price % Increase'] = yearly_avg_close['Yearly Avg Price % Increase'].fillna(0)

        # Round to 2 decimal places
        yearly_avg_close['Yearly Avg Price % Increase'] = yearly_avg_close['Yearly Avg Price % Increase'].round(2)

        # Drop the helper column
        yearly_avg_close = yearly_avg_close.drop(columns=['Prev Year Avg'])

        yearly_volatility = stock_data.groupby('Year')['Close'].std().reset_index()
        yearly_volatility.columns = ['Year', 'Yearly Volatility']

        last_dates = stock_data.groupby('Year')['Date'].idxmax()
        last_close_prices = pd.DataFrame()
        last_close_prices['Year'] = stock_data.loc[last_dates, 'Year'].values
        last_close_prices['Market Price'] = stock_data.loc[last_dates, 'Close'].values

        yearly_growth = stock_data.groupby('Year')['Close'].apply(
            lambda x: (x.iloc[-1] / x.iloc[0] - 1) if len(x) > 1 else 0
        ).reset_index()
        yearly_growth.columns = ['Year', 'Yearly Growth']

        # Merge metrics
        merged_data = pd.merge(last_close_prices, yearly_avg_close, on='Year', how='left')
        merged_data = pd.merge(merged_data, yearly_volatility, on='Year', how='left')
        merged_data = pd.merge(merged_data, yearly_growth, on='Year', how='left')
        merged_data.insert(1, 'Stock', full_symbol)

        # Get current financials using the yfinance API
        ticker = yf.Ticker(full_symbol)
        info = safe_info(ticker)

        # Extract current financial metrics
        current_eps = info.get('trailingEps', np.nan)
        current_pe = info.get('trailingPE', np.nan)
        current_book_value = info.get('bookValue', np.nan)
        current_roe = info.get('returnOnEquity', np.nan)

        # Normalize ROE if needed
        if current_roe and current_roe > 1:
            current_roe = current_roe / 100

        # Calculate fundamental PE based on ROE
        fundamental_pe = 1 / current_roe if current_roe and current_roe > 0 else np.nan

        # Add required columns
        for col in ['EPS', 'Projected EPS', 'P/E Ratio', 'Fundamental P/E',
                    'Book Value', 'P/B Ratio', 'ROE', 'Intrinsic Value',
                    'Intrinsic Value (Graham)', 'Intrinsic Value (Combined)',
                    'Market to Intrinsic Ratio']:
            if col not in merged_data.columns:
                merged_data[col] = np.nan

        # Apply derived metrics (approach from first script)
        # Financial metrics - synthesized approach from both scripts
        for index, row in merged_data.iterrows():
            year = row['Year']
            market_price = row['Market Price']
            years_diff = merged_data['Year'].max() - year

            # Estimated EPS based on current EPS with historical growth adjustment
            if current_eps is not None and not pd.isna(current_eps):
                growth_factor = (1 / (1.10 ** years_diff)) if years_diff > 0 else 1
                estimated_eps = current_eps * growth_factor
            else:
                # Fallback calculation from first script
                estimated_eps = (row['Yearly Average Price'] * 0.1 *
                                (1 + row.get('Yearly Growth', 0) * 0.3))
                if not pd.isna(estimated_eps):
                    estimated_eps = max(estimated_eps, 0.01)

            merged_data.at[index, 'EPS'] = estimated_eps

            # Estimated Book Value
            if current_book_value is not None and not pd.isna(current_book_value):
                growth_factor = (1 / (1.08 ** years_diff)) if years_diff > 0 else 1
                estimated_book = current_book_value * growth_factor
            else:
                # Fallback calculation from first script
                factor = (1 - row.get('Yearly Growth', 0) * 0.1 + np.sin(index) * 0.05)
                if not pd.isna(factor):
                    factor = max(factor, 0.05)
                estimated_book = row['Yearly Average Price'] * 0.5 * factor

            merged_data.at[index, 'Book Value'] = estimated_book

            # Calculate P/E and P/B ratios
            if not pd.isna(estimated_eps) and estimated_eps > 0:
                merged_data.at[index, 'P/E Ratio'] = market_price / estimated_eps

            if not pd.isna(estimated_book) and estimated_book > 0:
                merged_data.at[index, 'P/B Ratio'] = market_price / estimated_book

            # Return on Equity
            if current_roe is not None and not pd.isna(current_roe):
                merged_data.at[index, 'ROE'] = current_roe
            else:
                # Calculate from EPS and Book Value
                if not pd.isna(estimated_eps) and not pd.isna(estimated_book) and estimated_book > 0:
                    roe_value = estimated_eps / estimated_book
                    merged_data.at[index, 'ROE'] = roe_value

            # Fundamental P/E calculation
            if not pd.isna(merged_data.at[index, 'ROE']) and merged_data.at[index, 'ROE'] > 0:
                merged_data.at[index, 'Fundamental P/E'] = 1 / merged_data.at[index, 'ROE']
            else:
                # Alternative calculation from first script
                base_pe = 15.0
                if not pd.isna(row.get('Yearly Volatility')) and not pd.isna(row['Yearly Average Price']):
                    base_pe -= (row['Yearly Volatility'] / row['Yearly Average Price'] * 20)

                if not pd.isna(row.get('Yearly Growth')):
                    base_pe += (row['Yearly Growth'] * 10)

                base_pe = max(8, min(25, base_pe))
                merged_data.at[index, 'Fundamental P/E'] = base_pe

            # Calculate future growth and EPS projection
            future_growth_rate = row.get('Yearly Growth', 0)
            if not pd.isna(future_growth_rate):
                future_growth_rate = max(-0.1, min(0.2, future_growth_rate))
                if not pd.isna(estimated_eps):
                    merged_data.at[index, 'Projected EPS'] = estimated_eps * (1 + future_growth_rate)

            # Intrinsic Value calculations
            # Graham's formula
            try:
                if not pd.isna(estimated_eps) and not pd.isna(estimated_book) and estimated_eps > 0 and estimated_book > 0:
                    graham_value = math.sqrt(22.5 * estimated_eps * estimated_book)
                    merged_data.at[index, 'Intrinsic Value (Graham)'] = graham_value
            except:
                pass

            # EPS-based intrinsic value
            if not pd.isna(estimated_eps) and not pd.isna(merged_data.at[index, 'Fundamental P/E']):
                eps_value = estimated_eps * merged_data.at[index, 'Fundamental P/E']
                merged_data.at[index, 'Intrinsic Value'] = eps_value

            # Combined intrinsic value
            values = []
            for col in ['Intrinsic Value', 'Intrinsic Value (Graham)']:
                if col in merged_data.columns and not pd.isna(merged_data.at[index, col]):
                    values.append(merged_data.at[index, col])

            if values:
                combined = np.mean(values)
                merged_data.at[index, 'Intrinsic Value (Combined)'] = combined

                if not pd.isna(market_price) and combined > 0:
                    market_ratio = market_price / combined
                    merged_data.at[index, 'Market to Intrinsic Ratio'] = market_ratio

        # Valuation status
        conditions = [
            merged_data['Market to Intrinsic Ratio'] < 0.8,
            merged_data['Market to Intrinsic Ratio'] < 1.0,
            merged_data['Market to Intrinsic Ratio'] < 1.2,
            merged_data['Market to Intrinsic Ratio'] >= 1.2
        ]
        values = ['Undervalued', 'Fair Value', 'Slightly Overvalued', 'Overvalued']
        merged_data['Valuation Status'] = np.select(conditions, values, default='Fair Value')

        # Define final columns (removed S-curve related columns)
        final_columns = [
            'Year', 'Stock', 'Market Price', 'Yearly Average Price', 'Yearly Avg Price % Increase',
            'Yearly Volatility', 'Yearly Growth', 'EPS', 'Projected EPS', 'P/E Ratio',
            'Fundamental P/E', 'Book Value', 'P/B Ratio', 'ROE', 'Intrinsic Value',
            'Intrinsic Value (Graham)', 'Intrinsic Value (Combined)',
            'Market to Intrinsic Ratio', 'Valuation Status'
        ]

        # Ensure all columns exist (add if missing)
        for col in final_columns:
            if col not in merged_data.columns and col not in ['Year', 'Stock', 'Valuation Status']:
                merged_data[col] = np.nan

        # Select and order columns that actually exist in the dataframe
        existing_columns = [col for col in final_columns if col in merged_data.columns]
        merged_data = merged_data[existing_columns]

        # Round numeric columns
        for col in merged_data.columns:
            if col not in ['Year', 'Stock', 'Valuation Status']:
                try:
                    if merged_data[col].dtype in [np.float64, np.float32, float]:
                        merged_data[col] = merged_data[col].round(2)
                except:
                    pass

        # Save to file
        file_path = os.path.join(output_directory, f"{full_symbol}_yearly_analysis.csv")
        merged_data.to_csv(file_path, index=False)

        print(f"📁 Saved: {file_path}")
        return merged_data

    except Exception as error:
        print(f"⚠️ Error processing {full_symbol}: {error}")
        time.sleep(sleep_time)
        return None

# Main execution
all_results = {}
for i, row in stock_df.iterrows():
    symbol = row['SYMBOL']
    listing_date = row['DATE OF LISTING']

    result = fetch_and_process_stock_data(symbol, listing_date)

    if result is not None:
        all_results[symbol] = result

    # Take a break every 10 stocks to avoid rate limits
    if (i + 1) % 10 == 0:
        print("🌍 Taking a longer break to avoid rate limits...")
        time.sleep(15)

# Create summary of latest data for all stocks
if all_results:
    summary_data = []
    for symbol, data in all_results.items():
        if not data.empty:
            latest_year = data['Year'].max()
            latest_data = data[data['Year'] == latest_year].copy()
            if not latest_data.empty:
                summary_data.append(latest_data)

    if summary_data:
        summary_df = pd.concat(summary_data)
        summary_file = os.path.join(output_directory, "all_stocks_latest_analysis.csv")
        summary_df.to_csv(summary_file, index=False)
        print(f"📊 Summary saved to {summary_file}")

print(f"✅ Analysis complete. Output in '{output_directory}/'")
# Out:
# 📥 Processing 3IINFOLTD.NS from 2021-10-22...
# YF.download() has changed argument auto_adjust default to True
# ✅ Data fetched for 3IINFOLTD.NS (2021-10-22 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/3IINFOLTD.NS_yearly_analysis.csv
# 📥 Processing AAATECH.NS from 2022-11-28...
# ✅ Data fetched for AAATECH.NS (2022-11-28 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/AAATECH.NS_yearly_analysis.csv
# 📥 Processing AADHARHFC.NS from 2024-05-15...
# ✅ Data fetched for AADHARHFC.NS (2024-05-15 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/AADHARHFC.NS_yearly_analysis.csv
# 📥 Processing AAKASH.NS from 2020-09-29...
# ✅ Data fetched for AAKASH.NS (2020-09-29 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/AAKASH.NS_yearly_analysis.csv
# 📥 Processing AAREYDRUGS.NS from 2021-08-06...
# ✅ Data fetched for AAREYDRUGS.NS (2021-08-06 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/AAREYDRUGS.NS_yearly_analysis.csv
# 📥 Processing AARON.NS from 2020-11-06...
# ✅ Data fetched for AARON.NS (2020-11-06 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/AARON.NS_yearly_analysis.csv
# 📥 Processing AARTECH.NS from 2023-07-10...
# ✅ Data fetched for AARTECH.NS (2023-07-10 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/AARTECH.NS_yearly_analysis.csv
# 📥 Processing AARTIPHARM.NS from 2023-01-30...
# ✅ Data fetched for AARTIPHARM.NS (2023-01-30 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/AARTIPHARM.NS_yearly_analysis.csv
# 📥 Processing AARTISURF.NS from 2020-07-14...
# ✅ Data fetched for AARTISURF.NS (2020-07-14 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/AARTISURF.NS_yearly_analysis.csv
# 📥 Processing AARVI.NS from 2020-06-24...
# ✅ Data fetched for AARVI.NS (2020-06-24 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/AARVI.NS_yearly_analysis.csv
# 🌍 Taking a longer break to avoid rate limits...
# 📥 Processing ABDL.NS from 2024-07-02...
# ✅ Data fetched for ABDL.NS (2024-07-02 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/ABDL.NS_yearly_analysis.csv
# 📥 Processing ABINFRA.NS from 2024-11-08...
# ✅ Data fetched for ABINFRA.NS (2024-11-08 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/ABINFRA.NS_yearly_analysis.csv
# 📥 Processing ABMINTLLTD.NS from 2021-09-09...
# ✅ Data fetched for ABMINTLLTD.NS (2021-09-09 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/ABMINTLLTD.NS_yearly_analysis.csv
# 📥 Processing ABSLAMC.NS from 2021-10-11...
# ✅ Data fetched for ABSLAMC.NS (2021-10-11 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/ABSLAMC.NS_yearly_analysis.csv
# 📥 Processing ACCURACY.NS from 2020-12-11...
# ✅ Data fetched for ACCURACY.NS (2020-12-11 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/ACCURACY.NS_yearly_analysis.csv
# 📥 Processing ACEINTEG.NS from 2022-11-04...
# ✅ Data fetched for ACEINTEG.NS (2022-11-04 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/ACEINTEG.NS_yearly_analysis.csv
# 📥 Processing ACI.NS from 2022-11-21...
# ✅ Data fetched for ACI.NS (2022-11-21 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/ACI.NS_yearly_analysis.csv
# 📥 Processing ACL.NS from 2023-05-10...
# ✅ Data fetched for ACL.NS (2023-05-10 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/ACL.NS_yearly_analysis.csv
# 📥 Processing ACMESOLAR.NS from 2024-11-13...
# ✅ Data fetched for ACMESOLAR.NS (2024-11-13 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/ACMESOLAR.NS_yearly_analysis.csv
# 📥 Processing ADL.NS from 2020-10-01...
# ✅ Data fetched for ADL.NS (2020-10-01 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/ADL.NS_yearly_analysis.csv
# 🌍 Taking a longer break to avoid rate limits...
# 📥 Processing AEROFLEX.NS from 2023-08-31...
# ✅ Data fetched for AEROFLEX.NS (2023-08-31 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/AEROFLEX.NS_yearly_analysis.csv
# 📥 Processing AETHER.NS from 2022-06-03...
# ✅ Data fetched for AETHER.NS (2022-06-03 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/AETHER.NS_yearly_analysis.csv
# 📥 Processing AFCONS.NS from 2024-11-04...
# ✅ Data fetched for AFCONS.NS (2024-11-04 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/AFCONS.NS_yearly_analysis.csv
# 📥 Processing AFFORDABLE.NS from 2024-10-23...
# ✅ Data fetched for AFFORDABLE.NS (2024-10-23 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/AFFORDABLE.NS_yearly_analysis.csv
# 📥 Processing AFIL.NS from 2024-06-26...
# ✅ Data fetched for AFIL.NS (2024-06-26 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/AFIL.NS_yearly_analysis.csv
# 📥 Processing AGARWALEYE.NS from 2025-02-04...
# ✅ Data fetched for AGARWALEYE.NS (2025-02-04 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/AGARWALEYE.NS_yearly_analysis.csv
# 📥 Processing AGIIL.NS from 2024-07-15...
# ✅ Data fetched for AGIIL.NS (2024-07-15 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/AGIIL.NS_yearly_analysis.csv
# 📥 Processing AGSTRA.NS from 2022-01-31...
# ✅ Data fetched for AGSTRA.NS (2022-01-31 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/AGSTRA.NS_yearly_analysis.csv
# 📥 Processing AHL.NS from 2022-12-23...
# ✅ Data fetched for AHL.NS (2022-12-23 - 2025-04-11)
# 📁 Saved: Stock_Analysis_Data/AHL.NS_yearly_analysis.csv
# 📥 Processing AHLADA.NS from 2021-01-28...
# ✅ Data fetched for AHLADA.NS (2021-01-28 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/AHLADA.NS_yearly_analysis.csv
# 🌍 Taking a longer break to avoid rate limits...
# 📥 Processing AIIL.NS from 2024-04-23...
# ✅ Data fetched for AIIL.NS (2024-04-23 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/AIIL.NS_yearly_analysis.csv
# 📥 Processing AIROLAM.NS from 2021-10-13...
# ✅ Data fetched for AIROLAM.NS (2021-10-13 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/AIROLAM.NS_yearly_analysis.csv
# 📥 Processing AJAXENGG.NS from 2025-02-17...
# ✅ Data fetched for AJAXENGG.NS (2025-02-17 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/AJAXENGG.NS_yearly_analysis.csv
# 📥 Processing AJOONI.NS from 2021-05-07...
# ✅ Data fetched for AJOONI.NS (2021-05-07 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/AJOONI.NS_yearly_analysis.csv
# 📥 Processing AKG.NS from 2021-02-16...
# ✅ Data fetched for AKG.NS (2021-02-16 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/AKG.NS_yearly_analysis.csv
# 📥 Processing AKI.NS from 2023-04-06...
# ✅ Data fetched for AKI.NS (2023-04-06 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/AKI.NS_yearly_analysis.csv
# 📥 Processing AKSHAR.NS from 2022-05-23...
# ✅ Data fetched for AKSHAR.NS (2022-05-23 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/AKSHAR.NS_yearly_analysis.csv
# 📥 Processing AKUMS.NS from 2024-08-06...
# ✅ Data fetched for AKUMS.NS (2024-08-06 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/AKUMS.NS_yearly_analysis.csv
# 📥 Processing ALIVUS.NS from 2021-08-06...
# ✅ Data fetched for ALIVUS.NS (2025-01-13 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/ALIVUS.NS_yearly_analysis.csv
# 📥 Processing ALOKINDS.NS from 2020-02-19...
# ✅ Data fetched for ALOKINDS.NS (2020-02-19 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/ALOKINDS.NS_yearly_analysis.csv
# 🌍 Taking a longer break to avoid rate limits...
# 📥 Processing AMIORG.NS from 2021-09-14...
# ✅ Data fetched for AMIORG.NS (2021-09-14 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/AMIORG.NS_yearly_analysis.csv
# 📥 Processing AMNPLST.NS from 2023-11-10...
# ✅ Data fetched for AMNPLST.NS (2023-11-10 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/AMNPLST.NS_yearly_analysis.csv
# 📥 Processing ANANDRATHI.NS from 2021-12-14...
# ✅ Data fetched for ANANDRATHI.NS (2021-12-14 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/ANANDRATHI.NS_yearly_analysis.csv
# 📥 Processing ANGELONE.NS from 2020-10-05...
# ✅ Data fetched for ANGELONE.NS (2020-10-05 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/ANGELONE.NS_yearly_analysis.csv
# 📥 Processing ANMOL.NS from 2021-06-04...
# ✅ Data fetched for ANMOL.NS (2021-06-04 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/ANMOL.NS_yearly_analysis.csv
# 📥 Processing ANUHPHR.NS from 2024-12-20...
# ✅ Data fetched for ANUHPHR.NS (2024-12-20 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/ANUHPHR.NS_yearly_analysis.csv
# 📥 Processing ANURAS.NS from 2021-03-24...
# ✅ Data fetched for ANURAS.NS (2021-03-24 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/ANURAS.NS_yearly_analysis.csv
# 📥 Processing APTUS.NS from 2021-08-24...
# ✅ Data fetched for APTUS.NS (2021-08-24 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/APTUS.NS_yearly_analysis.csv
# 📥 Processing ARIHANTCAP.NS from 2021-06-15...
# ✅ Data fetched for ARIHANTCAP.NS (2021-06-15 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/ARIHANTCAP.NS_yearly_analysis.csv
# 📥 Processing ARKADE.NS from 2024-09-24...
# ✅ Data fetched for ARKADE.NS (2024-09-24 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/ARKADE.NS_yearly_analysis.csv
# 🌍 Taking a longer break to avoid rate limits...
# 📥 Processing ARTEMISMED.NS from 2020-01-23...
# ✅ Data fetched for ARTEMISMED.NS (2020-01-24 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/ARTEMISMED.NS_yearly_analysis.csv
# 📥 Processing ARTNIRMAN.NS from 2021-10-18...
# ✅ Data fetched for ARTNIRMAN.NS (2021-10-18 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/ARTNIRMAN.NS_yearly_analysis.csv
# 📥 Processing ARVEE.NS from 2021-03-22...
# ✅ Data fetched for ARVEE.NS (2021-03-22 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/ARVEE.NS_yearly_analysis.csv
# 📥 Processing ASALCBR.NS from 2020-02-12...
# ✅ Data fetched for ASALCBR.NS (2020-02-12 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/ASALCBR.NS_yearly_analysis.csv
# 📥 Processing ASHOKAMET.NS from 2023-06-27...
# ✅ Data fetched for ASHOKAMET.NS (2023-06-27 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/ASHOKAMET.NS_yearly_analysis.csv
# 📥 Processing ASIANENE.NS from 2021-12-09...
# ✅ Data fetched for ASIANENE.NS (2021-12-09 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/ASIANENE.NS_yearly_analysis.csv
# 📥 Processing ASKAUTOLTD.NS from 2023-11-15...
# ✅ Data fetched for ASKAUTOLTD.NS (2023-11-15 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/ASKAUTOLTD.NS_yearly_analysis.csv
# 📥 Processing ASMS.NS from 2023-02-09...
# ✅ Data fetched for ASMS.NS (2023-02-09 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/ASMS.NS_yearly_analysis.csv
# 📥 Processing ATALREAL.NS from 2023-05-12...
# ✅ Data fetched for ATALREAL.NS (2023-05-12 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/ATALREAL.NS_yearly_analysis.csv
# 📥 Processing ATAM.NS from 2023-05-10...
# ✅ Data fetched for ATAM.NS (2023-05-10 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/ATAM.NS_yearly_analysis.csv
# 🌍 Taking a longer break to avoid rate limits...
# 📥 Processing ATL.NS from 2023-08-10...
# ✅ Data fetched for ATL.NS (2023-08-10 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/ATL.NS_yearly_analysis.csv
# 📥 Processing AVALON.NS from 2023-04-18...
# ✅ Data fetched for AVALON.NS (2023-04-18 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/AVALON.NS_yearly_analysis.csv
# 📥 Processing AVANTEL.NS from 2024-07-31...
# ✅ Data fetched for AVANTEL.NS (2024-07-31 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/AVANTEL.NS_yearly_analysis.csv
# 📥 Processing AVG.NS from 2023-05-12...
# ✅ Data fetched for AVG.NS (2023-05-12 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/AVG.NS_yearly_analysis.csv
# 📥 Processing AVL.NS from 2024-11-06...
# ✅ Data fetched for AVL.NS (2024-11-06 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/AVL.NS_yearly_analysis.csv
# 📥 Processing AVONMORE.NS from 2023-01-04...
# ✅ Data fetched for AVONMORE.NS (2023-01-04 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/AVONMORE.NS_yearly_analysis.csv
# 📥 Processing AVROIND.NS from 2022-04-07...
# ✅ Data fetched for AVROIND.NS (2022-04-07 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/AVROIND.NS_yearly_analysis.csv
# 📥 Processing AWFIS.NS from 2024-05-30...
# ✅ Data fetched for AWFIS.NS (2024-05-30 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/AWFIS.NS_yearly_analysis.csv
# 📥 Processing AWHCL.NS from 2021-01-01...
# ✅ Data fetched for AWHCL.NS (2021-01-01 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/AWHCL.NS_yearly_analysis.csv
# 📥 Processing AWL.NS from 2022-02-08...
# ✅ Data fetched for AWL.NS (2022-02-08 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/AWL.NS_yearly_analysis.csv
# 🌍 Taking a longer break to avoid rate limits...
# 📥 Processing AXITA.NS from 2022-06-21...
# ✅ Data fetched for AXITA.NS (2022-06-21 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/AXITA.NS_yearly_analysis.csv
# 📥 Processing AZAD.NS from 2023-12-28...
# ✅ Data fetched for AZAD.NS (2023-12-28 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/AZAD.NS_yearly_analysis.csv
# 📥 Processing BAFNAPH.NS from 2020-02-27...
# ✅ Data fetched for BAFNAPH.NS (2020-02-27 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/BAFNAPH.NS_yearly_analysis.csv
# 📥 Processing BAIDFIN.NS from 2023-01-20...
# ✅ Data fetched for BAIDFIN.NS (2023-01-20 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/BAIDFIN.NS_yearly_analysis.csv
# 📥 Processing BAJAJHCARE.NS from 2021-11-25...
# ✅ Data fetched for BAJAJHCARE.NS (2021-11-25 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/BAJAJHCARE.NS_yearly_analysis.csv
# 📥 Processing BAJAJHFL.NS from 2024-09-16...
# ✅ Data fetched for BAJAJHFL.NS (2024-09-16 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/BAJAJHFL.NS_yearly_analysis.csv
# 📥 Processing BAJAJINDEF.NS from 2025-02-21...
# ✅ Data fetched for BAJAJINDEF.NS (2025-02-21 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/BAJAJINDEF.NS_yearly_analysis.csv
# 📥 Processing BAJEL.NS from 2023-12-19...
# ✅ Data fetched for BAJEL.NS (2023-12-19 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/BAJEL.NS_yearly_analysis.csv
# 📥 Processing BALAJEE.NS from 2024-09-12...
# ✅ Data fetched for BALAJEE.NS (2024-09-12 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/BALAJEE.NS_yearly_analysis.csv
# 📥 Processing BALUFORGE.NS from 2024-04-29...
# ✅ Data fetched for BALUFORGE.NS (2024-04-29 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/BALUFORGE.NS_yearly_analysis.csv
# 🌍 Taking a longer break to avoid rate limits...
# 📥 Processing BANKA.NS from 2020-10-29...
# ✅ Data fetched for BANKA.NS (2020-10-29 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/BANKA.NS_yearly_analysis.csv
# 📥 Processing BANSALWIRE.NS from 2024-07-10...
# ✅ Data fetched for BANSALWIRE.NS (2024-07-10 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/BANSALWIRE.NS_yearly_analysis.csv
# 📥 Processing BARBEQUE.NS from 2021-04-07...
# ✅ Data fetched for BARBEQUE.NS (2021-04-07 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/BARBEQUE.NS_yearly_analysis.csv
# 📥 Processing BBTCL.NS from 2022-11-23...
# ✅ Data fetched for BBTCL.NS (2022-11-23 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/BBTCL.NS_yearly_analysis.csv
# 📥 Processing BCLIND.NS from 2021-03-04...
# ✅ Data fetched for BCLIND.NS (2021-03-04 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/BCLIND.NS_yearly_analysis.csv
# 📥 Processing BCONCEPTS.NS from 2022-01-11...
# ✅ Data fetched for BCONCEPTS.NS (2022-01-11 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/BCONCEPTS.NS_yearly_analysis.csv
# 📥 Processing BECTORFOOD.NS from 2020-12-24...
# ✅ Data fetched for BECTORFOOD.NS (2020-12-24 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/BECTORFOOD.NS_yearly_analysis.csv
# 📥 Processing BESTAGRO.NS from 2024-04-10...
# ✅ Data fetched for BESTAGRO.NS (2024-04-10 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/BESTAGRO.NS_yearly_analysis.csv
# 📥 Processing BHAGCHEM.NS from 2021-10-18...
# ✅ Data fetched for BHAGCHEM.NS (2021-10-18 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/BHAGCHEM.NS_yearly_analysis.csv
# 📥 Processing BHARATSE.NS from 2025-03-24...
# ✅ Data fetched for BHARATSE.NS (2025-03-24 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/BHARATSE.NS_yearly_analysis.csv
# 🌍 Taking a longer break to avoid rate limits...
# 📥 Processing BHARTIHEXA.NS from 2024-04-12...
# ✅ Data fetched for BHARTIHEXA.NS (2024-04-12 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/BHARTIHEXA.NS_yearly_analysis.csv
# 📥 Processing BIKAJI.NS from 2022-11-16...
# ✅ Data fetched for BIKAJI.NS (2022-11-16 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/BIKAJI.NS_yearly_analysis.csv
# 📥 Processing BLACKBUCK.NS from 2024-11-22...
# ✅ Data fetched for BLACKBUCK.NS (2024-11-22 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/BLACKBUCK.NS_yearly_analysis.csv
# 📥 Processing BLAL.NS from 2023-04-19...
# ✅ Data fetched for BLAL.NS (2023-04-19 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/BLAL.NS_yearly_analysis.csv
# 📥 Processing BLSE.NS from 2024-02-06...
# ✅ Data fetched for BLSE.NS (2024-02-06 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/BLSE.NS_yearly_analysis.csv
# 📥 Processing BLUEJET.NS from 2023-11-01...
# ✅ Data fetched for BLUEJET.NS (2023-11-01 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/BLUEJET.NS_yearly_analysis.csv
# 📥 Processing BOHRAIND.NS from 2022-10-27...
# ✅ Data fetched for BOHRAIND.NS (2022-10-27 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/BOHRAIND.NS_yearly_analysis.csv
# 📥 Processing BOROLTD.NS from 2020-07-22...
# ✅ Data fetched for BOROLTD.NS (2020-07-22 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/BOROLTD.NS_yearly_analysis.csv
# 📥 Processing BOROSCI.NS from 2024-06-07...
# ✅ Data fetched for BOROSCI.NS (2024-06-07 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/BOROSCI.NS_yearly_analysis.csv
# 📥 Processing BSHSL.NS from 2020-10-28...
# ✅ Data fetched for BSHSL.NS (2020-10-28 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/BSHSL.NS_yearly_analysis.csv
# 🌍 Taking a longer break to avoid rate limits...
# 📥 Processing BTML.NS from 2023-02-15...
# ✅ Data fetched for BTML.NS (2023-02-15 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/BTML.NS_yearly_analysis.csv
# 📥 Processing CAMPUS.NS from 2022-05-09...
# ✅ Data fetched for CAMPUS.NS (2022-05-09 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/CAMPUS.NS_yearly_analysis.csv
# 📥 Processing CAMS.NS from 2021-05-07...
# ✅ Data fetched for CAMS.NS (2021-05-07 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/CAMS.NS_yearly_analysis.csv
# 📥 Processing CAPITALSFB.NS from 2024-02-14...
# ✅ Data fetched for CAPITALSFB.NS (2024-02-14 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/CAPITALSFB.NS_yearly_analysis.csv
# 📥 Processing CARRARO.NS from 2024-12-30...
# ✅ Data fetched for CARRARO.NS (2024-12-30 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/CARRARO.NS_yearly_analysis.csv
# 📥 Processing CARTRADE.NS from 2021-08-20...
# ✅ Data fetched for CARTRADE.NS (2021-08-20 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/CARTRADE.NS_yearly_analysis.csv
# 📥 Processing CARYSIL.NS from 2021-01-14...
# ✅ Data fetched for CARYSIL.NS (2021-01-14 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/CARYSIL.NS_yearly_analysis.csv
# 📥 Processing CEIGALL.NS from 2024-08-08...
# ✅ Data fetched for CEIGALL.NS (2024-08-08 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/CEIGALL.NS_yearly_analysis.csv
# 📥 Processing CELLO.NS from 2023-11-06...
# ✅ Data fetched for CELLO.NS (2023-11-06 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/CELLO.NS_yearly_analysis.csv
# 📥 Processing CEWATER.NS from 2024-12-27...
# ✅ Data fetched for CEWATER.NS (2024-12-27 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/CEWATER.NS_yearly_analysis.csv
# 🌍 Taking a longer break to avoid rate limits...
# 📥 Processing CHEMCON.NS from 2020-10-01...
# ✅ Data fetched for CHEMCON.NS (2020-10-01 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/CHEMCON.NS_yearly_analysis.csv
# 📥 Processing CHEMPLASTS.NS from 2021-08-24...
# ✅ Data fetched for CHEMPLASTS.NS (2021-08-24 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/CHEMPLASTS.NS_yearly_analysis.csv
# 📥 Processing CHEVIOT.NS from 2022-06-20...
# ✅ Data fetched for CHEVIOT.NS (2022-06-20 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/CHEVIOT.NS_yearly_analysis.csv
# 📥 Processing CHOICEIN.NS from 2022-04-08...
# ✅ Data fetched for CHOICEIN.NS (2022-04-08 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/CHOICEIN.NS_yearly_analysis.csv
# 📥 Processing CLEAN.NS from 2021-07-19...
# ✅ Data fetched for CLEAN.NS (2021-07-19 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/CLEAN.NS_yearly_analysis.csv
# 📥 Processing CLSEL.NS from 2021-05-12...
# ✅ Data fetched for CLSEL.NS (2021-05-12 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/CLSEL.NS_yearly_analysis.csv
# 📥 Processing CMSINFO.NS from 2021-12-31...
# ✅ Data fetched for CMSINFO.NS (2021-12-31 - 2025-04-15)
# ⚠️ Error processing CMSINFO.NS: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# 📥 Processing COASTCORP.NS from 2021-10-08...
# ✅ Data fetched for COASTCORP.NS (2021-10-08 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/COASTCORP.NS_yearly_analysis.csv
# 📥 Processing COMSYN.NS from 2024-01-23...
# ✅ Data fetched for COMSYN.NS (2024-01-23 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/COMSYN.NS_yearly_analysis.csv
# 📥 Processing CONCORDBIO.NS from 2023-08-18...
# ✅ Data fetched for CONCORDBIO.NS (2023-08-18 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/CONCORDBIO.NS_yearly_analysis.csv
# 🌍 Taking a longer break to avoid rate limits...
# 📥 Processing CRAFTSMAN.NS from 2021-03-25...
# ✅ Data fetched for CRAFTSMAN.NS (2021-03-25 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/CRAFTSMAN.NS_yearly_analysis.csv
# 📥 Processing CROWN.NS from 2022-02-08...
# ✅ Data fetched for CROWN.NS (2022-02-08 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/CROWN.NS_yearly_analysis.csv
# 📥 Processing CSLFINANCE.NS from 2022-07-21...
# ✅ Data fetched for CSLFINANCE.NS (2022-07-21 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/CSLFINANCE.NS_yearly_analysis.csv
# 📥 Processing CURAA.NS from 2025-03-21...
# ✅ Data fetched for CURAA.NS (2025-03-21 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/CURAA.NS_yearly_analysis.csv
# 📥 Processing CYIENTDLM.NS from 2023-07-10...
# ✅ Data fetched for CYIENTDLM.NS (2023-07-10 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/CYIENTDLM.NS_yearly_analysis.csv
# 📥 Processing DAMCAPITAL.NS from 2024-12-27...
# ✅ Data fetched for DAMCAPITAL.NS (2024-12-27 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/DAMCAPITAL.NS_yearly_analysis.csv
# 📥 Processing DANGEE.NS from 2020-11-13...
# ✅ Data fetched for DANGEE.NS (2020-11-13 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/DANGEE.NS_yearly_analysis.csv
# 📥 Processing DATAPATTNS.NS from 2021-12-24...
# ✅ Data fetched for DATAPATTNS.NS (2021-12-24 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/DATAPATTNS.NS_yearly_analysis.csv
# 📥 Processing DAVANGERE.NS from 2024-01-25...
# ✅ Data fetched for DAVANGERE.NS (2024-01-25 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/DAVANGERE.NS_yearly_analysis.csv
# 📥 Processing DBEIL.NS from 2024-10-28...
# ✅ Data fetched for DBEIL.NS (2024-10-28 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/DBEIL.NS_yearly_analysis.csv
# 🌍 Taking a longer break to avoid rate limits...
# 📥 Processing DBOL.NS from 2022-09-08...
# ✅ Data fetched for DBOL.NS (2022-09-08 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/DBOL.NS_yearly_analysis.csv
# 📥 Processing DCI.NS from 2022-10-19...
# ✅ Data fetched for DCI.NS (2022-10-19 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/DCI.NS_yearly_analysis.csv
# 📥 Processing DCMSRIND.NS from 2021-12-24...
# ✅ Data fetched for DCMSRIND.NS (2021-12-24 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/DCMSRIND.NS_yearly_analysis.csv
# 📥 Processing DCXINDIA.NS from 2022-11-11...
# ✅ Data fetched for DCXINDIA.NS (2022-11-11 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/DCXINDIA.NS_yearly_analysis.csv
# 📥 Processing DDEVPLSTIK.NS from 2025-01-15...
# ✅ Data fetched for DDEVPLSTIK.NS (2025-01-15 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/DDEVPLSTIK.NS_yearly_analysis.csv
# 📥 Processing DEEDEV.NS from 2024-06-26...
# ✅ Data fetched for DEEDEV.NS (2024-06-26 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/DEEDEV.NS_yearly_analysis.csv
# 📥 Processing DEEPINDS.NS from 2021-04-27...
# ✅ Data fetched for DEEPINDS.NS (2021-04-27 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/DEEPINDS.NS_yearly_analysis.csv
# 📥 Processing DELHIVERY.NS from 2022-05-24...
# ✅ Data fetched for DELHIVERY.NS (2022-05-24 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/DELHIVERY.NS_yearly_analysis.csv
# 📥 Processing DENTA.NS from 2025-01-29...
# ✅ Data fetched for DENTA.NS (2025-01-29 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/DENTA.NS_yearly_analysis.csv
# 📥 Processing DEVIT.NS from 2022-02-15...
# ✅ Data fetched for DEVIT.NS (2022-02-15 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/DEVIT.NS_yearly_analysis.csv
# 🌍 Taking a longer break to avoid rate limits...
# 📥 Processing DEVYANI.NS from 2021-08-16...
# ✅ Data fetched for DEVYANI.NS (2021-08-16 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/DEVYANI.NS_yearly_analysis.csv
# 📥 Processing DHARMAJ.NS from 2022-12-08...
# ✅ Data fetched for DHARMAJ.NS (2022-12-08 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/DHARMAJ.NS_yearly_analysis.csv
# 📥 Processing DHRUV.NS from 2021-11-25...
# ✅ Data fetched for DHRUV.NS (2021-11-25 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/DHRUV.NS_yearly_analysis.csv
# 📥 Processing DIACABS.NS from 2023-09-15...
# ✅ Data fetched for DIACABS.NS (2023-09-15 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/DIACABS.NS_yearly_analysis.csv
# 📥 Processing DIAMINESQ.NS from 2023-09-25...
# ✅ Data fetched for DIAMINESQ.NS (2023-09-25 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/DIAMINESQ.NS_yearly_analysis.csv
# 📥 Processing DIFFNKG.NS from 2024-10-04...
# ✅ Data fetched for DIFFNKG.NS (2024-10-04 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/DIFFNKG.NS_yearly_analysis.csv
# 📥 Processing DIGIDRIVE.NS from 2024-01-10...
# ✅ Data fetched for DIGIDRIVE.NS (2024-01-10 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/DIGIDRIVE.NS_yearly_analysis.csv
# 📥 Processing DIGJAMLMTD.NS from 2021-10-18...
# ✅ Data fetched for DIGJAMLMTD.NS (2021-10-18 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/DIGJAMLMTD.NS_yearly_analysis.csv
# 📥 Processing DIL.NS from 2022-03-31...
# ✅ Data fetched for DIL.NS (2022-03-31 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/DIL.NS_yearly_analysis.csv
# 📥 Processing DIVGIITTS.NS from 2023-03-14...
# ✅ Data fetched for DIVGIITTS.NS (2023-03-14 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/DIVGIITTS.NS_yearly_analysis.csv
# 🌍 Taking a longer break to avoid rate limits...
# 📥 Processing DJML.NS from 2022-12-05...
# ✅ Data fetched for DJML.NS (2022-12-05 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/DJML.NS_yearly_analysis.csv
# 📥 Processing DMCC.NS from 2021-12-01...
# ✅ Data fetched for DMCC.NS (2021-12-01 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/DMCC.NS_yearly_analysis.csv
# 📥 Processing DODLA.NS from 2021-06-28...
# ✅ Data fetched for DODLA.NS (2021-06-28 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/DODLA.NS_yearly_analysis.csv
# 📥 Processing DOLATALGO.NS from 2024-01-12...
# ✅ Data fetched for DOLATALGO.NS (2024-01-12 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/DOLATALGO.NS_yearly_analysis.csv
# 📥 Processing DOLPHIN.NS from 2023-08-21...
# ✅ Data fetched for DOLPHIN.NS (2023-08-21 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/DOLPHIN.NS_yearly_analysis.csv
# 📥 Processing DOMS.NS from 2023-12-20...
# ✅ Data fetched for DOMS.NS (2023-12-20 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/DOMS.NS_yearly_analysis.csv
# 📥 Processing DPABHUSHAN.NS from 2020-11-03...
# ✅ Data fetched for DPABHUSHAN.NS (2020-11-03 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/DPABHUSHAN.NS_yearly_analysis.csv
# 📥 Processing DPWIRES.NS from 2020-01-17...
# ✅ Data fetched for DPWIRES.NS (2020-01-17 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/DPWIRES.NS_yearly_analysis.csv
# 📥 Processing DRCSYSTEMS.NS from 2021-03-10...
# ✅ Data fetched for DRCSYSTEMS.NS (2021-03-10 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/DRCSYSTEMS.NS_yearly_analysis.csv
# 📥 Processing DREAMFOLKS.NS from 2022-09-06...
# ✅ Data fetched for DREAMFOLKS.NS (2022-09-06 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/DREAMFOLKS.NS_yearly_analysis.csv
# 🌍 Taking a longer break to avoid rate limits...
# 📥 Processing DYCL.NS from 2022-07-27...
# ✅ Data fetched for DYCL.NS (2022-07-27 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/DYCL.NS_yearly_analysis.csv
# 📥 Processing E2E.NS from 2022-04-12...
# ✅ Data fetched for E2E.NS (2022-04-12 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/E2E.NS_yearly_analysis.csv
# 📥 Processing EASEMYTRIP.NS from 2021-03-19...
# ✅ Data fetched for EASEMYTRIP.NS (2021-03-19 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/EASEMYTRIP.NS_yearly_analysis.csv
# 📥 Processing ECOSMOBLTY.NS from 2024-09-04...
# ✅ Data fetched for ECOSMOBLTY.NS (2024-09-04 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/ECOSMOBLTY.NS_yearly_analysis.csv
# 📥 Processing EIEL.NS from 2024-11-29...
# ✅ Data fetched for EIEL.NS (2024-11-29 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/EIEL.NS_yearly_analysis.csv
# 📥 Processing EIFFL.NS from 2021-10-12...
# ✅ Data fetched for EIFFL.NS (2021-10-12 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/EIFFL.NS_yearly_analysis.csv
# 📥 Processing ELDEHSG.NS from 2022-04-12...
# ✅ Data fetched for ELDEHSG.NS (2022-04-12 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/ELDEHSG.NS_yearly_analysis.csv
# 📥 Processing ELIN.NS from 2022-12-30...
# ✅ Data fetched for ELIN.NS (2022-12-30 - 2025-04-15)
# ⚠️ Error processing ELIN.NS: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# 📥 Processing EMCURE.NS from 2024-07-10...
# ✅ Data fetched for EMCURE.NS (2024-07-10 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/EMCURE.NS_yearly_analysis.csv
# 📥 Processing EMIL.NS from 2022-10-17...
# ✅ Data fetched for EMIL.NS (2022-10-17 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/EMIL.NS_yearly_analysis.csv
# 🌍 Taking a longer break to avoid rate limits...
# 📥 Processing EMSLIMITED.NS from 2023-09-21...
# ✅ Data fetched for EMSLIMITED.NS (2023-09-21 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/EMSLIMITED.NS_yearly_analysis.csv
# 📥 Processing EMUDHRA.NS from 2022-06-01...
# ✅ Data fetched for EMUDHRA.NS (2022-06-01 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/EMUDHRA.NS_yearly_analysis.csv
# 📥 Processing ENTERO.NS from 2024-02-16...
# ✅ Data fetched for ENTERO.NS (2024-02-16 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/ENTERO.NS_yearly_analysis.csv
# 📥 Processing EPACK.NS from 2024-01-30...
# ✅ Data fetched for EPACK.NS (2024-01-30 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/EPACK.NS_yearly_analysis.csv
# 📥 Processing EPIGRAL.NS from 2021-08-18...
# ✅ Data fetched for EPIGRAL.NS (2023-08-31 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/EPIGRAL.NS_yearly_analysis.csv
# 📥 Processing EQUIPPP.NS from 2021-05-19...
# ✅ Data fetched for EQUIPPP.NS (2021-05-19 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/EQUIPPP.NS_yearly_analysis.csv
# 📥 Processing EQUITASBNK.NS from 2020-11-02...
# ✅ Data fetched for EQUITASBNK.NS (2020-11-02 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/EQUITASBNK.NS_yearly_analysis.csv
# 📥 Processing ESAFSFB.NS from 2023-11-10...
# ✅ Data fetched for ESAFSFB.NS (2023-11-10 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/ESAFSFB.NS_yearly_analysis.csv
# 📥 Processing ETHOSLTD.NS from 2022-05-30...
# ✅ Data fetched for ETHOSLTD.NS (2022-05-30 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/ETHOSLTD.NS_yearly_analysis.csv
# 📥 Processing EUREKAFORB.NS from 2024-09-11...
# ✅ Data fetched for EUREKAFORB.NS (2024-09-11 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/EUREKAFORB.NS_yearly_analysis.csv
# 🌍 Taking a longer break to avoid rate limits...
# 📥 Processing EXICOM.NS from 2024-03-05...
# ✅ Data fetched for EXICOM.NS (2024-03-05 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/EXICOM.NS_yearly_analysis.csv
# 📥 Processing EXXARO.NS from 2021-08-16...
# ✅ Data fetched for EXXARO.NS (2021-08-16 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/EXXARO.NS_yearly_analysis.csv
# 📥 Processing FAIRCHEMOR.NS from 2020-12-24...
# ✅ Data fetched for FAIRCHEMOR.NS (2020-12-24 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/FAIRCHEMOR.NS_yearly_analysis.csv
# 📥 Processing FAZE3Q.NS from 2022-11-18...
# ✅ Data fetched for FAZE3Q.NS (2022-11-18 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/FAZE3Q.NS_yearly_analysis.csv
# 📥 Processing FEDFINA.NS from 2023-11-30...
# ✅ Data fetched for FEDFINA.NS (2023-11-30 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/FEDFINA.NS_yearly_analysis.csv
# 📥 Processing FIBERWEB.NS from 2022-02-16...
# ✅ Data fetched for FIBERWEB.NS (2022-02-16 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/FIBERWEB.NS_yearly_analysis.csv
# 📥 Processing FILATFASH.NS from 2024-05-06...
# ✅ Data fetched for FILATFASH.NS (2024-05-06 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/FILATFASH.NS_yearly_analysis.csv
# 📥 Processing FINOPB.NS from 2021-11-12...
# ✅ Data fetched for FINOPB.NS (2021-11-12 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/FINOPB.NS_yearly_analysis.csv
# 📥 Processing FIRSTCRY.NS from 2024-08-13...
# ✅ Data fetched for FIRSTCRY.NS (2024-08-13 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/FIRSTCRY.NS_yearly_analysis.csv
# 📥 Processing FIVESTAR.NS from 2022-11-21...
# ✅ Data fetched for FIVESTAR.NS (2022-11-21 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/FIVESTAR.NS_yearly_analysis.csv
# 🌍 Taking a longer break to avoid rate limits...
# 📥 Processing FLAIR.NS from 2023-12-01...
# ✅ Data fetched for FLAIR.NS (2023-12-01 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/FLAIR.NS_yearly_analysis.csv
# 📥 Processing FOCUS.NS from 2021-11-24...
# ✅ Data fetched for FOCUS.NS (2021-11-24 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/FOCUS.NS_yearly_analysis.csv
# 📥 Processing FOODSIN.NS from 2021-11-16...
# ✅ Data fetched for FOODSIN.NS (2021-11-16 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/FOODSIN.NS_yearly_analysis.csv
# 📥 Processing FORCEMOT.NS from 2024-02-14...
# ✅ Data fetched for FORCEMOT.NS (2024-02-14 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/FORCEMOT.NS_yearly_analysis.csv
# 📥 Processing FUSION.NS from 2022-11-15...
# ✅ Data fetched for FUSION.NS (2022-11-15 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/FUSION.NS_yearly_analysis.csv
# 📥 Processing GALAPREC.NS from 2024-09-09...
# ✅ Data fetched for GALAPREC.NS (2024-09-09 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/GALAPREC.NS_yearly_analysis.csv
# 📥 Processing GANDHAR.NS from 2023-11-30...
# ✅ Data fetched for GANDHAR.NS (2023-11-30 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/GANDHAR.NS_yearly_analysis.csv
# 📥 Processing GANESHBE.NS from 2021-09-16...
# ✅ Data fetched for GANESHBE.NS (2021-09-16 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/GANESHBE.NS_yearly_analysis.csv
# 📥 Processing GANGAFORGE.NS from 2021-07-06...
# ✅ Data fetched for GANGAFORGE.NS (2021-07-06 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/GANGAFORGE.NS_yearly_analysis.csv
# 📥 Processing GARUDA.NS from 2024-10-15...
# ✅ Data fetched for GARUDA.NS (2024-10-15 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/GARUDA.NS_yearly_analysis.csv
# 🌍 Taking a longer break to avoid rate limits...
# 📥 Processing GATEWAY.NS from 2022-03-22...
# ✅ Data fetched for GATEWAY.NS (2022-03-22 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/GATEWAY.NS_yearly_analysis.csv
# 📥 Processing GEEKAYWIRE.NS from 2020-03-06...
# ✅ Data fetched for GEEKAYWIRE.NS (2020-03-06 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/GEEKAYWIRE.NS_yearly_analysis.csv
# 📥 Processing GENCON.NS from 2021-02-16...
# ✅ Data fetched for GENCON.NS (2021-02-16 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/GENCON.NS_yearly_analysis.csv
# 📥 Processing GENSOL.NS from 2023-07-03...
# ✅ Data fetched for GENSOL.NS (2023-07-03 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/GENSOL.NS_yearly_analysis.csv
# 📥 Processing GHCLTEXTIL.NS from 2023-06-12...
# ✅ Data fetched for GHCLTEXTIL.NS (2023-06-12 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/GHCLTEXTIL.NS_yearly_analysis.csv
# 📥 Processing GLAND.NS from 2020-11-20...
# ✅ Data fetched for GLAND.NS (2020-11-20 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/GLAND.NS_yearly_analysis.csv
# 📥 Processing GLOBAL.NS from 2020-12-07...
# ✅ Data fetched for GLOBAL.NS (2020-12-07 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/GLOBAL.NS_yearly_analysis.csv
# 📥 Processing GLOBALE.NS from 2024-08-27...
# ✅ Data fetched for GLOBALE.NS (2024-08-27 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/GLOBALE.NS_yearly_analysis.csv
# 📥 Processing GLOBE.NS from 2020-10-07...
# ✅ Data fetched for GLOBE.NS (2020-10-07 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/GLOBE.NS_yearly_analysis.csv
# 📥 Processing GLOSTERLTD.NS from 2024-04-26...
# ✅ Data fetched for GLOSTERLTD.NS (2024-04-26 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/GLOSTERLTD.NS_yearly_analysis.csv
# 🌍 Taking a longer break to avoid rate limits...
# 📥 Processing GMRP&UI.NS from 2022-03-23...
# ✅ Data fetched for GMRP&UI.NS (2022-03-23 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/GMRP&UI.NS_yearly_analysis.csv
# 📥 Processing GOCOLORS.NS from 2021-11-30...
# ✅ Data fetched for GOCOLORS.NS (2021-11-30 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/GOCOLORS.NS_yearly_analysis.csv
# 📥 Processing GODAVARIB.NS from 2024-10-30...
# ✅ Data fetched for GODAVARIB.NS (2024-10-30 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/GODAVARIB.NS_yearly_analysis.csv
# 📥 Processing GODHA.NS from 2020-12-24...
# ✅ Data fetched for GODHA.NS (2020-12-24 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/GODHA.NS_yearly_analysis.csv
# 📥 Processing GODIGIT.NS from 2024-05-23...
# ✅ Data fetched for GODIGIT.NS (2024-05-23 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/GODIGIT.NS_yearly_analysis.csv
# 📥 Processing GOPAL.NS from 2024-03-14...
# ✅ Data fetched for GOPAL.NS (2024-03-14 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/GOPAL.NS_yearly_analysis.csv
# 📥 Processing GOYALALUM.NS from 2022-11-04...
# ✅ Data fetched for GOYALALUM.NS (2022-11-04 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/GOYALALUM.NS_yearly_analysis.csv
# 📥 Processing GPTHEALTH.NS from 2024-02-29...
# ✅ Data fetched for GPTHEALTH.NS (2024-02-29 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/GPTHEALTH.NS_yearly_analysis.csv
# 📥 Processing GRINFRA.NS from 2021-07-19...
# ✅ Data fetched for GRINFRA.NS (2021-07-19 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/GRINFRA.NS_yearly_analysis.csv
# 📥 Processing GRMOVER.NS from 2022-09-07...
# ✅ Data fetched for GRMOVER.NS (2022-09-07 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/GRMOVER.NS_yearly_analysis.csv
# 🌍 Taking a longer break to avoid rate limits...
# 📥 Processing GRWRHITECH.NS from 2022-02-03...
# ✅ Data fetched for GRWRHITECH.NS (2022-02-03 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/GRWRHITECH.NS_yearly_analysis.csv
# 📥 Processing GSLSU.NS from 2023-03-23...
# ✅ Data fetched for GSLSU.NS (2023-03-23 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/GSLSU.NS_yearly_analysis.csv
# 📥 Processing GTECJAINX.NS from 2020-11-13...
# ✅ Data fetched for GTECJAINX.NS (2023-09-04 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/GTECJAINX.NS_yearly_analysis.csv
# 📥 Processing GUJTHEM.NS from 2025-02-25...
# ✅ Data fetched for GUJTHEM.NS (2025-02-25 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/GUJTHEM.NS_yearly_analysis.csv
# 📥 Processing GVPTECH.NS from 2022-09-06...
# ✅ Data fetched for GVPTECH.NS (2022-09-06 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/GVPTECH.NS_yearly_analysis.csv
# 📥 Processing HAPPSTMNDS.NS from 2020-09-17...
# ✅ Data fetched for HAPPSTMNDS.NS (2020-09-17 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/HAPPSTMNDS.NS_yearly_analysis.csv
# 📥 Processing HAPPYFORGE.NS from 2023-12-27...
# ✅ Data fetched for HAPPYFORGE.NS (2023-12-27 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/HAPPYFORGE.NS_yearly_analysis.csv
# 📥 Processing HARDWYN.NS from 2022-04-12...
# ✅ Data fetched for HARDWYN.NS (2022-04-12 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/HARDWYN.NS_yearly_analysis.csv
# 📥 Processing HARIOMPIPE.NS from 2022-04-13...
# ✅ Data fetched for HARIOMPIPE.NS (2022-04-13 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/HARIOMPIPE.NS_yearly_analysis.csv
# 📥 Processing HARSHA.NS from 2022-09-26...
# ✅ Data fetched for HARSHA.NS (2022-09-26 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/HARSHA.NS_yearly_analysis.csv
# 🌍 Taking a longer break to avoid rate limits...
# 📥 Processing HECPROJECT.NS from 2021-12-30...
# ✅ Data fetched for HECPROJECT.NS (2021-12-30 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/HECPROJECT.NS_yearly_analysis.csv
# 📥 Processing HEMIPROP.NS from 2020-10-22...
# ✅ Data fetched for HEMIPROP.NS (2020-10-22 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/HEMIPROP.NS_yearly_analysis.csv
# 📥 Processing HERANBA.NS from 2021-03-05...
# ✅ Data fetched for HERANBA.NS (2021-03-05 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/HERANBA.NS_yearly_analysis.csv
# 📥 Processing HEXT.NS from 2025-02-19...
# ✅ Data fetched for HEXT.NS (2025-02-19 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/HEXT.NS_yearly_analysis.csv
# 📥 Processing HINDCON.NS from 2021-07-05...
# ✅ Data fetched for HINDCON.NS (2021-07-05 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/HINDCON.NS_yearly_analysis.csv
# 📥 Processing HLEGLAS.NS from 2023-02-09...
# ✅ Data fetched for HLEGLAS.NS (2023-02-09 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/HLEGLAS.NS_yearly_analysis.csv
# 📥 Processing HMAAGRO.NS from 2023-07-04...
# ✅ Data fetched for HMAAGRO.NS (2023-07-04 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/HMAAGRO.NS_yearly_analysis.csv
# 📥 Processing HNDFDS.NS from 2023-06-06...
# ✅ Data fetched for HNDFDS.NS (2023-06-06 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/HNDFDS.NS_yearly_analysis.csv
# 📥 Processing HOMEFIRST.NS from 2021-02-03...
# ✅ Data fetched for HOMEFIRST.NS (2021-02-03 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/HOMEFIRST.NS_yearly_analysis.csv
# 📥 Processing HONASA.NS from 2023-11-07...
# ✅ Data fetched for HONASA.NS (2023-11-07 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/HONASA.NS_yearly_analysis.csv
# 🌍 Taking a longer break to avoid rate limits...
# 📥 Processing HPAL.NS from 2021-12-27...
# ✅ Data fetched for HPAL.NS (2021-12-27 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/HPAL.NS_yearly_analysis.csv
# 📥 Processing HPIL.NS from 2022-11-07...
# ✅ Data fetched for HPIL.NS (2022-11-07 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/HPIL.NS_yearly_analysis.csv
# 📥 Processing HYBRIDFIN.NS from 2022-12-05...
# ✅ Data fetched for HYBRIDFIN.NS (2022-12-06 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/HYBRIDFIN.NS_yearly_analysis.csv
# 📥 Processing HYUNDAI.NS from 2024-10-22...
# ✅ Data fetched for HYUNDAI.NS (2024-10-22 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/HYUNDAI.NS_yearly_analysis.csv
# 📥 Processing ICEMAKE.NS from 2020-10-12...
# ✅ Data fetched for ICEMAKE.NS (2020-10-12 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/ICEMAKE.NS_yearly_analysis.csv
# 📥 Processing IDEAFORGE.NS from 2023-07-07...
# ✅ Data fetched for IDEAFORGE.NS (2023-07-07 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/IDEAFORGE.NS_yearly_analysis.csv
# 📥 Processing IEL.NS from 2022-12-27...
# ✅ Data fetched for IEL.NS (2022-12-27 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/IEL.NS_yearly_analysis.csv
# 📥 Processing IGIL.NS from 2024-12-20...
# ✅ Data fetched for IGIL.NS (2024-12-20 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/IGIL.NS_yearly_analysis.csv
# 📥 Processing IKIO.NS from 2023-06-16...
# ✅ Data fetched for IKIO.NS (2023-06-16 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/IKIO.NS_yearly_analysis.csv
# 📥 Processing IKS.NS from 2024-12-19...
# ✅ Data fetched for IKS.NS (2024-12-19 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/IKS.NS_yearly_analysis.csv
# 🌍 Taking a longer break to avoid rate limits...
# 📥 Processing INDGN.NS from 2024-05-13...
# ✅ Data fetched for INDGN.NS (2024-05-13 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/INDGN.NS_yearly_analysis.csv
# 📥 Processing INDIASHLTR.NS from 2023-12-20...
# ✅ Data fetched for INDIASHLTR.NS (2023-12-20 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/INDIASHLTR.NS_yearly_analysis.csv
# 📥 Processing INDIGOPNTS.NS from 2021-02-02...
# ✅ Data fetched for INDIGOPNTS.NS (2021-02-02 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/INDIGOPNTS.NS_yearly_analysis.csv
# 📥 Processing INDOAMIN.NS from 2022-04-29...
# ✅ Data fetched for INDOAMIN.NS (2022-04-29 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/INDOAMIN.NS_yearly_analysis.csv
# 📥 Processing INDOBORAX.NS from 2022-03-29...
# ✅ Data fetched for INDOBORAX.NS (2022-03-29 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/INDOBORAX.NS_yearly_analysis.csv
# 📥 Processing INDOFARM.NS from 2025-01-07...
# ✅ Data fetched for INDOFARM.NS (2025-01-07 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/INDOFARM.NS_yearly_analysis.csv
# 📥 Processing INDOUS.NS from 2024-09-27...
# ✅ Data fetched for INDOUS.NS (2024-09-27 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/INDOUS.NS_yearly_analysis.csv
# 📥 Processing INNOVACAP.NS from 2023-12-29...
# ✅ Data fetched for INNOVACAP.NS (2023-12-29 - 2025-04-15)
# ⚠️ Error processing INNOVACAP.NS: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# 📥 Processing INNOVANA.NS from 2024-12-17...
# ✅ Data fetched for INNOVANA.NS (2024-12-17 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/INNOVANA.NS_yearly_analysis.csv
# 📥 Processing INOXGREEN.NS from 2022-11-23...
# ✅ Data fetched for INOXGREEN.NS (2022-11-23 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/INOXGREEN.NS_yearly_analysis.csv
# 🌍 Taking a longer break to avoid rate limits...
# 📥 Processing INOXINDIA.NS from 2023-12-21...
# ✅ Data fetched for INOXINDIA.NS (2023-12-21 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/INOXINDIA.NS_yearly_analysis.csv
# 📥 Processing INTERARCH.NS from 2024-08-26...
# ✅ Data fetched for INTERARCH.NS (2024-08-26 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/INTERARCH.NS_yearly_analysis.csv
# 📥 Processing INTLCONV.NS from 2021-09-16...
# ✅ Data fetched for INTLCONV.NS (2021-09-16 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/INTLCONV.NS_yearly_analysis.csv
# 📥 Processing IONEXCHANG.NS from 2022-02-22...
# ✅ Data fetched for IONEXCHANG.NS (2022-02-22 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/IONEXCHANG.NS_yearly_analysis.csv
# 📥 Processing IPL.NS from 2021-07-05...
# ✅ Data fetched for IPL.NS (2021-07-05 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/IPL.NS_yearly_analysis.csv
# 📥 Processing IREDA.NS from 2023-11-29...
# ✅ Data fetched for IREDA.NS (2023-11-29 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/IREDA.NS_yearly_analysis.csv
# 📥 Processing IRFC.NS from 2021-01-29...
# ✅ Data fetched for IRFC.NS (2021-01-29 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/IRFC.NS_yearly_analysis.csv
# 📥 Processing IRIS.NS from 2021-11-08...
# ✅ Data fetched for IRIS.NS (2021-11-08 - 2025-04-15)
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['IRIS-RE.NS']: YFInvalidPeriodError("IRIS-RE.NS: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['IRIS-RE.NS']: YFInvalidPeriodError("IRIS-RE.NS: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['IRIS-RE.NS']: YFInvalidPeriodError("IRIS-RE.NS: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# 📁 Saved: Stock_Analysis_Data/IRIS.NS_yearly_analysis.csv
# 📥 Processing IRIS-RE.NS from 2025-03-27...
# ⚠️ No data found for IRIS-RE.NS
# 📥 Processing IRISDOREME.NS from 2021-02-22...
# ✅ Data fetched for IRISDOREME.NS (2021-02-22 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/IRISDOREME.NS_yearly_analysis.csv
# 🌍 Taking a longer break to avoid rate limits...
# 📥 Processing IRMENERGY.NS from 2023-10-26...
# ✅ Data fetched for IRMENERGY.NS (2023-10-26 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/IRMENERGY.NS_yearly_analysis.csv
# 📥 Processing ISGEC.NS from 2021-05-05...
# ✅ Data fetched for ISGEC.NS (2021-05-05 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/ISGEC.NS_yearly_analysis.csv
# 📥 Processing ISHANCH.NS from 2025-03-24...
# ✅ Data fetched for ISHANCH.NS (2025-03-24 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/ISHANCH.NS_yearly_analysis.csv
# 📥 Processing ITCHOTELS.NS from 2025-01-29...
# ✅ Data fetched for ITCHOTELS.NS (2025-01-29 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/ITCHOTELS.NS_yearly_analysis.csv
# 📥 Processing IWEL.NS from 2021-06-11...
# ✅ Data fetched for IWEL.NS (2021-06-11 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/IWEL.NS_yearly_analysis.csv
# 📥 Processing IXIGO.NS from 2024-06-18...
# ✅ Data fetched for IXIGO.NS (2024-06-18 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/IXIGO.NS_yearly_analysis.csv
# 📥 Processing JAIPURKURT.NS from 2021-09-02...
# ✅ Data fetched for JAIPURKURT.NS (2021-09-02 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/JAIPURKURT.NS_yearly_analysis.csv
# 📥 Processing JETFREIGHT.NS from 2021-12-21...
# ✅ Data fetched for JETFREIGHT.NS (2021-12-21 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/JETFREIGHT.NS_yearly_analysis.csv
# 📥 Processing JGCHEM.NS from 2024-03-13...
# ✅ Data fetched for JGCHEM.NS (2024-03-13 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/JGCHEM.NS_yearly_analysis.csv
# 📥 Processing JIOFIN.NS from 2023-08-21...
# ✅ Data fetched for JIOFIN.NS (2023-08-21 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/JIOFIN.NS_yearly_analysis.csv
# 🌍 Taking a longer break to avoid rate limits...
# 📥 Processing JLHL.NS from 2023-09-18...
# ✅ Data fetched for JLHL.NS (2023-09-18 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/JLHL.NS_yearly_analysis.csv
# 📥 Processing JNKINDIA.NS from 2024-04-30...
# ✅ Data fetched for JNKINDIA.NS (2024-04-30 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/JNKINDIA.NS_yearly_analysis.csv
# 📥 Processing JSFB.NS from 2024-02-14...
# ✅ Data fetched for JSFB.NS (2024-02-14 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/JSFB.NS_yearly_analysis.csv
# 📥 Processing JSWINFRA.NS from 2023-10-03...
# ✅ Data fetched for JSWINFRA.NS (2023-10-03 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/JSWINFRA.NS_yearly_analysis.csv
# 📥 Processing JTLIND.NS from 2023-06-12...
# ✅ Data fetched for JTLIND.NS (2023-06-12 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/JTLIND.NS_yearly_analysis.csv
# 📥 Processing JUBLCPL.NS from 2025-02-14...
# ✅ Data fetched for JUBLCPL.NS (2025-02-14 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/JUBLCPL.NS_yearly_analysis.csv
# 📥 Processing JUBLINGREA.NS from 2021-03-19...
# ✅ Data fetched for JUBLINGREA.NS (2021-03-19 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/JUBLINGREA.NS_yearly_analysis.csv
# 📥 Processing JUNIPER.NS from 2024-02-28...
# ✅ Data fetched for JUNIPER.NS (2024-02-28 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/JUNIPER.NS_yearly_analysis.csv
# 📥 Processing JYOTICNC.NS from 2024-01-16...
# ✅ Data fetched for JYOTICNC.NS (2024-01-16 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/JYOTICNC.NS_yearly_analysis.csv
# 📥 Processing KALAMANDIR.NS from 2023-09-27...
# ...
# 🌍 Taking a longer break to avoid rate limits...
# 📥 Processing STYLEBAAZA.NS from 2024-09-06...
# ✅ Data fetched for STYLEBAAZA.NS (2024-09-06 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/STYLEBAAZA.NS_yearly_analysis.csv
# 📥 Processing SUBEXLTD.NS from 2020-11-05...
# ✅ Data fetched for SUBEXLTD.NS (2020-11-05 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/SUBEXLTD.NS_yearly_analysis.csv
# 📥 Processing SUKHJITS.NS from 2022-11-07...
# ✅ Data fetched for SUKHJITS.NS (2022-11-07 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/SUKHJITS.NS_yearly_analysis.csv
# 📥 Processing SULA.NS from 2022-12-22...
# ✅ Data fetched for SULA.NS (2022-12-22 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/SULA.NS_yearly_analysis.csv
# 📥 Processing SUMICHEM.NS from 2020-01-27...
# ✅ Data fetched for SUMICHEM.NS (2020-01-27 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/SUMICHEM.NS_yearly_analysis.csv
# 📥 Processing SUNCLAY.NS from 2023-12-29...
# ✅ Data fetched for SUNCLAY.NS (2023-12-29 - 2025-04-15)
# ⚠️ Error processing SUNCLAY.NS: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# 📥 Processing SUPREME.NS from 2025-02-03...
# ✅ Data fetched for SUPREME.NS (2025-02-03 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/SUPREME.NS_yearly_analysis.csv
# 📥 Processing SUPREMEENG.NS from 2020-12-04...
# ✅ Data fetched for SUPREMEENG.NS (2020-12-04 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/SUPREMEENG.NS_yearly_analysis.csv
# 📥 Processing SUPRIYA.NS from 2021-12-28...
# ✅ Data fetched for SUPRIYA.NS (2021-12-28 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/SUPRIYA.NS_yearly_analysis.csv
# 📥 Processing SURAJEST.NS from 2023-12-26...
# ✅ Data fetched for SURAJEST.NS (2023-12-26 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/SURAJEST.NS_yearly_analysis.csv
# 🌍 Taking a longer break to avoid rate limits...
# 📥 Processing SURAJLTD.NS from 2024-08-29...
# ✅ Data fetched for SURAJLTD.NS (2024-08-29 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/SURAJLTD.NS_yearly_analysis.csv
# 📥 Processing SURAKSHA.NS from 2024-12-06...
# ✅ Data fetched for SURAKSHA.NS (2024-12-06 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/SURAKSHA.NS_yearly_analysis.csv
# 📥 Processing SURYODAY.NS from 2021-03-26...
# ✅ Data fetched for SURYODAY.NS (2021-03-26 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/SURYODAY.NS_yearly_analysis.csv
# 📥 Processing SUULD.NS from 2020-10-19...
# ✅ Data fetched for SUULD.NS (2020-10-19 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/SUULD.NS_yearly_analysis.csv
# 📥 Processing SUVENPHAR.NS from 2020-03-09...
# ✅ Data fetched for SUVENPHAR.NS (2020-03-09 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/SUVENPHAR.NS_yearly_analysis.csv
# 📥 Processing SUVIDHAA.NS from 2021-03-31...
# ✅ Data fetched for SUVIDHAA.NS (2021-03-31 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/SUVIDHAA.NS_yearly_analysis.csv
# 📥 Processing SUYOG.NS from 2024-08-20...
# ✅ Data fetched for SUYOG.NS (2024-08-20 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/SUYOG.NS_yearly_analysis.csv
# 📥 Processing SVLL.NS from 2023-04-21...
# ✅ Data fetched for SVLL.NS (2023-04-21 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/SVLL.NS_yearly_analysis.csv
# 📥 Processing SVPGLOB.NS from 2021-07-14...
# ✅ Data fetched for SVPGLOB.NS (2021-07-14 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/SVPGLOB.NS_yearly_analysis.csv
# 📥 Processing SWIGGY.NS from 2024-11-13...
# ✅ Data fetched for SWIGGY.NS (2024-11-13 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/SWIGGY.NS_yearly_analysis.csv
# 🌍 Taking a longer break to avoid rate limits...
# 📥 Processing SYNCOMF.NS from 2022-11-18...
# ✅ Data fetched for SYNCOMF.NS (2022-11-18 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/SYNCOMF.NS_yearly_analysis.csv
# 📥 Processing SYRMA.NS from 2022-08-26...
# ✅ Data fetched for SYRMA.NS (2022-08-26 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/SYRMA.NS_yearly_analysis.csv
# 📥 Processing TARACHAND.NS from 2024-04-16...
# ✅ Data fetched for TARACHAND.NS (2024-04-16 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/TARACHAND.NS_yearly_analysis.csv
# 📥 Processing TARC.NS from 2020-12-18...
# ✅ Data fetched for TARC.NS (2020-12-18 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/TARC.NS_yearly_analysis.csv
# 📥 Processing TARSONS.NS from 2021-11-26...
# ✅ Data fetched for TARSONS.NS (2021-11-26 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/TARSONS.NS_yearly_analysis.csv
# 📥 Processing TATATECH.NS from 2023-11-30...
# ✅ Data fetched for TATATECH.NS (2023-11-30 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/TATATECH.NS_yearly_analysis.csv
# 📥 Processing TATVA.NS from 2021-07-29...
# ✅ Data fetched for TATVA.NS (2021-07-29 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/TATVA.NS_yearly_analysis.csv
# 📥 Processing TBOTEK.NS from 2024-05-15...
# ✅ Data fetched for TBOTEK.NS (2024-05-15 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/TBOTEK.NS_yearly_analysis.csv
# 📥 Processing TEGA.NS from 2021-12-13...
# ✅ Data fetched for TEGA.NS (2021-12-13 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/TEGA.NS_yearly_analysis.csv
# 📥 Processing TEMBO.NS from 2021-04-23...
# ✅ Data fetched for TEMBO.NS (2021-04-23 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/TEMBO.NS_yearly_analysis.csv
# 🌍 Taking a longer break to avoid rate limits...
# 📥 Processing THEJO.NS from 2023-10-10...
# ✅ Data fetched for THEJO.NS (2023-10-10 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/THEJO.NS_yearly_analysis.csv
# 📥 Processing TICL.NS from 2023-10-16...
# ✅ Data fetched for TICL.NS (2023-10-16 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/TICL.NS_yearly_analysis.csv
# 📥 Processing TIPSFILMS.NS from 2022-10-06...
# ✅ Data fetched for TIPSFILMS.NS (2022-10-06 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/TIPSFILMS.NS_yearly_analysis.csv
# 📥 Processing TIRUPATIFL.NS from 2020-08-04...
# ✅ Data fetched for TIRUPATIFL.NS (2020-08-04 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/TIRUPATIFL.NS_yearly_analysis.csv
# 📥 Processing TMB.NS from 2022-09-15...
# ✅ Data fetched for TMB.NS (2022-09-15 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/TMB.NS_yearly_analysis.csv
# 📥 Processing TOLINS.NS from 2024-09-16...
# ✅ Data fetched for TOLINS.NS (2024-09-16 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/TOLINS.NS_yearly_analysis.csv
# 📥 Processing TOTAL.NS from 2020-08-28...
# ✅ Data fetched for TOTAL.NS (2020-08-28 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/TOTAL.NS_yearly_analysis.csv
# 📥 Processing TOUCHWOOD.NS from 2020-01-21...
# ✅ Data fetched for TOUCHWOOD.NS (2020-01-21 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/TOUCHWOOD.NS_yearly_analysis.csv
# 📥 Processing TRACXN.NS from 2022-10-20...
# ✅ Data fetched for TRACXN.NS (2022-10-20 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/TRACXN.NS_yearly_analysis.csv
# 📥 Processing TRANSRAILL.NS from 2024-12-27...
# ✅ Data fetched for TRANSRAILL.NS (2024-12-27 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/TRANSRAILL.NS_yearly_analysis.csv
# 🌍 Taking a longer break to avoid rate limits...
# 📥 Processing TREL.NS from 2023-08-10...
# ✅ Data fetched for TREL.NS (2023-08-10 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/TREL.NS_yearly_analysis.csv
# 📥 Processing TRU.NS from 2023-06-20...
# ✅ Data fetched for TRU.NS (2023-06-20 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/TRU.NS_yearly_analysis.csv
# 📥 Processing TVSSCS.NS from 2023-08-23...
# ✅ Data fetched for TVSSCS.NS (2023-08-23 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/TVSSCS.NS_yearly_analysis.csv
# 📥 Processing UDAICEMENT.NS from 2024-04-23...
# ✅ Data fetched for UDAICEMENT.NS (2024-04-23 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/UDAICEMENT.NS_yearly_analysis.csv
# 📥 Processing UDS.NS from 2023-10-04...
# ✅ Data fetched for UDS.NS (2023-10-04 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/UDS.NS_yearly_analysis.csv
# 📥 Processing UGROCAP.NS from 2021-08-11...
# ✅ Data fetched for UGROCAP.NS (2021-08-11 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/UGROCAP.NS_yearly_analysis.csv
# 📥 Processing UMAEXPORTS.NS from 2022-04-07...
# ✅ Data fetched for UMAEXPORTS.NS (2022-04-07 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/UMAEXPORTS.NS_yearly_analysis.csv
# 📥 Processing UNIDT.NS from 2020-09-25...
# ✅ Data fetched for UNIDT.NS (2020-09-25 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/UNIDT.NS_yearly_analysis.csv
# 📥 Processing UNIECOM.NS from 2024-08-13...
# ✅ Data fetched for UNIECOM.NS (2024-08-13 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/UNIECOM.NS_yearly_analysis.csv
# 📥 Processing UNIINFO.NS from 2022-01-12...
# ✅ Data fetched for UNIINFO.NS (2022-01-12 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/UNIINFO.NS_yearly_analysis.csv
# 🌍 Taking a longer break to avoid rate limits...
# 📥 Processing UNIMECH.NS from 2024-12-31...
# ✅ Data fetched for UNIMECH.NS (2024-12-31 - 2025-04-15)
# ⚠️ Error processing UNIMECH.NS: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# 📥 Processing UNIPARTS.NS from 2022-12-12...
# ✅ Data fetched for UNIPARTS.NS (2022-12-12 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/UNIPARTS.NS_yearly_analysis.csv
# 📥 Processing UNITEDPOLY.NS from 2021-12-31...
# ✅ Data fetched for UNITEDPOLY.NS (2021-12-31 - 2025-04-15)
# ⚠️ Error processing UNITEDPOLY.NS: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# 📥 Processing UNIVASTU.NS from 2020-06-22...
# ✅ Data fetched for UNIVASTU.NS (2020-06-22 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/UNIVASTU.NS_yearly_analysis.csv
# 📥 Processing UNIVPHOTO.NS from 2020-02-14...
# ✅ Data fetched for UNIVPHOTO.NS (2020-02-14 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/UNIVPHOTO.NS_yearly_analysis.csv
# 📥 Processing URAVIDEF.NS from 2023-07-05...
# ✅ Data fetched for URAVIDEF.NS (2023-07-05 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/URAVIDEF.NS_yearly_analysis.csv
# 📥 Processing USK.NS from 2023-04-03...
# ✅ Data fetched for USK.NS (2023-04-03 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/USK.NS_yearly_analysis.csv
# 📥 Processing UTIAMC.NS from 2020-10-12...
# ✅ Data fetched for UTIAMC.NS (2020-10-13 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/UTIAMC.NS_yearly_analysis.csv
# 📥 Processing UTKARSHBNK.NS from 2023-07-21...
# ✅ Data fetched for UTKARSHBNK.NS (2023-07-21 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/UTKARSHBNK.NS_yearly_analysis.csv
# 📥 Processing UYFINCORP.NS from 2024-10-03...
# ✅ Data fetched for UYFINCORP.NS (2024-10-03 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/UYFINCORP.NS_yearly_analysis.csv
# 🌍 Taking a longer break to avoid rate limits...
# 📥 Processing VAISHALI.NS from 2020-01-15...
# ✅ Data fetched for VAISHALI.NS (2020-01-15 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/VAISHALI.NS_yearly_analysis.csv
# 📥 Processing VALIANTLAB.NS from 2023-10-06...
# ✅ Data fetched for VALIANTLAB.NS (2023-10-06 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/VALIANTLAB.NS_yearly_analysis.csv
# 📥 Processing VALIANTORG.NS from 2021-07-23...
# ✅ Data fetched for VALIANTORG.NS (2021-07-23 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/VALIANTORG.NS_yearly_analysis.csv
# 📥 Processing VCL.NS from 2022-04-19...
# ✅ Data fetched for VCL.NS (2022-04-19 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/VCL.NS_yearly_analysis.csv
# 📥 Processing VENTIVE.NS from 2024-12-30...
# ✅ Data fetched for VENTIVE.NS (2024-12-30 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/VENTIVE.NS_yearly_analysis.csv
# 📥 Processing VENUSPIPES.NS from 2022-05-24...
# ✅ Data fetched for VENUSPIPES.NS (2022-05-24 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/VENUSPIPES.NS_yearly_analysis.csv
# 📥 Processing VERANDA.NS from 2022-04-11...
# ✅ Data fetched for VERANDA.NS (2022-04-11 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/VERANDA.NS_yearly_analysis.csv
# 📥 Processing VERTOZ.NS from 2020-05-14...
# ✅ Data fetched for VERTOZ.NS (2020-05-14 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/VERTOZ.NS_yearly_analysis.csv
# 📥 Processing VHLTD.NS from 2024-04-03...
# ✅ Data fetched for VHLTD.NS (2024-04-03 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/VHLTD.NS_yearly_analysis.csv
# 📥 Processing VIJAYA.NS from 2021-09-14...
# ✅ Data fetched for VIJAYA.NS (2021-09-14 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/VIJAYA.NS_yearly_analysis.csv
# 🌍 Taking a longer break to avoid rate limits...
# 📥 Processing VINCOFE.NS from 2024-10-18...
# ✅ Data fetched for VINCOFE.NS (2024-10-18 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/VINCOFE.NS_yearly_analysis.csv
# 📥 Processing VINEETLAB.NS from 2021-06-15...
# ✅ Data fetched for VINEETLAB.NS (2021-06-15 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/VINEETLAB.NS_yearly_analysis.csv
# 📥 Processing VINNY.NS from 2022-11-28...
# ✅ Data fetched for VINNY.NS (2022-11-28 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/VINNY.NS_yearly_analysis.csv
# 📥 Processing VIRINCHI.NS from 2023-05-03...
# ✅ Data fetched for VIRINCHI.NS (2023-05-03 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/VIRINCHI.NS_yearly_analysis.csv
# 📥 Processing VLEGOV.NS from 2023-08-14...
# ✅ Data fetched for VLEGOV.NS (2023-08-14 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/VLEGOV.NS_yearly_analysis.csv
# 📥 Processing VMM.NS from 2024-12-18...
# ✅ Data fetched for VMM.NS (2024-12-18 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/VMM.NS_yearly_analysis.csv
# 📥 Processing VPRPL.NS from 2023-09-05...
# ✅ Data fetched for VPRPL.NS (2023-09-05 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/VPRPL.NS_yearly_analysis.csv
# 📥 Processing VRAJ.NS from 2024-07-03...
# ✅ Data fetched for VRAJ.NS (2024-07-03 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/VRAJ.NS_yearly_analysis.csv
# 📥 Processing VSTL.NS from 2024-02-20...
# ✅ Data fetched for VSTL.NS (2024-02-20 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/VSTL.NS_yearly_analysis.csv
# 📥 Processing WAAREEENER.NS from 2024-10-28...
# ✅ Data fetched for WAAREEENER.NS (2024-10-28 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/WAAREEENER.NS_yearly_analysis.csv
# 🌍 Taking a longer break to avoid rate limits...
# 📥 Processing WCIL.NS from 2024-09-24...
# ✅ Data fetched for WCIL.NS (2024-09-24 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/WCIL.NS_yearly_analysis.csv
# 📥 Processing WEALTH.NS from 2021-01-20...
# ✅ Data fetched for WEALTH.NS (2021-01-20 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/WEALTH.NS_yearly_analysis.csv
# 📥 Processing WEL.NS from 2022-01-17...
# ✅ Data fetched for WEL.NS (2022-01-17 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/WEL.NS_yearly_analysis.csv
# 📥 Processing WESTLIFE.NS from 2023-06-05...
# ✅ Data fetched for WESTLIFE.NS (2023-06-05 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/WESTLIFE.NS_yearly_analysis.csv
# 📥 Processing WEWIN.NS from 2022-06-15...
# ✅ Data fetched for WEWIN.NS (2022-06-15 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/WEWIN.NS_yearly_analysis.csv
# 📥 Processing WINDLAS.NS from 2021-08-16...
# ✅ Data fetched for WINDLAS.NS (2021-08-16 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/WINDLAS.NS_yearly_analysis.csv
# 📥 Processing WORTH.NS from 2020-08-04...
# ✅ Data fetched for WORTH.NS (2020-08-04 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/WORTH.NS_yearly_analysis.csv
# 📥 Processing XTGLOBAL.NS from 2024-09-16...
# ✅ Data fetched for XTGLOBAL.NS (2024-09-16 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/XTGLOBAL.NS_yearly_analysis.csv
# 📥 Processing YASHO.NS from 2023-08-21...
# ✅ Data fetched for YASHO.NS (2023-08-21 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/YASHO.NS_yearly_analysis.csv
# 📥 Processing YATHARTH.NS from 2023-08-07...
# ✅ Data fetched for YATHARTH.NS (2023-08-07 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/YATHARTH.NS_yearly_analysis.csv
# 🌍 Taking a longer break to avoid rate limits...
# 📥 Processing YATRA.NS from 2023-09-28...
# ✅ Data fetched for YATRA.NS (2023-09-28 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/YATRA.NS_yearly_analysis.csv
# 📥 Processing YUKEN.NS from 2021-09-02...
# ✅ Data fetched for YUKEN.NS (2021-09-02 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/YUKEN.NS_yearly_analysis.csv
# 📥 Processing ZAGGLE.NS from 2023-09-22...
# ✅ Data fetched for ZAGGLE.NS (2023-09-22 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/ZAGGLE.NS_yearly_analysis.csv
# 📥 Processing ZIMLAB.NS from 2022-11-25...
# ✅ Data fetched for ZIMLAB.NS (2022-11-25 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/ZIMLAB.NS_yearly_analysis.csv
# 📥 Processing ZODIAC.NS from 2021-12-14...
# ✅ Data fetched for ZODIAC.NS (2021-12-14 - 2025-04-15)
# 📁 Saved: Stock_Analysis_Data/ZODIAC.NS_yearly_analysis.csv
# 📥 Processing ZOMATO.NS from 2021-07-23...
# ✅ Data fetched for ZOMATO.NS (2021-07-23 - 2025-04-11)
# 📁 Saved: Stock_Analysis_Data/ZOMATO.NS_yearly_analysis.csv
# 📊 Summary saved to Stock_Analysis_Data/all_stocks_latest_analysis.csv
# ✅ Analysis complete. Output in 'Stock_Analysis_Data/'

# %%
import shutil

# Replace 'your_folder_name' with the name of the folder you want to zip
folder_to_zip = 'Stock_Analysis_Data'
zip_filename = 'Stock_Analysis_Data.zip'

# Create zip file
shutil.make_archive(base_name=zip_filename.replace('.zip', ''), format='zip', root_dir=folder_to_zip)

print(f"Zipped folder saved as: {zip_filename}")
# Out:
# Zipped folder saved as: Stock_Analysis_Data.zip
